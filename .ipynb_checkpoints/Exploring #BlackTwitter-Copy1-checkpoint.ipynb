# %% [markdown]
# I'm not a big Twitter user, but I've heard the term "black twitter" come up in conversations. From what I gather, it's used to describe when black folks let our voices ring out on topics of interest to us. So I wanted to grab some twitter data and explore black twitter hashtags for myself to see what are the topics of conversation. Who is using this hashtag, and why? This notebook will dig into that.

# %%
from tweepy import OAuthHandler
import tweepy
import json
import pandas as pd
import csv
import string
import os
import time

# %% [markdown]
# You need to have Twitter credentials from a developer account in order to use the Twitter API

# %%
#Twitter credentials from developer account
consumer_key = "xxxxxxxxxxx"
consumer_secret = "xxxxxxxxxxxx"
access_token = "xxxxxxxxxxxxxxxxxx"
access_secret = "xxxxxxxxxxxxxxxxxxx"


auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
#Test out how data looks when pulled and paramaters
#ading tweet_mode='extended' was essential to get the full text

for tweet in tweepy.Cursor(api.search,q="#blacktwitter or #BlackTwitter or #blackTwitter or #Blacktwitter",count=100,
                           lang="en",
                           tweet_mode='extended',
                           since="2019-01-03", include_rts=False).items():
    print (tweet.created_at, "\n", tweet.user.screen_name, "\n", tweet.user.location, "\n", tweet.entities['hashtags'],"\n", tweet.entities['urls'])
    try:
        print(tweet.retweeted_status.full_text, "\n-----------------------")
    except:  # Not a Retweet
        print("not a retweet")
        try:
            print(tweet.full_text, "\n-----------------------")
        except:
            print(tweet.text, "\n---------------------")
# Out:
# 2020-05-03 22:14:56
#  iftikharsoomr0
#  Dubai, United Arab Emirates
#  [{'text': 'bluetweeter', 'indices': [121, 133]}, {'text': 'BlackTwitter', 'indices': [135, 148]}]
#  []
# not a retweet
# The most beautiful things in the world cannot be seen or even touched. They must be felt with heart ❤️
#
# (Helen keller)
#
# #bluetweeter
# #BlackTwitter https://t.co/C4qWekn3la
# -----------------------
# 2020-05-03 22:06:01
#  BlackPressRadio
#  Washington, DC in the USA
#  [{'text': 'BlackTwitter', 'indices': [246, 259]}, {'text': 'Tech4Covid', 'indices': [260, 271]}]
#  [{'url': 'https://t.co/TxCORto0bV', 'expanded_url': 'http://BlackWomenCEOS.com', 'display_url': 'BlackWomenCEOS.com', 'indices': [42, 65]}]
# not a retweet
# THIS IS MY 'WHY'!!! This is why I started https://t.co/TxCORto0bV and even am PERSONALLY hosting FOUNDERS FRIDAY so I can share tips with my young Black Women CEOs because we DON'T NEED THE BANKS OR VENTURE CAPITALISTS. They NEED us! - DC Livers #BlackTwitter #Tech4Covid https://t.co/nwfZy1M4qt
# -----------------------
# 2020-05-03 21:56:48
#  SadafReal
#  Karachi, Pakistan
#  [{'text': 'BlackTwitter', 'indices': [87, 100]}]
#  []
# not a retweet
# Just trust those things which are seen or heard by yourself not conveyed from others.  #BlackTwitter https://t.co/o6VHub6B2L
# -----------------------
# 2020-05-03 21:45:17
#  OurBloggingLife
#
#  []
#  []
# Here is a Great List of Best Google Adsense Alternatives which will helps to monetize your blog or website. I know you are very excited to know. So let's started 👇
# https://t.co/PsfzhgrjoC
#
# #Google #1May #WordPress #BlackTwitter #BloggingCommunity #blogger #SEO #bloggers #adsense https://t.co/4pgovfgxrF
# -----------------------
# 2020-05-03 21:45:12
#  or_she_raja_g
#   420
#  [{'text': 'BlackTwitter', 'indices': [58, 71]}]
#  []
# The only colour which i prefer the most🖤🖤🖤🖤
# #BlackTwitter https://t.co/kK9bAXIU4h
# -----------------------
# 2020-05-03 21:42:45
#  889_neo
#
#  []
#  []
# Here is a Great List of Best Google Adsense Alternatives which will helps to monetize your blog or website. I know you are very excited to know. So let's started 👇
# https://t.co/PsfzhgrjoC
#
# #Google #1May #WordPress #BlackTwitter #BloggingCommunity #blogger #SEO #bloggers #adsense https://t.co/4pgovfgxrF
# -----------------------
# 2020-05-03 21:26:23
#  ayajnabi
#  astéri
#  [{'text': 'BlackTwitter', 'indices': [26, 39]}, {'text': 'throwback', 'indices': [45, 55]}]
#  []
# Is it #BlackTwitter
# Or
# #throwback https://t.co/zD7cXLo3B3
# -----------------------
# 2020-05-03 21:03:03
#  marco_bal99
#  Italia
#  [{'text': 'BlackExcellence', 'indices': [96, 112]}, {'text': 'BlackTwitter', 'indices': [113, 126]}]
#  [{'url': 'https://t.co/flVtsy8ypd', 'expanded_url': 'https://bit.ly/34ztco8', 'display_url': 'bit.ly/34ztco8', 'indices': [72, 95]}]
# If Your Child Is In 1st or 2nd Grade, Read This! - https://t.co/flVtsy8ypd #BlackExcellence #BlackTwitter #SupportBlackBusiness https://t.co/6dzpL2Ifqq
# -----------------------
# 2020-05-03 20:52:11
#  AmnaadnanAD
#  Dubai, United Arab Emirates
#  [{'text': 'BlackTwitter', 'indices': [33, 46]}]
#  []
# not a retweet
# What will be next colour trend ? #BlackTwitter white or pink ? https://t.co/4OJrC0ifKq
# -----------------------
# 2020-05-03 20:46:58
#  lakapakhtundey
#  Karachi, Pakistan
#  [{'text': 'BlackTwitter', 'indices': [32, 45]}]
#  []
# yes or no?
#  #BlackTwitter https://t.co/8HiIqyxZMF
# -----------------------
# 2020-05-03 20:45:30
#  KNiazi69
#  Qatar +974 31491000 whatsApp
#  [{'text': 'BlackTwitter', 'indices': [17, 30]}]
#  []
# #BlackTwitter or this. https://t.co/J1PYEo3yk2
# -----------------------
# 2020-05-03 20:30:08
#  blackpeopledata
#  Global
#  [{'text': 'BlackExcellence', 'indices': [96, 112]}, {'text': 'BlackTwitter', 'indices': [113, 126]}]
#  [{'url': 'https://t.co/flVtsy8ypd', 'expanded_url': 'https://bit.ly/34ztco8', 'display_url': 'bit.ly/34ztco8', 'indices': [72, 95]}]
# If Your Child Is In 1st or 2nd Grade, Read This! - https://t.co/flVtsy8ypd #BlackExcellence #BlackTwitter #SupportBlackBusiness https://t.co/6dzpL2Ifqq
# -----------------------
# 2020-05-03 20:29:07
#  blackpeopledata
#  Global
#  [{'text': 'BlackExcellence', 'indices': [111, 127]}]
#  [{'url': 'https://t.co/bgPaAAGQKm', 'expanded_url': 'https://bit.ly/2LzlnGc', 'display_url': 'bit.ly/2LzlnGc', 'indices': [87, 110]}]
# If Your Child Is In Pre-K or Kindergarten, Read This Right Now! - https://t.co/bgPaAAGQKm #BlackExcellence #BlackTwitter #SupportBlackBusiness https://t.co/oqwcFAxCh4
# -----------------------
# 2020-05-03 20:25:32
#  ch_rehaan
#  New York, NY
#  [{'text': 'BlackTwitter', 'indices': [22, 35]}, {'text': 'WhiteTwitter', 'indices': [39, 52]}]
#  []
# not a retweet
# tell me should i find #BlackTwitter or #WhiteTwitter? 🙈
# -----------------------
# 2020-05-03 20:19:24
#  hamidhayatnatt
#  Lahore-Islamabad via GT Road
#  [{'text': 'BlackTwitter', 'indices': [6, 19]}, {'text': 'throwback', 'indices': [25, 35]}]
#  []
# not a retweet
# Is it #BlackTwitter
# Or
# #throwback https://t.co/zD7cXLo3B3
# -----------------------
# 2020-05-03 20:18:38
#  GulKhanummm
#  Lala land
#  [{'text': 'BlackTwitter', 'indices': [0, 13]}]
#  []
# not a retweet
# #BlackTwitter or this 😍 https://t.co/i5UtSpDx8l
# -----------------------
# 2020-05-03 20:17:47
#  GulKhanummm
#  Lala land
#  [{'text': 'BlackTwitter', 'indices': [0, 13]}]
#  []
# not a retweet
# #BlackTwitter or this. https://t.co/J1PYEo3yk2
# -----------------------
# 2020-05-03 20:16:47
#  BlackParenting1
#  Los Angeles, CA
#  [{'text': 'BlackExcellence', 'indices': [90, 106]}, {'text': 'BlackTwitter', 'indices': [107, 120]}, {'text': 'SupportBlackBusiness', 'indices': [121, 142]}]
#  [{'url': 'https://t.co/bgPaAAGQKm', 'expanded_url': 'https://bit.ly/2LzlnGc', 'display_url': 'bit.ly/2LzlnGc', 'indices': [66, 89]}]
# not a retweet
# If Your Child Is In Pre-K or Kindergarten, Read This Right Now! - https://t.co/bgPaAAGQKm #BlackExcellence #BlackTwitter #SupportBlackBusiness https://t.co/oqwcFAxCh4
# -----------------------
# 2020-05-03 20:05:44
#  YallJustDontKno
#  MS
#  []
#  []
# Black ppl, men and women, being some of the poorest mfers sure do argue and shame mfers abt money alot
#
# Most of us started from 0 or -17 but can’t understand dual income households or mfers that are struggling financially. It’s why I say #BlackTwitter is the twilight zone
# -----------------------
# 2020-05-03 20:01:52
#  BlackParenting1
#  Los Angeles, CA
#  [{'text': 'BlackExcellence', 'indices': [75, 91]}, {'text': 'BlackTwitter', 'indices': [92, 105]}, {'text': 'SupportBlackBusiness', 'indices': [106, 127]}]
#  [{'url': 'https://t.co/flVtsy8ypd', 'expanded_url': 'https://bit.ly/34ztco8', 'display_url': 'bit.ly/34ztco8', 'indices': [51, 74]}]
# not a retweet
# If Your Child Is In 1st or 2nd Grade, Read This! - https://t.co/flVtsy8ypd #BlackExcellence #BlackTwitter #SupportBlackBusiness https://t.co/6dzpL2Ifqq
# -----------------------
# 2020-05-03 19:48:24
#  ezwuzhere
#  Atlanta, GA
#  []
#  []
# Black ppl, men and women, being some of the poorest mfers sure do argue and shame mfers abt money alot
#
# Most of us started from 0 or -17 but can’t understand dual income households or mfers that are struggling financially. It’s why I say #BlackTwitter is the twilight zone
# -----------------------
# 2020-05-03 19:43:47
#  RobIsRandomAF_6
#  Biting My Wife's Butt, TX
#  [{'text': 'BlackTwitter', 'indices': [238, 251]}]
#  []
# not a retweet
# Black ppl, men and women, being some of the poorest mfers sure do argue and shame mfers abt money alot
#
# Most of us started from 0 or -17 but can’t understand dual income households or mfers that are struggling financially. It’s why I say #BlackTwitter is the twilight zone
# -----------------------
# 2020-05-03 19:09:12
#  ranashaheryar
#  Pakistan
#  [{'text': 'BlackTwitter', 'indices': [15, 28]}]
#  []
# #BlackTwitter For there is no Black as beautiful as the Ghilaaf- e- kaaba SubhanAllah. Ya Allah please take us all for Umrah or Hajj soon , to see the beautiful Khaan e Kaaba soon. Ameen
# #BlackTwitter
# #haram https://t.co/VuU570RpSo
# -----------------------
# 2020-05-03 19:06:53
#  Cazmir_Da_Gr8
#
#  [{'text': 'BlueLivesMatter', 'indices': [215, 231]}, {'text': 'BlackTwitter', 'indices': [232, 245]}, {'text': 'Democrats', 'indices': [246, 256]}, {'text': 'Republican', 'indices': [257, 268]}]
#  []
# not a retweet
# It seems like no social movement or political party can demonstrate integrity anymore. From Blue Lives Matter and Black Lives Matter to Democrats and Republicans, they're all hypocrites unless it fits their agenda. #BlueLivesMatter #BlackTwitter #Democrats #Republican
# -----------------------
# 2020-05-03 19:01:32
#  Aestheticthin13
#
#  []
#  []
# Hey everyone!! I just officially published my lil shopify website! Yay! I would appreciate it so much if y’all supported my dreams of eventually self-publishing my poetry, by purchasing some of my pieces or rting❤️
#
# Just a tiny black gal trying to become big 🙌🏾
#
# #BlackTwitter https://t.co/OZgSPHdFy1
# -----------------------
# 2020-05-03 18:55:16
#  FaatiAmir
#  Islamabad
#  [{'text': 'BlackTwitter', 'indices': [247, 260]}]
#  []
# not a retweet
# THREAD ON KAABAH 🖤
# Muslims believe that Abraham known as Ibrahim in the Islamic tradition and his son constructed the Kaaba.
# The Kaaba is the center of the earth.
# It is therefore impossible to fly over the Kaaba either by birds or even airplanes.
# #BlackTwitter https://t.co/2G8hkP3P2l
# -----------------------
# 2020-05-03 18:51:07
#  MrJordanBrown
#  HARLEM, NY
#  [{'text': 'MrBROWNsRealTalk', 'indices': [0, 17]}, {'text': 'PleaseSHARE', 'indices': [19, 31]}, {'text': 'BlackTwitter', 'indices': [92, 105]}, {'text': 'HIPHOP', 'indices': [119, 126]}, {'text': 'VEGAN', 'indices': [127, 133]}, {'text': 'SMART', 'indices': [148, 154]}, {'text': 'URBAN', 'indices': [155, 161]}, {'text': 'VEGGIE', 'indices': [162, 169]}, {'text': 'FARM', 'indices': [170, 175]}]
#  [{'url': 'https://t.co/UWDPDu0zhy', 'expanded_url': 'https://bvbvotwu.shop/products/hydroponic-cultivation-equipment-soilless-cultivation-planting-box-intelligent-control-flower-pot-desktop-vegetable-grow-box', 'display_url': 'bvbvotwu.shop/products/hydro…', 'indices': [178, 201]}]
# not a retweet
# #MrBROWNsRealTalk: #PleaseSHARE
# 🙏🏿“GOD BLESS THE 🧒🏿 CHILD 👶🏿 THAT GROWS HIS OR HER OWN!!!🙏🏿 #BlackTwitter
# “HYDROPONIC #HIPHOP #VEGAN / SOIL-FREE / #SMART #URBAN #VEGGIE #FARM!" https://t.co/UWDPDu0zhy
# -----------------------
# 2020-05-03 18:46:33
#  UrFragileEgo
#  خاکِ جاناں
#  [{'text': 'BlackTwitter', 'indices': [0, 13]}]
#  []
# not a retweet
# #BlackTwitter Or yeh huta
# Damn Fucking Hot ,handsome, dashing, Sexy
# Uuuuufffffff.. ❤️❤️❤️💞💞💞 Tabahai. https://t.co/vN2hZsbJrr
# -----------------------
# 2020-05-03 18:39:20
#  usnehal
#  Manhattan, NY
#  [{'text': 'implicitbias', 'indices': [128, 141]}, {'text': 'socialmedia', 'indices': [179, 191]}, {'text': 'medTwitter', 'indices': [198, 209]}, {'text': 'blacktwitter', 'indices': [232, 245]}]
#  [{'url': 'https://t.co/gBnHJJCquB', 'expanded_url': 'https://coco-net.org/problem-woman-colour-nonprofit-organizations/', 'display_url': 'coco-net.org/problem-woman-…', 'indices': [309, 332]}]
# not a retweet
# @EEEaley @Vancbromycin @USC @USCViterbi @KeckMedUSC Racist policing on communication is a classic form of structural racism and #implicitbias so it is highly likely to show up on #socialmedia &amp; #medTwitter, especially regarding #blacktwitter trends or black culture
#
# This is about WOC but applies to POC
#
# https://t.co/gBnHJJCquB
# -----------------------
# 2020-05-03 18:37:34
#  aroobakhanghori
#  space
#  [{'text': 'BlackTwitter', 'indices': [32, 45]}]
#  []
# yes or no?
#  #BlackTwitter https://t.co/8HiIqyxZMF
# -----------------------
# 2020-05-03 18:37:10
#  mnakkhan
#  🇵🇰#PTIMemberSince1999
#  [{'text': 'BlackTwitter', 'indices': [156, 169]}]
#  [{'url': 'https://t.co/KXuWQjZxYb', 'expanded_url': 'https://twitter.com/BANOCHI/status/1256002935810666498', 'display_url': 'twitter.com/BANOCHI/status…', 'indices': [170, 193]}]
# not a retweet
# I asked an old man: Which is more important. [To love or to be loved?]
# Old man replied: Which is more important to a bird? The left wing or the right wing?
# #BlackTwitter https://t.co/KXuWQjZxYb
# -----------------------
# 2020-05-03 18:36:16
#  ProBlactivist
#  Harlem
#  [{'text': 'BlackTwitter', 'indices': [0, 13]}]
#  []
# not a retweet
# #BlackTwitter He obviously doesn’t give a shit whether or not he can say the n word, sooo why don’t we all email his school 😪 https://t.co/amuz1YfR99
# -----------------------
# 2020-05-03 18:33:30
#  Dorlion26_
#  Eskişehir, Türkiye
#  [{'text': 'BlackTwitter', 'indices': [15, 28]}]
#  []
# #BlackTwitter For there is no Black as beautiful as the Ghilaaf- e- kaaba SubhanAllah. Ya Allah please take us all for Umrah or Hajj soon , to see the beautiful Khaan e Kaaba soon. Ameen
# #BlackTwitter
# #haram https://t.co/VuU570RpSo
# -----------------------
# 2020-05-03 18:27:43
#  Katakana071
#  Киев
#  [{'text': 'BlackTwitter', 'indices': [15, 28]}]
#  []
# #BlackTwitter For there is no Black as beautiful as the Ghilaaf- e- kaaba SubhanAllah. Ya Allah please take us all for Umrah or Hajj soon , to see the beautiful Khaan e Kaaba soon. Ameen
# #BlackTwitter
# #haram https://t.co/VuU570RpSo
# -----------------------
# 2020-05-03 18:27:07
#  saqibf
#  Karachi, Pakistan
#  [{'text': 'BlackTwitter', 'indices': [15, 28]}]
#  []
# #BlackTwitter For there is no Black as beautiful as the Ghilaaf- e- kaaba SubhanAllah. Ya Allah please take us all for Umrah or Hajj soon , to see the beautiful Khaan e Kaaba soon. Ameen
# #BlackTwitter
# #haram https://t.co/VuU570RpSo
# -----------------------
# 2020-05-03 18:24:15
#  p_tomblin
#  Las Vegas, NV
#  [{'text': 'TurnEmLoose', 'indices': [96, 108]}, {'text': 'blackmen', 'indices': [109, 118]}, {'text': 'BlackTwitter', 'indices': [119, 132]}, {'text': 'funtimes', 'indices': [133, 142]}, {'text': 'laughter', 'indices': [143, 152]}]
#  []
# not a retweet
# What does it mean when the thugs call you Sir?? Did I get that old or did thugs get respectful?
# #TurnEmLoose #blackmen #BlackTwitter #funtimes #laughter #
# -----------------------
# 2020-05-03 18:23:35
#  iamisgana
#  merkato bete
#  []
#  []
# Colorism at its finest. Rap battle or not talking about pimping out a black 6yr old girl is disgusting. We need to protect our children and women, this should not be the norm. A full 4 minutes of bullshit. #BlackTwitter https://t.co/7n9vYoaD8y
# -----------------------
# 2020-05-03 18:14:19
#  rennyderin
#
#  []
#  []
# Hey everyone!! I just officially published my lil shopify website! Yay! I would appreciate it so much if y’all supported my dreams of eventually self-publishing my poetry, by purchasing some of my pieces or rting❤️
#
# Just a tiny black gal trying to become big 🙌🏾
#
# #BlackTwitter https://t.co/OZgSPHdFy1
# -----------------------
# 2020-05-03 18:02:27
#  thehoracetowns
#  Palm Beach, Florida.  Atlanta
#  [{'text': 'BlackTwitter', 'indices': [220, 233]}]
#  []
# not a retweet
# Florida never got Donkey of the Day or had a bad image until the state got more residents from New York, Philly, Jersey, and D.C.   All those people in the news are from those states. South Florida people are laid back  #BlackTwitter
# -----------------------
# 2020-05-03 18:01:49
#  _ajike_
#  West Africa_Nigeria_Lagos
#  []
#  []
# Hey everyone!! I just officially published my lil shopify website! Yay! I would appreciate it so much if y’all supported my dreams of eventually self-publishing my poetry, by purchasing some of my pieces or rting❤️
#
# Just a tiny black gal trying to become big 🙌🏾
#
# #BlackTwitter https://t.co/OZgSPHdFy1
# -----------------------
# 2020-05-03 17:47:49
#  samalsufiani
#  United States Of America 🇺🇸
#  [{'text': 'BlackTwitter', 'indices': [15, 28]}]
#  []
# #BlackTwitter For there is no Black as beautiful as the Ghilaaf- e- kaaba SubhanAllah. Ya Allah please take us all for Umrah or Hajj soon , to see the beautiful Khaan e Kaaba soon. Ameen
# #BlackTwitter
# #haram https://t.co/VuU570RpSo
# -----------------------
# 2020-05-03 17:46:49
#  greatestarcane
#  CareVille
#  []
#  []
# Hey everyone!! I just officially published my lil shopify website! Yay! I would appreciate it so much if y’all supported my dreams of eventually self-publishing my poetry, by purchasing some of my pieces or rting❤️
#
# Just a tiny black gal trying to become big 🙌🏾
#
# #BlackTwitter https://t.co/OZgSPHdFy1
# -----------------------
# 2020-05-03 17:33:19
#  Tozanthecreator
#
#  []
#  []
# Hey everyone!! I just officially published my lil shopify website! Yay! I would appreciate it so much if y’all supported my dreams of eventually self-publishing my poetry, by purchasing some of my pieces or rting❤️
#
# Just a tiny black gal trying to become big 🙌🏾
#
# #BlackTwitter https://t.co/OZgSPHdFy1
# -----------------------
# 2020-05-03 17:32:36
#  TugayHatayli
#  İzmir, Türkiye [Man]
#  [{'text': 'BlackTwitter', 'indices': [15, 28]}]
#  []
# #BlackTwitter For there is no Black as beautiful as the Ghilaaf- e- kaaba SubhanAllah. Ya Allah please take us all for Umrah or Hajj soon , to see the beautiful Khaan e Kaaba soon. Ameen
# #BlackTwitter
# #haram https://t.co/VuU570RpSo
# -----------------------
# 2020-05-03 17:29:11
#  talhajan_tj
#  Punjab, Pakistan
#  [{'text': '12yrsMadaniChannel', 'indices': [101, 120]}, {'text': 'BlackTwitter', 'indices': [121, 134]}, {'text': 'عوام_دوست_حکومت', 'indices': [136, 152]}, {'text': 'PakistanMaangeWar', 'indices': [154, 172]}, {'text': 'Kashmir', 'indices': [173, 181]}, {'text': 'ArrestArnab', 'indices': [183, 195]}, {'text': 'IForIndia', 'indices': [196, 206]}, {'text': 'HandwaraEncounter', 'indices': [207, 225]}]
#  [{'url': 'https://t.co/XiWREV7X2s', 'expanded_url': 'https://www.fiverr.com/share/d0Pwx0', 'display_url': 'fiverr.com/share/d0Pwx0', 'indices': [228, 251]}]
# not a retweet
# Check out my Gig on Fiverr: design wordpress website using astra pro, elementor pro or divi builder
# #12yrsMadaniChannel #BlackTwitter  #عوام_دوست_حکومت
# #PakistanMaangeWar #Kashmir  #ArrestArnab #IForIndia #HandwaraEncounter
#
# https://t.co/XiWREV7X2s
# -----------------------
# 2020-05-03 17:23:06
#  UrFragileEgo
#  خاکِ جاناں
#  [{'text': 'BlackTwitter', 'indices': [15, 28]}]
#  []
# #BlackTwitter For there is no Black as beautiful as the Ghilaaf- e- kaaba SubhanAllah. Ya Allah please take us all for Umrah or Hajj soon , to see the beautiful Khaan e Kaaba soon. Ameen
# #BlackTwitter
# #haram https://t.co/VuU570RpSo
# -----------------------
# 2020-05-03 17:17:57
#  MZia009
#  Singapore, Bangkok, Jakarta.
#  [{'text': 'BlackTwitter', 'indices': [23, 36]}]
#  []
# not a retweet
# Black or put in Back..
# #BlackTwitter https://t.co/dfAECrdAj0
# -----------------------
# 2020-05-03 17:10:10
#  Wisevenus
#
#  [{'text': 'BlackTwitter', 'indices': [0, 13]}, {'text': 'BlackTwitter', 'indices': [187, 200]}, {'text': 'haram', 'indices': [202, 208]}]
#  []
# not a retweet
# #BlackTwitter For there is no Black as beautiful as the Ghilaaf- e- kaaba SubhanAllah. Ya Allah please take us all for Umrah or Hajj soon , to see the beautiful Khaan e Kaaba soon. Ameen
# #BlackTwitter
# #haram https://t.co/VuU570RpSo
# -----------------------
# 2020-05-03 16:58:06
#  AbleGod_givet
#  Lagos, Nigeria
#  []
#  []
# Hey everyone!! I just officially published my lil shopify website! Yay! I would appreciate it so much if y’all supported my dreams of eventually self-publishing my poetry, by purchasing some of my pieces or rting❤️
#
# Just a tiny black gal trying to become big 🙌🏾
#
# #BlackTwitter https://t.co/OZgSPHdFy1
# -----------------------
# 2020-05-03 16:53:51
#  Mack_N_Cheese8
#
#  []
#  []
# Hey everyone!! I just officially published my lil shopify website! Yay! I would appreciate it so much if y’all supported my dreams of eventually self-publishing my poetry, by purchasing some of my pieces or rting❤️
#
# Just a tiny black gal trying to become big 🙌🏾
#
# #BlackTwitter https://t.co/OZgSPHdFy1
# -----------------------
# 2020-05-03 16:52:16
#  PurpleFuego_
#  Micheal Scott Paper Company
#  []
#  []
# Hey everyone!! I just officially published my lil shopify website! Yay! I would appreciate it so much if y’all supported my dreams of eventually self-publishing my poetry, by purchasing some of my pieces or rting❤️
#
# Just a tiny black gal trying to become big 🙌🏾
#
# #BlackTwitter https://t.co/OZgSPHdFy1
# -----------------------
# 2020-05-03 16:51:57
#  baabykayyy
#  Bay Area, CA
#  []
#  []
# Hey everyone!! I just officially published my lil shopify website! Yay! I would appreciate it so much if y’all supported my dreams of eventually self-publishing my poetry, by purchasing some of my pieces or rting❤️
#
# Just a tiny black gal trying to become big 🙌🏾
#
# #BlackTwitter https://t.co/OZgSPHdFy1
# -----------------------
# 2020-05-03 16:49:22
#  _SlaveInUtero
#
#  []
#  []
# Hey everyone!! I just officially published my lil shopify website! Yay! I would appreciate it so much if y’all supported my dreams of eventually self-publishing my poetry, by purchasing some of my pieces or rting❤️
#
# Just a tiny black gal trying to become big 🙌🏾
#
# #BlackTwitter https://t.co/OZgSPHdFy1
# -----------------------
# 2020-05-03 16:46:25
#  iits_hassan
#  کراچی, پاکستان
#  [{'text': 'BlackTwitter', 'indices': [32, 45]}]
#  []
# yes or no?
#  #BlackTwitter https://t.co/8HiIqyxZMF
# -----------------------
# 2020-05-03 16:29:59
#  illuminottee
#  Sydney, New South Wales
#  [{'text': 'BlackTwitter', 'indices': [18, 31]}]
#  []
# #BlackTwitter or or orrrrr 🔥🔥 https://t.co/yMyPd2AXas
# -----------------------
# 2020-05-03 16:25:19
#  ZiadaMtBolaKaro
#
#  [{'text': 'BlackTwitter', 'indices': [32, 45]}]
#  []
# yes or no?
#  #BlackTwitter https://t.co/8HiIqyxZMF
# -----------------------
# 2020-05-03 16:24:32
#  thisiskhann
#  پاکستان
#  [{'text': 'BlackTwitter', 'indices': [32, 45]}]
#  []
# yes or no?
#  #BlackTwitter https://t.co/8HiIqyxZMF
# -----------------------
# 2020-05-03 16:22:54
#  UmarHayaKr
#  Lahore, Pakistan.
#  [{'text': 'BlackTwitter', 'indices': [32, 45]}]
#  []
# yes or no?
#  #BlackTwitter https://t.co/8HiIqyxZMF
# -----------------------
# 2020-05-03 16:22:02
#  lakapakhtundey
#  Karachi, Pakistan
#  [{'text': 'BlackTwitter', 'indices': [12, 25]}]
#  []
# not a retweet
# yes or no?
#  #BlackTwitter https://t.co/8HiIqyxZMF
# -----------------------
# 2020-05-03 16:03:20
#  RScotland
#  NYC
#  [{'text': 'COVIDー19', 'indices': [79, 88]}, {'text': 'BlackTwitter', 'indices': [89, 102]}]
#  [{'url': 'https://t.co/VQN6wefO4B', 'expanded_url': 'https://youtu.be/2yu4jSPNtic', 'display_url': 'youtu.be/2yu4jSPNtic', 'indices': [105, 128]}]
# not a retweet
# ♥️ 🧼 🖐🏾🖐🏽🖐🏼 20 Seconds or More ft. Doug E. Fresh, Artie Green &amp; Gerry Gunn #COVIDー19 #BlackTwitter~  https://t.co/VQN6wefO4B via @YouTube
# -----------------------
# 2020-05-03 15:53:10
#  LyietSyied
#  Gaborone, Botswana
#  [{'text': 'NtshalamoragoBW', 'indices': [184, 200]}, {'text': 'BlackTwitter', 'indices': [202, 215]}, {'text': 'BW', 'indices': [217, 220]}, {'text': 'RSA', 'indices': [221, 225]}, {'text': 'TLasleepBW', 'indices': [227, 238]}]
#  []
# not a retweet
# So where my RSAn family and friends at? They keep talmbout BW's low population when it's got to do with good things. Wanna jump on this here one as well. You're at 66 or something FYI
# #NtshalamoragoBW
# #BlackTwitter
# #BW
# #RSA
# #TLasleepBW https://t.co/BojSxvEEjd
# -----------------------
# 2020-05-03 15:43:31
#  sintiaiswhack
#
#  [{'text': 'BlackTwitter', 'indices': [240, 253]}, {'text': 'StopTheHate', 'indices': [254, 266]}]
#  []
# not a retweet
# I’ve always felt like the non African Americans that want to say the N word want to say it because they wanna feel more superior than us or to remind us that we’re beneath them, and that just isn’t the case anymore and they can’t handle it #BlackTwitter #StopTheHate
# -----------------------
# 2020-05-03 15:22:00
#  TachyonFlash
#  Sindh, Pakistan
#  [{'text': 'BlackTwitter', 'indices': [0, 13]}]
#  []
# not a retweet
# #BlackTwitter or or orrrrr 🔥🔥 https://t.co/yMyPd2AXas
# -----------------------
# 2020-05-03 15:20:11
#  captannaveed
#  layyah
#  []
#  []
# Imagine you have no money to buy dinner for your family.
# What will you do?
# Go out and earn money or sit at home for the sake of corona?
# Bhook sab say bara virus hai.
# #SindhGovt #lockdown #BlackTwitter #CallOffBoardExams #COVIDー19
# -----------------------
# 2020-05-03 15:16:47
#  Intellactual86
#  فیصل آباد، پنجاب، پاکستان
#  [{'text': 'BlackTwitter', 'indices': [17, 30]}, {'text': 'BackTwitter', 'indices': [34, 46]}]
#  []
# not a retweet
# @memebaaz_ Is it #BlackTwitter or #BackTwitter 😂
# -----------------------
# 2020-05-03 15:16:41
#  nimratahreem
#
#  [{'text': 'CallOfBoardExams', 'indices': [0, 17]}, {'text': 'AskKajol', 'indices': [18, 27]}, {'text': 'BlackTwitter', 'indices': [28, 41]}, {'text': 'day38oflockdown', 'indices': [42, 58]}, {'text': 'UnitedStates', 'indices': [59, 72]}, {'text': 'เนเน่', 'indices': [73, 79]}, {'text': 'Madres', 'indices': [80, 87]}, {'text': 'แพรวาโกงทุกด้อม', 'indices': [88, 104]}, {'text': 'تجربة_تصفح_فريدة', 'indices': [106, 123]}]
#  [{'url': 'https://t.co/xnhwBDFA1z', 'expanded_url': 'https://www.fiverr.com/s2/628375a974?utm_source=Twitter_Mobile', 'display_url': 'fiverr.com/s2/628375a974?…', 'indices': [241, 264]}]
# not a retweet
# #CallOfBoardExams #AskKajol #BlackTwitter #day38oflockdown #UnitedStates #เนเน่ #Madres #แพรวาโกงทุกด้อม  #تجربة_تصفح_فريدة
# For an outstanding professional flat/minimalist logo design. Contact me now, and enjoy cheap rates in this lockdown.
# https://t.co/xnhwBDFA1z
# -----------------------
# 2020-05-03 15:16:00
#  imSMHasanDanish
#  Karachi, Pakistan
#  [{'text': 'SindhGovt', 'indices': [169, 179]}, {'text': 'lockdown', 'indices': [180, 189]}, {'text': 'BlackTwitter', 'indices': [190, 203]}, {'text': 'CallOffBoardExams', 'indices': [204, 222]}, {'text': 'COVIDー19', 'indices': [223, 232]}]
#  []
# not a retweet
# Imagine you have no money to buy dinner for your family.
# What will you do?
# Go out and earn money or sit at home for the sake of corona?
# Bhook sab say bara virus hai.
# #SindhGovt #lockdown #BlackTwitter #CallOffBoardExams #COVIDー19
# -----------------------
# 2020-05-03 15:08:52
#  nimratahreem
#
#  [{'text': 'CallOfBoardExams', 'indices': [0, 17]}, {'text': 'AskKajol', 'indices': [18, 27]}, {'text': 'BlackTwitter', 'indices': [28, 41]}, {'text': 'day38oflockdown', 'indices': [42, 58]}, {'text': 'UnitedStates', 'indices': [59, 72]}, {'text': 'เนเน่', 'indices': [73, 79]}, {'text': 'Madres', 'indices': [80, 87]}, {'text': 'แพรวาโกงทุกด้อม', 'indices': [88, 104]}]
#  [{'url': 'https://t.co/kYWjZZecbc', 'expanded_url': 'https://www.fiverr.com/s2/f41924104a?utm_source=Twitter_Mobile', 'display_url': 'fiverr.com/s2/f41924104a?…', 'indices': [257, 280]}]
# not a retweet
# #CallOfBoardExams #AskKajol #BlackTwitter #day38oflockdown #UnitedStates #เนเน่ #Madres #แพรวาโกงทุกด้อม Want an outstanding signature logo for your name business/brand? Contact me now. Click the link below and enjoy cheap rates in this lockdown situation
# https://t.co/kYWjZZecbc
# -----------------------
# 2020-05-03 15:07:41
#  tridentflow
#  Ontario, Canada
#  [{'text': 'BlackTwitter', 'indices': [252, 265]}]
#  []
# not a retweet
# I wanna get rich and start farming. I want land. I want to run a black owned farm. Then an organic supermarket. I have 50 year plans in the making and I pray I don’t get killed or this tweet gets removed because it invokes inspiration among my people. #BlackTwitter
# -----------------------
# 2020-05-03 15:05:35
#  Anony42644349
#
#  [{'text': 'PanAfricanism', 'indices': [193, 207]}, {'text': 'BlackTwitter', 'indices': [209, 222]}]
#  []
# not a retweet
# @DjNewAfrica They prioritise issues of national importance, issues that affect ordinary South Africans. They do not follow celebs or politicians and are not paid to defend factions in parties. #PanAfricanism  #BlackTwitter
# -----------------------
# 2020-05-03 14:47:49
#  jstwalkingby
#  Dystopia
#  [{'text': 'BlackTwitter', 'indices': [25, 38]}]
#  []
# not a retweet
# Let it be blue or red or #BlackTwitter  my tweets always go unnoticed in the fuckin world where nothing goes unnoticed.
# -----------------------
# 2020-05-03 14:41:22
#  J00NIPERBERRY
#
#  [{'text': 'blacktwitter', 'indices': [81, 94]}, {'text': 'Malutrevejo', 'indices': [95, 107]}, {'text': 'whiteprivilege', 'indices': [108, 123]}]
#  []
# i don’t care how or when but this better reach black twitter. #blacktwitter #Malutrevejo #whiteprivilege https://t.co/v36NJCbNth
# -----------------------
# 2020-05-03 14:28:58
#  Or_sunaao
#  Me hu he nahi is duniya ki
#  [{'text': 'BlackTwitter', 'indices': [9, 22]}]
#  []
# not a retweet
# Finally  #BlackTwitter is here. 🖤
# -----------------------
# 2020-05-03 14:00:46
#  Irishbrat1966
#
#  [{'text': 'Pennsylvania', 'indices': [15, 28]}, {'text': 'BlackTwitter', 'indices': [29, 42]}]
#  []
# #Pennsylvania #BlackTwitter I think this is why they are keeping people in halfway house against their home plans for the next 2 weeks they can't go to work, I'm not sure if it's all or just a specific one here in Lackawanna county. Doesn't seem right! Can't get black people to.. https://t.co/NZhyLNTvov
# -----------------------
# 2020-05-03 13:56:09
#  Ashish22173724
#
#  [{'text': 'BlueTwitter', 'indices': [60, 72]}, {'text': 'BlackTwitter', 'indices': [77, 90]}, {'text': 'AyezaKhan', 'indices': [107, 117]}, {'text': 'ArtiSingh', 'indices': [118, 128]}]
#  []
# I don't care if it's there or not
#
# Doing #BlueTwitter and #BlackTwitter again for them
#
# #AyezaKhan
# #ArtiSingh
# #ShilpaShinde
# Bonus:-#RashamiDesai https://t.co/twtfOCS65u
# -----------------------
# 2020-05-03 12:58:54
#  ComedicHotep
#  Wakanda
#  [{'text': 'BlackTwitter', 'indices': [86, 99]}]
#  []
# not a retweet
# Are there any black screen writers or playwrights I can email ? Black Directors too ? #BlackTwitter
# -----------------------
# 2020-05-03 12:37:24
#  abeerberkat
#  اسلام آباد, پاکستان
#  [{'text': 'BlackTwitter', 'indices': [111, 124]}]
#  []
# not a retweet
# Sooner or later, we, the humans would kill the earth and won't have anyone to blame ✌️... The most scary black
# #BlackTwitter https://t.co/ZVVAVt3TI8
# -----------------------
# 2020-05-03 12:22:48
#  isitjustus2
#
#  [{'text': 'GrowingUpBlack', 'indices': [129, 144]}, {'text': '2Black2Strong', 'indices': [145, 159]}, {'text': 'BlackTwitter', 'indices': [160, 173]}]
#  [{'url': 'https://t.co/QoxSH63Pgb', 'expanded_url': 'http://isitjust.us', 'display_url': 'isitjust.us', 'indices': [0, 23]}, {'url': 'https://t.co/2FBWttDw0j', 'expanded_url': 'http://twib.in/l/48a4M9MEqpk5', 'display_url': 'twib.in/l/48a4M9MEqpk5', 'indices': [105, 128]}]
# not a retweet
# https://t.co/QoxSH63Pgb Nationwide “Rent Strike”: Would You Use Your Last To Pay Rent Or Buy Essentials? https://t.co/2FBWttDw0j #GrowingUpBlack #2Black2Strong #BlackTwitter https://t.co/lPyGD36m5M
# -----------------------
# 2020-05-03 11:54:16
#  bensa25341463
#  India
#  [{'text': 'BlueTwitter', 'indices': [58, 70]}, {'text': 'BlackTwitter', 'indices': [75, 88]}, {'text': 'AyezaKhan', 'indices': [105, 115]}, {'text': 'ArtiSingh', 'indices': [116, 126]}]
#  []
# I don't care if it's there or not
#
# Doing #BlueTwitter and #BlackTwitter again for them
#
# #AyezaKhan
# #ArtiSingh
# #ShilpaShinde
# Bonus:-#RashamiDesai https://t.co/twtfOCS65u
# -----------------------
# 2020-05-03 11:27:34
#  DesaiClub
#  New Delhi
#  [{'text': 'BlueTwitter', 'indices': [58, 70]}, {'text': 'BlackTwitter', 'indices': [75, 88]}, {'text': 'AyezaKhan', 'indices': [105, 115]}, {'text': 'ArtiSingh', 'indices': [116, 126]}]
#  []
# I don't care if it's there or not
#
# Doing #BlueTwitter and #BlackTwitter again for them
#
# #AyezaKhan
# #ArtiSingh
# #ShilpaShinde
# Bonus:-#RashamiDesai https://t.co/twtfOCS65u
# -----------------------
# 2020-05-03 11:26:16
#  Rashami_Is_Love
#  Ahmadabad City, India
#  [{'text': 'BlueTwitter', 'indices': [58, 70]}, {'text': 'BlackTwitter', 'indices': [75, 88]}, {'text': 'AyezaKhan', 'indices': [105, 115]}, {'text': 'ArtiSingh', 'indices': [116, 126]}]
#  []
# I don't care if it's there or not
#
# Doing #BlueTwitter and #BlackTwitter again for them
#
# #AyezaKhan
# #ArtiSingh
# #ShilpaShinde
# Bonus:-#RashamiDesai https://t.co/twtfOCS65u
# -----------------------
# 2020-05-03 11:13:28
#  kailovesu
#  Love Land, USA
#  [{'text': 'VERZUZ', 'indices': [3, 10]}, {'text': 'bananapudding', 'indices': [45, 59]}, {'text': 'peachcobbler', 'indices': [63, 76]}, {'text': 'sundaydinner', 'indices': [81, 94]}, {'text': 'SundayThoughts', 'indices': [125, 140]}, {'text': 'desserts', 'indices': [141, 150]}, {'text': 'sweettooth', 'indices': [151, 162]}, {'text': 'BlackTwitter', 'indices': [189, 202]}, {'text': 'yummy', 'indices': [203, 209]}]
#  []
# not a retweet
# My #VERZUZ battle for today is should I make #bananapudding or #peachcobbler for #sundaydinner? This is tough! What say you? #SundayThoughts #desserts #sweettooth @Timbaland @THEREALSWIZZZ #BlackTwitter #yummy @piscespodcast https://t.co/nnuvAU1UdF
# -----------------------
# 2020-05-03 10:43:07
#  mmr04055
#
#  [{'text': 'BlackTwitter', 'indices': [135, 148]}]
#  []
# not a retweet
# instead of designs unique to ethnic group and region, or opportunities for textile expansion many African countries, you want it cheap #BlackTwitter need a better AGOA African Growth and Opportunity Act
# -----------------------
# 2020-05-03 10:13:37
#  RightBlackAtYou
#  via Mid-Atlantic/Southeast USA
#  [{'text': 'BlackTwitter', 'indices': [25, 38]}]
#  []
# Any #BlackTwitter on the public stage not willing to buckdance for @dnc massa will ultimately be called a grifter.  And those "I don't see color" liberals will attack them as their obedient black pets defend them and/or join the feeding frenzy. #FreeCandace #SaturdayThoughts
# -----------------------
# 2020-05-03 09:45:34
#  yuck_fou2
#  Pakistan
#  [{'text': 'BlackTwitter', 'indices': [17, 30]}]
#  []
# #BlackTwitter
# Government is still unsure whether to cancel the exams or not, like come on decide already its May! Students are confused they don't know what to do.
# In these times more confusion is not what we need. So raise your voices!
# #CallOffBoardExams
# @ImranKhanPTI https://t.co/bJNRGwU7Zc
# -----------------------
# 2020-05-03 09:36:46
#  saif_hadia
#
#  [{'text': 'BlackTwitter', 'indices': [17, 30]}]
#  []
# #BlackTwitter
# Government is still unsure whether to cancel the exams or not, like come on decide already its May! Students are confused they don't know what to do.
# In these times more confusion is not what we need. So raise your voices!
# #CallOffBoardExams
# @ImranKhanPTI https://t.co/bJNRGwU7Zc
# -----------------------
# 2020-05-03 09:33:51
#  nayab_baig_
#
#  [{'text': 'BlackTwitter', 'indices': [0, 13]}, {'text': 'CallOffBoardExams', 'indices': [237, 255]}]
#  []
# not a retweet
# #BlackTwitter
# Government is still unsure whether to cancel the exams or not, like come on decide already its May! Students are confused they don't know what to do.
# In these times more confusion is not what we need. So raise your voices!
# #CallOffBoardExams
# @ImranKhanPTI https://t.co/bJNRGwU7Zc
# -----------------------
# 2020-05-03 09:32:03
#  XAABBASI
#
#  [{'text': 'power', 'indices': [56, 62]}, {'text': 'horse', 'indices': [63, 69]}, {'text': 'photography', 'indices': [71, 83]}, {'text': 'BlackTwitter', 'indices': [85, 98]}]
#  []
# not a retweet
# This world is a jungle you either fight or run forever! #power #horse  #photography  #BlackTwitter https://t.co/YcVrnaXUUg
# -----------------------
# 2020-05-03 09:23:48
#  Or_sunayen
#
#  [{'text': 'BlackTwitter', 'indices': [33, 46]}]
#  []
# not a retweet
# I forgot to put on my black mask #BlackTwitter https://t.co/clTws9LbVc
# -----------------------
# 2020-05-03 09:01:50
#  JohnWil60163557
#  South Africa
#  [{'text': 'Blacktwitter', 'indices': [3, 16]}, {'text': 'Blacktwitter', 'indices': [73, 86]}]
#  [{'url': 'https://t.co/APJkSi3mWq', 'expanded_url': 'https://twitter.com/mphokarabo/status/1256836604930506752', 'display_url': 'twitter.com/mphokarabo/sta…', 'indices': [272, 295]}]
# not a retweet
# If #Blacktwitter wants to accuse me of being superior with pleasure.
# If #Blacktwitter wants to accuse me or me forefathers of land theft it's their stupidity.
# Robert Mugabe was supposedly educated look what happened.
# When you sick will you go2 @DlaminiZuma 4 treatment? https://t.co/APJkSi3mWq
# -----------------------
# 2020-05-03 08:52:59
#  RanaSuhaibPhoto
#  Islamabad
#  [{'text': 'BlackTwitter', 'indices': [64, 77]}]
#  []
# not a retweet
# Okay i don't have full black jet or heli.
# Pak Army🇵🇰✌️ Bell 412
# #BlackTwitter https://t.co/qeEwDp6FqR
# -----------------------
# 2020-05-03 08:17:39
#  SasTrendy
#
#  [{'text': 'Pennsylvania', 'indices': [0, 13]}, {'text': 'BlackTwitter', 'indices': [14, 27]}]
#  []
# not a retweet
# #Pennsylvania #BlackTwitter I think this is why they are keeping people in halfway house against their home plans for the next 2 weeks they can't go to work, I'm not sure if it's all or just a specific one here in Lackawanna county. Doesn't seem right! Can't get black people to.. https://t.co/NZhyLNTvov
# -----------------------
# 2020-05-03 07:49:22
#  Biggbos29775144
#
#  [{'text': 'BlueTwitter', 'indices': [60, 72]}, {'text': 'BlackTwitter', 'indices': [77, 90]}, {'text': 'AyezaKhan', 'indices': [107, 117]}, {'text': 'ArtiSingh', 'indices': [118, 128]}]
#  []
# I don't care if it's there or not
#
# Doing #BlueTwitter and #BlackTwitter again for them
#
# #AyezaKhan
# #ArtiSingh
# #ShilpaShinde
# Bonus:-#RashamiDesai https://t.co/twtfOCS65u
# -----------------------
# 2020-05-03 07:40:01
#  Vivian_Taabu
#  Kenya
#  [{'text': 'KOT', 'indices': [139, 143]}, {'text': 'BlackTwitter', 'indices': [144, 157]}]
#  []
# not a retweet
# Did you know that the first people to inhabit ASIA 20000 years ago, were Black people?
# And not Chinese, Koreans, Japanese or Philippines??
# #KOT #BlackTwitter
# -----------------------
# 2020-05-03 07:07:55
#  AliGond11701840
#  سرگودھا, پاکستان
#  []
#  []
# Vlog-2 Today 2, May, 2020|| 8 Ramadan you have been seen the streets and markets of Rawalpindi city in lock-down. And you can easily analyze people are following lock-down or not.
#
# https://t.co/nL2Fgr6cvP
#
# #BlackTwitter
# #CallOffBoardExams
# #SundayThoughts
# -----------------------
# 2020-05-03 06:47:25
#  UrTakreem
#  pind dadan khan
#  [{'text': 'MaAn', 'indices': [48, 53]}, {'text': 'BlackTwitter', 'indices': [57, 70]}, {'text': 'Pakistan', 'indices': [72, 81]}]
#  []
# not a retweet
# Identity is small or big
#
# Should be your own �
#
# #MaAn���
# #BlackTwitter
# #Pakistan https://t.co/kh2sNGYCjd
# -----------------------
# 2020-05-03 06:44:56
#  Malikwajahad
#  Islamabad
#  [{'text': 'BlackTwitter', 'indices': [207, 220]}, {'text': 'CallOffBoardExams', 'indices': [222, 240]}, {'text': 'SundayThoughts', 'indices': [242, 257]}]
#  [{'url': 'https://t.co/nL2Fgr6cvP', 'expanded_url': 'https://youtu.be/89zB595zRsU', 'display_url': 'youtu.be/89zB595zRsU', 'indices': [181, 204]}]
# not a retweet
# Vlog-2 Today 2, May, 2020|| 8 Ramadan you have been seen the streets and markets of Rawalpindi city in lock-down. And you can easily analyze people are following lock-down or not.
#
# https://t.co/nL2Fgr6cvP
#
# #BlackTwitter
# #CallOffBoardExams
# #SundayThoughts
# -----------------------
# 2020-05-03 06:33:54
#  TheRealQuay_1
#  Paris, TX
#  [{'text': 'BlackTwitter', 'indices': [124, 137]}]
#  []
# If black people invested more in stocks, bonds, Treasurys hell anything we would be much further along #BlackTwitter
# Your free stock is waiting for you! Join Robinhood and we'll both get a stock like Apple, Ford, or Facebook for free. Sign up with my link. https://t.co/1qE2z8pOES https://t.co/U9ssagX311
# -----------------------
# 2020-05-03 06:21:06
#  AikAamSaLarka
#  Pune, India
#  [{'text': 'BlueTwitter', 'indices': [41, 53]}, {'text': 'BlackTwitter', 'indices': [58, 71]}, {'text': 'AyezaKhan', 'indices': [88, 98]}, {'text': 'ArtiSingh', 'indices': [99, 109]}, {'text': 'ShilpaShinde', 'indices': [110, 123]}, {'text': 'RashamiDesai', 'indices': [131, 144]}]
#  []
# not a retweet
# I don't care if it's there or not
#
# Doing #BlueTwitter and #BlackTwitter again for them
#
# #AyezaKhan
# #ArtiSingh
# #ShilpaShinde
# Bonus:-#RashamiDesai https://t.co/twtfOCS65u
# -----------------------
# 2020-05-03 05:56:23
#  baritoneblogger
#  Seattle, WA
#  [{'text': 'BlackTwitter', 'indices': [9, 22]}]
#  []
# not a retweet
# Wherever #BlackTwitter is at, I’m looking for a skin care routine to get rid of razor bumps and skin darkening. I might as well start a routine in quarantine. Who has got tips or something they swear by?
# -----------------------
# 2020-05-03 05:47:09
#  mr__ragsdale
#  Dallas, TX
#  [{'text': 'IAmGettingSoTiredOf', 'indices': [0, 20]}, {'text': 'BlackTwitter', 'indices': [250, 263]}]
#  []
# not a retweet
# #IAmGettingSoTiredOf TikTok being the playground for cultural appropriation. Some of you illiterate mfs can’t even spell Black but insist on inserting yourself into the culture. Leave us alone and go steal something else BESIDES people... or culture #BlackTwitter
# -----------------------
# 2020-05-03 05:39:00
#  SBBExpo
#
#  [{'text': 'BlackExcellence', 'indices': [89, 105]}, {'text': 'BlackTwitter', 'indices': [106, 119]}]
#  [{'url': 'https://t.co/QYgXH4rGS9', 'expanded_url': 'https://bit.ly/2NI40FU', 'display_url': 'bit.ly/2NI40FU', 'indices': [65, 88]}]
# Naughty or Nice: To Spank or Not to Spank - https://t.co/QYgXH4rGS9 #BlackExcellence #BlackTwitter #SupportBlackBusiness https://t.co/9kePUnKrub
# -----------------------
# 2020-05-03 05:32:01
#  BlackParenting1
#  Los Angeles, CA
#  [{'text': 'BlackExcellence', 'indices': [68, 84]}, {'text': 'BlackTwitter', 'indices': [85, 98]}, {'text': 'SupportBlackBusiness', 'indices': [99, 120]}]
#  [{'url': 'https://t.co/QYgXH4rGS9', 'expanded_url': 'https://bit.ly/2NI40FU', 'display_url': 'bit.ly/2NI40FU', 'indices': [44, 67]}]
# not a retweet
# Naughty or Nice: To Spank or Not to Spank - https://t.co/QYgXH4rGS9 #BlackExcellence #BlackTwitter #SupportBlackBusiness https://t.co/9kePUnKrub
# -----------------------
# 2020-05-03 05:30:53
#  KemalistGymcel
#  New Jersey, USA
#  [{'text': 'BlackTwitter', 'indices': [67, 80]}]
#  []
# not a retweet
# @gsc_mak @dankvanna @CR7sBase @goodideahaver @REZZY4PREZZY Calling #BlackTwitter like its the avengers or some shit https://t.co/4QcfDCsusA
# -----------------------
# 2020-05-03 05:25:15
#  DoughboyLA
#
#  [{'text': 'BlackTwitter', 'indices': [124, 137]}]
#  []
# If black people invested more in stocks, bonds, Treasurys hell anything we would be much further along #BlackTwitter
# Your free stock is waiting for you! Join Robinhood and we'll both get a stock like Apple, Ford, or Facebook for free. Sign up with my link. https://t.co/1qE2z8pOES https://t.co/U9ssagX311
# -----------------------
# 2020-05-03 05:25:13
#  DarnellFriedman
#
#  [{'text': 'BlackTwitter', 'indices': [124, 137]}]
#  []
# If black people invested more in stocks, bonds, Treasurys hell anything we would be much further along #BlackTwitter
# Your free stock is waiting for you! Join Robinhood and we'll both get a stock like Apple, Ford, or Facebook for free. Sign up with my link. https://t.co/1qE2z8pOES https://t.co/U9ssagX311
# -----------------------
# 2020-05-03 05:25:08
#  MobSquadDF
#
#  [{'text': 'BlackTwitter', 'indices': [124, 137]}]
#  []
# If black people invested more in stocks, bonds, Treasurys hell anything we would be much further along #BlackTwitter
# Your free stock is waiting for you! Join Robinhood and we'll both get a stock like Apple, Ford, or Facebook for free. Sign up with my link. https://t.co/1qE2z8pOES https://t.co/U9ssagX311
# -----------------------
# 2020-05-03 05:20:01
#  MarcelleImhotep
#
#  [{'text': 'BlackTwitter', 'indices': [103, 116]}]
#  [{'url': 'https://t.co/1qE2z8pOES', 'expanded_url': 'http://join.robinhood.com/marcels13', 'display_url': 'join.robinhood.com/marcels13', 'indices': [257, 280]}]
# not a retweet
# If black people invested more in stocks, bonds, Treasurys hell anything we would be much further along #BlackTwitter
# Your free stock is waiting for you! Join Robinhood and we'll both get a stock like Apple, Ford, or Facebook for free. Sign up with my link. https://t.co/1qE2z8pOES https://t.co/U9ssagX311
# -----------------------
# 2020-05-03 04:53:09
#  haIoface
#  mn • 22 • she/they
#  []
#  []
# Hey everyone!! I just officially published my lil shopify website! Yay! I would appreciate it so much if y’all supported my dreams of eventually self-publishing my poetry, by purchasing some of my pieces or rting❤️
#
# Just a tiny black gal trying to become big 🙌🏾
#
# #BlackTwitter https://t.co/OZgSPHdFy1
# -----------------------
# 2020-05-03 04:50:08
#  BlackPressRadio
#  Washington, DC in the USA
#  [{'text': 'KNICKS', 'indices': [42, 49]}, {'text': 'TheLastDance', 'indices': [105, 118]}, {'text': 'PatrickEwing', 'indices': [239, 252]}, {'text': 'BlackTwitter', 'indices': [253, 266]}, {'text': 'LebronJames', 'indices': [267, 279]}]
#  []
# not a retweet
# &gt;&gt;&gt; TRIGGER WARNING &lt;&lt;&lt; #KNICKS FANS want to remind you NOT to call us BEFORE or AFTER #TheLastDance
# Do not come for me because We gonna be in our feelings all day with a plastic bat to beat the pillows on May 3, 2020!  #PatrickEwing #BlackTwitter #LebronJames https://t.co/m6uivjaviM
# -----------------------
# 2020-05-03 04:38:52
#  xBl3ssdx
#  Richmond, VA
#  [{'text': 'BlackTwitter', 'indices': [34, 47]}]
#  [{'url': 'https://t.co/Vc1dHsnbvu', 'expanded_url': 'https://twitter.com/hnnnnnnnggggggg/status/1256799377101815809', 'display_url': 'twitter.com/hnnnnnnngggggg…', 'indices': [112, 135]}]
# not a retweet
# I need explanations for this also #BlackTwitter Is this her redemption or we just ain’t got time for it today 🤔 https://t.co/Vc1dHsnbvu https://t.co/tgpA6kt0md
# -----------------------
# 2020-05-03 03:22:27
#  blackpeopledata
#  Global
#  [{'text': 'BlackExcellence', 'indices': [75, 91]}, {'text': 'BlackTwitter', 'indices': [92, 105]}, {'text': 'SupportBlackBusiness', 'indices': [106, 127]}]
#  [{'url': 'https://t.co/oz4DRGOX0q', 'expanded_url': 'https://bit.ly/2NsDlwv', 'display_url': 'bit.ly/2NsDlwv', 'indices': [51, 74]}]
# Is Screen Time Bad or Good? - https://t.co/oz4DRGOX0q #BlackExcellence #BlackTwitter #SupportBlackBusiness
# -----------------------
# 2020-05-03 02:43:55
#  uniqueloves
#  paypal.me/uniqueloves
#  [{'text': 'BlackExcellence', 'indices': [75, 91]}, {'text': 'BlackTwitter', 'indices': [92, 105]}, {'text': 'SupportBlackBusiness', 'indices': [106, 127]}]
#  [{'url': 'https://t.co/oz4DRGOX0q', 'expanded_url': 'https://bit.ly/2NsDlwv', 'display_url': 'bit.ly/2NsDlwv', 'indices': [51, 74]}]
# Is Screen Time Bad or Good? - https://t.co/oz4DRGOX0q #BlackExcellence #BlackTwitter #SupportBlackBusiness
# -----------------------
# 2020-05-03 02:38:54
#  SBBExpo
#
#  [{'text': 'BlackExcellence', 'indices': [75, 91]}, {'text': 'BlackTwitter', 'indices': [92, 105]}, {'text': 'SupportBlackBusiness', 'indices': [106, 127]}]
#  [{'url': 'https://t.co/oz4DRGOX0q', 'expanded_url': 'https://bit.ly/2NsDlwv', 'display_url': 'bit.ly/2NsDlwv', 'indices': [51, 74]}]
# Is Screen Time Bad or Good? - https://t.co/oz4DRGOX0q #BlackExcellence #BlackTwitter #SupportBlackBusiness
# -----------------------
# 2020-05-03 02:31:45
#  BlackParenting1
#  Los Angeles, CA
#  [{'text': 'BlackExcellence', 'indices': [54, 70]}, {'text': 'BlackTwitter', 'indices': [71, 84]}, {'text': 'SupportBlackBusiness', 'indices': [85, 106]}]
#  [{'url': 'https://t.co/oz4DRGOX0q', 'expanded_url': 'https://bit.ly/2NsDlwv', 'display_url': 'bit.ly/2NsDlwv', 'indices': [30, 53]}]
# not a retweet
# Is Screen Time Bad or Good? - https://t.co/oz4DRGOX0q #BlackExcellence #BlackTwitter #SupportBlackBusiness
# -----------------------
# 2020-05-03 01:28:24
#  sacelov3
#
#  [{'text': 'BlackTwitter', 'indices': [36, 49]}]
#  []
# Am I tripping or...🥴?
# #BlackTwitter https://t.co/yXlpUMaAAZ
# -----------------------
# 2020-05-03 00:39:14
#  SBBExpo
#
#  [{'text': 'BlackExcellence', 'indices': [96, 112]}, {'text': 'BlackTwitter', 'indices': [113, 126]}]
#  [{'url': 'https://t.co/flVtsy8ypd', 'expanded_url': 'https://bit.ly/34ztco8', 'display_url': 'bit.ly/34ztco8', 'indices': [72, 95]}]
# If Your Child Is In 1st or 2nd Grade, Read This! - https://t.co/flVtsy8ypd #BlackExcellence #BlackTwitter #SupportBlackBusiness https://t.co/Pk4hNpckwb
# -----------------------
# 2020-05-03 00:38:07
#  directornola
#  South Korea
#  [{'text': 'businesstwitter', 'indices': [113, 129]}, {'text': 'facemasks', 'indices': [130, 140]}, {'text': 'subscription', 'indices': [141, 154]}, {'text': 'BlackTwitter', 'indices': [155, 168]}]
#  []
# not a retweet
# Would you subscribe to a subscription service that sent you 5~6 face mask or other hygiene products every month? #businesstwitter #facemasks #subscription #BlackTwitter https://t.co/j84OeuXy6b
# ...
# -----------------------
# 2020-04-26 12:50:26
#  S0odSaheb10
#  Himachal Pradesh, India
#  [{'text': 'tag', 'indices': [58, 62]}, {'text': 'BlueTwitter', 'indices': [72, 84]}, {'text': 'BlackTwitter', 'indices': [88, 101]}]
#  []
# not a retweet
# @tinkerbell9958 One more question 🙋
# .
# Is car wale bhai ka #tag kya hoga
# #BlueTwitter or #BlackTwitter 😁
# -----------------------
# 2020-04-26 12:34:51
#  Kuznets26174168
#
#  [{'text': 'RET', 'indices': [184, 188]}, {'text': 'BlackTwitter', 'indices': [192, 205]}]
#  []
# not a retweet
# @aleoniea @goss_spg @La_Revolucion11 @KhethaMabaso3 @makumbi_k2 @SipJeroh99 @IamMosiuwaK @Mafatlhaneng @LandDilemma @LandNoli @KingShaka79 @Hloksie7 when you write the twee start with #RET or #BlackTwitter or @LandNoli they have a lot of woke followers. all you do is write those wordings including mine which is @Kuznets26174168 then we will immediately get all you post
# -----------------------
# 2020-04-26 11:33:34
#  joanhelena0
#
#  []
#  []
# Drop your cashtag or paypal, i am sending 100 peoples $500 today to make his/her day. RT &amp; follow me to win valid for next 24 hours #Giveaway #COVID19 #sugar #BlackTwitter #UKlockdown #usaCoronavirus https://t.co/FfV1GezbS4
# -----------------------
# 2020-04-26 11:05:33
#  NJCU4C
#  New Jersey, USA
#  [{'text': 'judasgoats', 'indices': [66, 77]}, {'text': 'blacktwitter', 'indices': [170, 183]}, {'text': 'StayHome', 'indices': [184, 193]}]
#  []
# not a retweet
# @jamalhbryant on @cnn Brother Let them know!!! We ain’t following #judasgoats blacks won’t be lab rats or the canary in the coal mine for big business and the government #blacktwitter #StayHome
# -----------------------
# 2020-04-26 10:38:53
#  SBBExpo
#
#  [{'text': 'BlackExcellence', 'indices': [75, 91]}, {'text': 'BlackTwitter', 'indices': [92, 105]}, {'text': 'SupportBlackBusiness', 'indices': [106, 127]}]
#  [{'url': 'https://t.co/oz4DRGOX0q', 'expanded_url': 'https://bit.ly/2NsDlwv', 'display_url': 'bit.ly/2NsDlwv', 'indices': [51, 74]}]
# Is Screen Time Bad or Good? - https://t.co/oz4DRGOX0q #BlackExcellence #BlackTwitter #SupportBlackBusiness
# -----------------------
# 2020-04-26 10:34:47
#  bboportal
#  Chicago, IL
#  [{'text': 'BlackExcellence', 'indices': [75, 91]}, {'text': 'BlackTwitter', 'indices': [92, 105]}, {'text': 'SupportBlackBusiness', 'indices': [106, 127]}]
#  [{'url': 'https://t.co/oz4DRGOX0q', 'expanded_url': 'https://bit.ly/2NsDlwv', 'display_url': 'bit.ly/2NsDlwv', 'indices': [51, 74]}]
# Is Screen Time Bad or Good? - https://t.co/oz4DRGOX0q #BlackExcellence #BlackTwitter #SupportBlackBusiness
# -----------------------
# 2020-04-26 10:34:40
#  Fadolistic
#
#  [{'text': 'BlackExcellence', 'indices': [75, 91]}, {'text': 'BlackTwitter', 'indices': [92, 105]}, {'text': 'SupportBlackBusiness', 'indices': [106, 127]}]
#  [{'url': 'https://t.co/oz4DRGOX0q', 'expanded_url': 'https://bit.ly/2NsDlwv', 'display_url': 'bit.ly/2NsDlwv', 'indices': [51, 74]}]
# Is Screen Time Bad or Good? - https://t.co/oz4DRGOX0q #BlackExcellence #BlackTwitter #SupportBlackBusiness
# -----------------------
# 2020-04-26 10:32:08
#  BlackParenting1
#  Los Angeles, CA
#  [{'text': 'BlackExcellence', 'indices': [54, 70]}, {'text': 'BlackTwitter', 'indices': [71, 84]}, {'text': 'SupportBlackBusiness', 'indices': [85, 106]}]
#  [{'url': 'https://t.co/oz4DRGOX0q', 'expanded_url': 'https://bit.ly/2NsDlwv', 'display_url': 'bit.ly/2NsDlwv', 'indices': [30, 53]}]
# not a retweet
# Is Screen Time Bad or Good? - https://t.co/oz4DRGOX0q #BlackExcellence #BlackTwitter #SupportBlackBusiness
# -----------------------
# 2020-04-26 10:00:05
#  lisaluvv12
#
#  [{'text': 'BlackExcellence', 'indices': [111, 127]}]
#  [{'url': 'https://t.co/bgPaAAGQKm', 'expanded_url': 'https://bit.ly/2LzlnGc', 'display_url': 'bit.ly/2LzlnGc', 'indices': [87, 110]}]
# If Your Child Is In Pre-K or Kindergarten, Read This Right Now! - https://t.co/bgPaAAGQKm #BlackExcellence #BlackTwitter #SupportBlackBusiness https://t.co/eisgqRn7Oy
# -----------------------
# 2020-04-26 09:42:50
#  steveharhar
#  home
#  [{'text': 'BlackTwitter', 'indices': [19, 32]}, {'text': 'blcktweet', 'indices': [33, 43]}]
#  []
# #BlackTwitter #blcktweet
#
# Can’t wait till we notify your school or leak your address.💕 https://t.co/FT9XwOPtDi
# -----------------------
# 2020-04-26 08:39:24
#  SBBExpo
#
#  [{'text': 'BlackExcellence', 'indices': [96, 112]}, {'text': 'BlackTwitter', 'indices': [113, 126]}]
#  [{'url': 'https://t.co/flVtsy8ypd', 'expanded_url': 'https://bit.ly/34ztco8', 'display_url': 'bit.ly/34ztco8', 'indices': [72, 95]}]
# If Your Child Is In 1st or 2nd Grade, Read This! - https://t.co/flVtsy8ypd #BlackExcellence #BlackTwitter #SupportBlackBusiness https://t.co/r2Z6aG3fM7
# -----------------------
# 2020-04-26 08:39:07
#  SBBExpo
#
#  [{'text': 'BlackExcellence', 'indices': [111, 127]}]
#  [{'url': 'https://t.co/bgPaAAGQKm', 'expanded_url': 'https://bit.ly/2LzlnGc', 'display_url': 'bit.ly/2LzlnGc', 'indices': [87, 110]}]
# If Your Child Is In Pre-K or Kindergarten, Read This Right Now! - https://t.co/bgPaAAGQKm #BlackExcellence #BlackTwitter #SupportBlackBusiness https://t.co/eisgqRn7Oy
# -----------------------
# 2020-04-26 08:17:56
#  BlackParenting1
#  Los Angeles, CA
#  [{'text': 'BlackExcellence', 'indices': [90, 106]}, {'text': 'BlackTwitter', 'indices': [107, 120]}, {'text': 'SupportBlackBusiness', 'indices': [121, 142]}]
#  [{'url': 'https://t.co/bgPaAAGQKm', 'expanded_url': 'https://bit.ly/2LzlnGc', 'display_url': 'bit.ly/2LzlnGc', 'indices': [66, 89]}]
# not a retweet
# If Your Child Is In Pre-K or Kindergarten, Read This Right Now! - https://t.co/bgPaAAGQKm #BlackExcellence #BlackTwitter #SupportBlackBusiness https://t.co/eisgqRn7Oy
# -----------------------
# 2020-04-26 07:42:03
#  Tanishaevonne
#  Pittsburgh, PA
#  [{'text': 'BlackTwitter', 'indices': [23, 36]}]
#  []
# not a retweet
# Y'all really abuse the #BlackTwitter hashtag
# Don't ruin it to push your mix tape or sell your lashes
# 🤦🏾‍♀️🤦🏾‍♀️🤦🏾‍♀️
# -----------------------
# 2020-04-26 05:42:59
#  AboutThatTrash
#
#  [{'text': 'BlackTwitter', 'indices': [163, 176]}]
#  []
# not a retweet
# Update so as I’m watching I’m realizing that all the black songs are either shorten or cut. The whole movie is about integration so cutting it up ruins the movie. #BlackTwitter
# -----------------------
# 2020-04-26 04:12:41
#  joantsellers20
#  Charleston, S.C. U.S.A.
#  [{'text': 'negrophile4life', 'indices': [75, 91]}, {'text': 'BlackTwitter', 'indices': [92, 105]}, {'text': 'blackAF', 'indices': [106, 114]}, {'text': 'blessed', 'indices': [115, 123]}, {'text': 'blackculture', 'indices': [124, 137]}]
#  []
# I am that NEGRO not the Nigga or Nigger.
# I am a NEGRO! #negrophile4life #BlackTwitter #blackAF #blessed #blackculture 👍✌️❤️🌞😎☀️🌹🌸✊🌍💐👍✌️✊🌹😎 https://t.co/dOxMf92XR2
# -----------------------
# 2020-04-26 04:12:34
#  joantsellers20
#  Charleston, S.C. U.S.A.
#  [{'text': 'negrophile4life', 'indices': [55, 71]}, {'text': 'BlackTwitter', 'indices': [72, 85]}, {'text': 'blackAF', 'indices': [86, 94]}, {'text': 'blessed', 'indices': [95, 103]}, {'text': 'blackculture', 'indices': [104, 117]}]
#  []
# not a retweet
# I am that NEGRO not the Nigga or Nigger.
# I am a NEGRO! #negrophile4life #BlackTwitter #blackAF #blessed #blackculture 👍✌️❤️🌞😎☀️🌹🌸✊🌍💐👍✌️✊🌹😎 https://t.co/dOxMf92XR2
# -----------------------
# 2020-04-26 03:34:12
#  Alexand52792186
#
#  [{'text': 'blacktwitter', 'indices': [100, 113]}]
#  []
# not a retweet
# You bitches is weird bro. Just say that's ya friend or your favorite "big bro" and keep it pushing. #blacktwitter https://t.co/0nbfhJFKqj
# -----------------------
# 2020-04-26 03:05:19
#  ssiann1
#
#  [{'text': 'BlackTwitter', 'indices': [34, 47]}]
#  []
# not a retweet
# Is this a harmless “joke” or..... #BlackTwitter https://t.co/xh1zCvy3AD
# -----------------------
# 2020-04-26 02:38:10
#  pinkzebracross
#
#  [{'text': 'medtwitter', 'indices': [96, 107]}, {'text': 'nnveyy', 'indices': [108, 115]}, {'text': 'blacktwitter', 'indices': [116, 129]}, {'text': 'auspol', 'indices': [130, 137]}, {'text': 'bitcoin', 'indices': [138, 146]}]
#  [{'url': 'https://t.co/RWKrE5HeqY', 'expanded_url': 'https://twitter.com/chbstone2/status/1254169028039409667', 'display_url': 'twitter.com/chbstone2/stat…', 'indices': [147, 170]}]
# not a retweet
# More doctors must speak out the truth now, or let the destruction of humanity be on your hands.
# #medtwitter #nnveyy #blacktwitter #auspol #bitcoin https://t.co/RWKrE5HeqY
# -----------------------
# 2020-04-26 02:02:11
#  1sticksnstones2
#  Chicago, IL
#  [{'text': 'BlackTwitter', 'indices': [19, 32]}, {'text': 'blcktweet', 'indices': [33, 43]}]
#  []
# #BlackTwitter #blcktweet
#
# Can’t wait till we notify your school or leak your address.💕 https://t.co/FT9XwOPtDi
# -----------------------
# 2020-04-26 01:52:47
#  markarose231
#
#  [{'text': 'BlackTwitter', 'indices': [241, 254]}]
#  []
# not a retweet
# @txsmia @Jasmine_Wya @daxotaaa oh, so youre agreeing to do the same, name, school, location doxxing for every immigrant, terrorist, unseasoned food, school shooter joke you see? if not, wouldnt that be racist? we surely wouldnt want that or #BlackTwitter would be doxxing u next, oh wait.... that wouldnt happen
# -----------------------
# 2020-04-26 01:36:00
#  DextrousNinja
#  Spectral Extant
#  [{'text': 'BlackTwitter', 'indices': [39, 52]}, {'text': 'IndiaFlag', 'indices': [93, 103]}, {'text': 'JaiHind', 'indices': [164, 172]}, {'text': 'VandeMatram', 'indices': [173, 185]}, {'text': 'IndiaFirst', 'indices': [186, 197]}]
#  []
# not a retweet
# @dharmicverangna Forget About Black or #BlackTwitter
# Forget About good looking
#
# Important is #IndiaFlag...
#
# ... That TriColor Explains A Lot
# &amp; Burning Many...
#
# #JaiHind #VandeMatram #IndiaFirst
# -----------------------
# 2020-04-26 00:59:03
#  Alexand52792186
#
#  [{'text': 'blacktwitter', 'indices': [238, 251]}]
#  []
# not a retweet
# Broke mfers don't understand that they're fave celebrities &amp; entertainers are not part of the 1% they're conventionally wealthy some,  but they are employees..they don't have passive income or 1% money, power &amp; income flowing in. #blacktwitter
# -----------------------
# 2020-04-26 00:44:30
#  CadaverTisement
#
#  [{'text': 'BlackTwitter', 'indices': [174, 187]}, {'text': 'BlackPeople', 'indices': [188, 200]}, {'text': 'blackpeopletwitter', 'indices': [201, 220]}]
#  []
# not a retweet
# Anyone else wondering what Deebo went to jail for in Friday?
#
# He just got his ass whooped why they arrest dude? Did @icecube or Pops leave the gun on him?
#
# @christuckerreal
#
# #BlackTwitter #BlackPeople #blackpeopletwitter https://t.co/ksfwpnlpqW
# -----------------------
# 2020-04-26 00:31:58
#  KashKash7650
#  NJ/NC
#  [{'text': 'Knowledge', 'indices': [8, 18]}, {'text': 'SaturdayThoughts', 'indices': [53, 70]}, {'text': 'BlackTwitter', 'indices': [71, 84]}, {'text': 'COVID19', 'indices': [85, 93]}, {'text': 'NWO', 'indices': [94, 98]}, {'text': 'StayWoke', 'indices': [99, 108]}, {'text': 'Truth', 'indices': [109, 115]}, {'text': 'SelfCare', 'indices': [116, 125]}]
#  [{'url': 'https://t.co/2fIkHxL4TU', 'expanded_url': 'https://youtu.be/KJVRx3Agfo8', 'display_url': 'youtu.be/KJVRx3Agfo8', 'indices': [202, 225]}]
# not a retweet
# Consume #Knowledge or be consumed by ignorance 🤷🏿‍♀️
# #SaturdayThoughts #BlackTwitter #COVID19 #NWO #StayWoke #Truth #SelfCare
# (Is the New World Order upon us?) Unselfish Behavior Podcast | EP #35 wi... https://t.co/2fIkHxL4TU via @YouTube
# -----------------------
# 2020-04-25 23:26:49
#  AngelThaSinger
#  Kansas City, MO
#  [{'text': 'BlackTwitter', 'indices': [8, 21]}]
#  []
# not a retweet
# Alright #BlackTwitter. Let’s settle this once and for all.
#
# Is ROTEL considered a Meal, a Side or just an Appetizer?  Tell me why in the comments.
#
# Annnnnnd GO! 🤣
# -----------------------
# 2020-04-25 22:55:01
#  AlexisChisolm1
#
#  [{'text': 'blacktwitter', 'indices': [73, 86]}]
#  []
# Why is my mom such a fucking nigger I mean nagger srry #blacktwitter I didn't mean to say nigger I mean black or whatever I should call y'all no nvm I meant darkies or y'all porch monkeys but yea love y'all tree swinging niggers I mean blacks my fault #whitetwitter help
# -----------------------
# 2020-04-25 19:56:14
#  TahrisJ
#
#  [{'text': 'BlackTwitter', 'indices': [230, 243]}, {'text': 'dilligaf', 'indices': [244, 253]}]
#  []
# not a retweet
# Hoes Think shit funny with these racist ass videos till they get kick outta school...Jumped... or just caught lacking in the streets😂Yea what’s gone be funny is them knots and rejection letters from your dream college 😂😂‼️BITCH😝🖕🏾#BlackTwitter #dilligaf
# -----------------------
# 2020-04-25 17:32:01
#  BlackParenting1
#  Los Angeles, CA
#  [{'text': 'BlackExcellence', 'indices': [68, 84]}, {'text': 'BlackTwitter', 'indices': [85, 98]}, {'text': 'SupportBlackBusiness', 'indices': [99, 120]}]
#  [{'url': 'https://t.co/QYgXH4rGS9', 'expanded_url': 'https://bit.ly/2NI40FU', 'display_url': 'bit.ly/2NI40FU', 'indices': [44, 67]}]
# not a retweet
# Naughty or Nice: To Spank or Not to Spank - https://t.co/QYgXH4rGS9 #BlackExcellence #BlackTwitter #SupportBlackBusiness https://t.co/0TM3GjgMy2
# -----------------------
# 2020-04-25 16:53:04
#  msdarlingdiva
#  BIRMINGHAM,AL
#  [{'text': 'BlackTwitter', 'indices': [95, 108]}]
#  []
# not a retweet
# Ok serious question which was the best album @Usher Confessions or @DruHill4Real Enter the Dru #BlackTwitter
# -----------------------
# 2020-04-25 14:55:22
#  FatherTheblack
#
#  [{'text': 'Blackmen', 'indices': [128, 137]}, {'text': 'advice', 'indices': [138, 145]}, {'text': 'blackwomen', 'indices': [146, 157]}, {'text': 'BlackTwitter', 'indices': [158, 171]}, {'text': 'netflixandchill', 'indices': [172, 188]}, {'text': 'blackness', 'indices': [189, 199]}, {'text': 'word', 'indices': [200, 205]}, {'text': 'blackfathers', 'indices': [206, 219]}, {'text': 'blacldad', 'indices': [220, 229]}, {'text': 'realtalk', 'indices': [230, 239]}, {'text': 'love', 'indices': [240, 245]}, {'text': 'SaturdayThoughts', 'indices': [246, 263]}, {'text': 'saturday', 'indices': [264, 273]}]
#  []
# not a retweet
# Son: always always never skeet in a woman no matter if she says she’s on the pill or can’t get pregnant...👌🏿💪🏿✊🏿🚶🏿‍♂️🚶🏿‍♂️🚶🏿‍♂️ #Blackmen #advice #blackwomen #BlackTwitter #netflixandchill #blackness #word #blackfathers #blacldad #realtalk #love #SaturdayThoughts #saturday
# -----------------------
# 2020-04-25 14:46:45
#  blackpeopledata
#  Global
#  [{'text': 'BlackExcellence', 'indices': [75, 91]}, {'text': 'BlackTwitter', 'indices': [92, 105]}, {'text': 'SupportBlackBusiness', 'indices': [106, 127]}]
#  [{'url': 'https://t.co/oz4DRGOX0q', 'expanded_url': 'https://bit.ly/2NsDlwv', 'display_url': 'bit.ly/2NsDlwv', 'indices': [51, 74]}]
# Is Screen Time Bad or Good? - https://t.co/oz4DRGOX0q #BlackExcellence #BlackTwitter #SupportBlackBusiness
# -----------------------
# 2020-04-25 14:38:59
#  SBBExpo
#
#  [{'text': 'BlackExcellence', 'indices': [75, 91]}, {'text': 'BlackTwitter', 'indices': [92, 105]}, {'text': 'SupportBlackBusiness', 'indices': [106, 127]}]
#  [{'url': 'https://t.co/oz4DRGOX0q', 'expanded_url': 'https://bit.ly/2NsDlwv', 'display_url': 'bit.ly/2NsDlwv', 'indices': [51, 74]}]
# Is Screen Time Bad or Good? - https://t.co/oz4DRGOX0q #BlackExcellence #BlackTwitter #SupportBlackBusiness
# -----------------------
# 2020-04-25 14:37:15
#  Alexand52792186
#
#  [{'text': 'blacktwitter', 'indices': [191, 204]}]
#  []
# not a retweet
# Let's not pretend like girls don't be out here saying men ain't shit before even having a actual relationship or expirence dating &amp; be bitter by 17 after 1-2 niggas she let in her life.. #blacktwitter https://t.co/sQnV1fJd5r
# -----------------------
# 2020-04-25 14:31:59
#  BlackParenting1
#  Los Angeles, CA
#  [{'text': 'BlackExcellence', 'indices': [54, 70]}, {'text': 'BlackTwitter', 'indices': [71, 84]}, {'text': 'SupportBlackBusiness', 'indices': [85, 106]}]
#  [{'url': 'https://t.co/oz4DRGOX0q', 'expanded_url': 'https://bit.ly/2NsDlwv', 'display_url': 'bit.ly/2NsDlwv', 'indices': [30, 53]}]
# not a retweet
# Is Screen Time Bad or Good? - https://t.co/oz4DRGOX0q #BlackExcellence #BlackTwitter #SupportBlackBusiness
# -----------------------

# %%
#This code block will pull the pieces of tweet information that I want and store them in a dataframe.

def pull_tweets(mydate): #"yyyy-mm-dd"
    tweets_df = pd.DataFrame(columns = ['tw_id','date', 'user', 'location', 'hashtags', 'urls', 'text'] )

    # how many tweets to pull at a time
    pull_cadence = 2000 
    # keep track of how many tweets have been pulled
    cnter = 0 
    twt_cnt =0

    for i in list(range(1,30)): 
            print(i)
            tweets = tweepy.Cursor(api.search,q="#blacktwitter or #BlackTwitter or #blackTwitter or #Blacktwitter",
                                   count=pull_cadence,
                                   lang="en",
                                   tweet_mode='extended',
                                   since=mydate, include_rts=False).items()
            for tweet in tweets:

                tw_id = tweet.id
                date = tweet.created_at 
                user = tweet.user.screen_name
                location = tweet.user.location
                hashtags = tweet.entities['hashtags']
                urls = tweet.entities['urls']
                try:
                    text = tweet.retweeted_status.full_text
                except:  # Not a Retweet
                    #print("not a retweet")
                    try:
                        text = tweet.full_text
                    except:
                        text = tweet.text

                # Clean up some of the Fields
                hashtags = [t['text'] for t in hashtags ]

                # Save the results to a list and append to data frame
                tweet_lst = [tw_id, date, user, location, hashtags, urls, text]
                row1 = pd.Series(tweet_lst, index = tweets_df.columns)
                tweets_df = tweets_df.append(row1, ignore_index=True)

                # keep track of how many tweets have been pulled
                #cnter +=1
            twt_cnt = pull_cadence * i 
            print(twt_cnt)

            # wait 1minutes to continue pulling so twitter won't boot us out
            time.sleep(1*60)
            
    return(tweets_df)

# %%
tweets_df4 = pull_tweets("2020-05-03")


tweets_df = pull_tweets("2020-04-25")
tweets_df2 = pull_tweets("2020-05-04") # came back and pulled this a few days later after a major new event had occurred

#tweets_df2 ran for 5/4/20 to morning of 5/7/20
#tweets_df ran for 4/25/20 to morning of 5/3/20
#tweets_df4 ran for 5/3/20 to morning of 5/10/20

#tweets_df4.to_csv("BlackTwitter_Tweets_df4.csv")
#tweets_df.to_csv("BlackTwitter_Tweets_df.csv")
#tweets_df2.to_csv("BlackTwitter_Tweets_df2.csv")
# Out:
# 1
# 2000
# 2
# 4000
# 3
# 6000
# 4
# 8000
# 5
# 10000
# 6
# 12000
# 7
# 14000
# 8
# 16000
# 9
# 18000
# 10
# 20000
# 11
# 22000
# 12
# 24000
# 13
# 26000
# 14
# 28000
# 15
# 30000
# 16
# 32000
# 17
# 34000
# 18
# 36000
# 19
# 38000
# 20
# 40000
# 21
# 42000
# 22
# 44000
# 23
# 46000
# 24
# 48000
# 25
# 50000
# 26
# 52000
# 27
# 54000
# 28
# 56000
# 29
# 58000

# %%
print(len(tweets_df4))
print(len(tweets_df4.tw_id.unique()))
print(len(tweets_df4.text.unique()))
print(tweets_df4.date.min())
print(tweets_df4.date.max())
tweets_df4.head()

# %%
tweets_df = pd.read_csv("BlackTwitter_Tweets_df.csv")
tweets_df2 = pd.read_csv("BlackTwitter_Tweets_df2.csv")
tweets_df4 = pd.read_csv("BlackTwitter_Tweets_df4.csv")
print(len(tweets_df))
print(len(tweets_df2))
print(len(tweets_df4))
# Out:
# 14944
# 5356
# 17643

# %%
tweets_df4.iloc[:,2:]
# Out:
#                       date             user         location  \
# 0      2020-05-10 01:24:34         LITzy933              NaN
# 1      2020-05-10 01:23:10        afrogarm_  London, England
# 2      2020-05-10 00:57:58       JV10883156              NaN
# 3      2020-05-10 00:10:10  Allforthatgayn1              NaN
# 4      2020-05-09 23:45:06       baitSpeech               UK
# ...                    ...              ...              ...
# 17638  2020-05-03 00:39:14          SBBExpo              NaN
# 17639  2020-05-03 00:38:07     directornola      South Korea
# 17640  2020-05-03 00:36:50         apkimble              NaN
# 17641  2020-05-03 00:16:52  BlackParenting1  Los Angeles, CA
# 17642  2020-05-03 00:01:48  BlackParenting1  Los Angeles, CA
#
#                                                 hashtags  \
# 0                                                     []
# 1                                       ['BlackTwitter']
# 2                                       ['BlackTwitter']
# 3                   ['tiktok', 'BlackTwitter', 'racist']
# 4                              ['blackTwitter', 'hotep']
# ...                                                  ...
# 17638                ['BlackExcellence', 'BlackTwitter']
# 17639  ['businesstwitter', 'facemasks', 'subscription...
# 17640                ['BlackExcellence', 'BlackTwitter']
# 17641  ['BlackExcellence', 'BlackTwitter', 'SupportBl...
# 17642  ['BlackExcellence', 'BlackTwitter', 'SupportBl...
#
#                                                     urls  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 17638  [{'url': 'https://t.co/flVtsy8ypd', 'expanded_...
# 17639                                                 []
# 17640  [{'url': 'https://t.co/flVtsy8ypd', 'expanded_...
# 17641  [{'url': 'https://t.co/bgPaAAGQKm', 'expanded_...
# 17642  [{'url': 'https://t.co/flVtsy8ypd', 'expanded_...
#
#                                                     text
# 0      My name is Shadae and I’m a freelance model in...
# 1      #BlackTwitter thank you for making sure I don’...
# 2      #BlackTwitter thank you for making sure I don’...
# 3      #tiktok #BlackTwitter #racist ATTENTION TWITTE...
# 4      Is the same thing happening in your country #b...
# ...                                                  ...
# 17638  If Your Child Is In 1st or 2nd Grade, Read Thi...
# 17639  Would you subscribe to a subscription service ...
# 17640  If Your Child Is In 1st or 2nd Grade, Read Thi...
# 17641  If Your Child Is In Pre-K or Kindergarten, Rea...
# 17642  If Your Child Is In 1st or 2nd Grade, Read Thi...
#
# [17643 rows x 6 columns]

# %%
df = tweets_df.iloc[:,1:].append(tweets_df2.iloc[:,1:], ignore_index=True)
print(len(df))
df = df.append(tweets_df4.iloc[:,2:], ignore_index=True)
print(len(df))
print(df.date.min())
print(df.date.max())
df
# Out:
# 20300
# 37943
# 2020-04-25 14:31:59
# 2020-05-10 02:35:42
#                       date             user                        location  \
# 0      2020-05-04 00:42:36    cheema_noor29                        Pakistan
# 1      2020-05-04 00:26:05    szadususufzai  غنی خان دے کلی#Islamia college
# 2      2020-05-04 00:22:18   hassan_sayss__                Lahore, Pakistan
# 3      2020-05-04 00:16:18         mnakkhan           🇵🇰#PTIMemberSince1999
# 4      2020-05-04 00:09:44        sadidasss               Karachi, Pakistan
# ...                    ...              ...                             ...
# 37938  2020-05-03 00:39:14          SBBExpo                             NaN
# 37939  2020-05-03 00:38:07     directornola                     South Korea
# 37940  2020-05-03 00:36:50         apkimble                             NaN
# 37941  2020-05-03 00:16:52  BlackParenting1                 Los Angeles, CA
# 37942  2020-05-03 00:01:48  BlackParenting1                 Los Angeles, CA
#
#                                                 hashtags  \
# 0                                       ['BlackTwitter']
# 1                                       ['BlackTwitter']
# 2                         ['BlackTwitter', 'RedTwitter']
# 3                                                     []
# 4                                       ['BlackTwitter']
# ...                                                  ...
# 37938                ['BlackExcellence', 'BlackTwitter']
# 37939  ['businesstwitter', 'facemasks', 'subscription...
# 37940                ['BlackExcellence', 'BlackTwitter']
# 37941  ['BlackExcellence', 'BlackTwitter', 'SupportBl...
# 37942  ['BlackExcellence', 'BlackTwitter', 'SupportBl...
#
#                                                     urls  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 37938  [{'url': 'https://t.co/flVtsy8ypd', 'expanded_...
# 37939                                                 []
# 37940  [{'url': 'https://t.co/flVtsy8ypd', 'expanded_...
# 37941  [{'url': 'https://t.co/bgPaAAGQKm', 'expanded_...
# 37942  [{'url': 'https://t.co/flVtsy8ypd', 'expanded_...
#
#                                                     text
# 0      "I have lived as plain Mr. Jinnah and I hope t...
# 1      #BlackTwitter For there is no Black as beautif...
# 2      Did someone say #BlackTwitter or maybe #RedTwi...
# 3      I asked an old man: Which is more important. [...
# 4      yes or no?\n #BlackTwitter https://t.co/8HiIqy...
# ...                                                  ...
# 37938  If Your Child Is In 1st or 2nd Grade, Read Thi...
# 37939  Would you subscribe to a subscription service ...
# 37940  If Your Child Is In 1st or 2nd Grade, Read Thi...
# 37941  If Your Child Is In Pre-K or Kindergarten, Rea...
# 37942  If Your Child Is In 1st or 2nd Grade, Read Thi...
#
# [37943 rows x 6 columns]

# %%
#use pd.options to display the full length of the text without truncating
pd.options.display.max_colwidth = 300
df.text[19920:]
# Out:
# 19920    Count me in @KFCSA ... if Phillet was White or Indian, #BlackTwitter &amp; Political farts would be tearing SA down. Call a Black person a monkey or the K word &amp; you are vilified but it’s OK for Blacks to go around wanting death &amp; calling others monkeys &amp; we just over look this? http...
# 19921                                                                “At the foundation of civilization is the melanated mind,  just about everything you see around you was either inspired by, invented by, or originated by a Black man or woman." #BlackHistory #BlackTwitter #BlackNews https://t.co/Ehm7pumm56
# 19922                          🤔"Go Back To Africa"\nIF every African-bred person in the 🗺 did return to the continent (on the cavet that all non-POCS abandoned Africa) to establish or support all black nations, I wonder how long before the 1st World Race War would break out?\n#BlackTwitter #blackgaytwitter
# 19923                    See how that #DoubleStandard  works? #BlueLivesMatter  = You must comply with the officers commands, right or wrong just so long as you're not white. Don't you treat us like black people right? #whiteprivilege and #WhiteSupremacy in a nutshell.  #BlackTwitter https://t.co/NDBQlqHo8M
# 19924                                                                                       Is it just me Or are there other Black people out there who lose their sh*t everytime a Black person wins anything??!!\n  Listening to all that Blackness win Pultizers yesterday just about took me out \n#BlackTwitter
#                                                                                                                                                             ...
# 37938                                                                                                                                                        If Your Child Is In 1st or 2nd Grade, Read This! - https://t.co/flVtsy8ypd #BlackExcellence #BlackTwitter #SupportBlackBusiness https://t.co/Pk4hNpckwb
# 37939                                                                                                               Would you subscribe to a subscription service that sent you 5~6 face mask or other hygiene products every month? #businesstwitter #facemasks #subscription #BlackTwitter https://t.co/j84OeuXy6b
# 37940                                                                                                                                                        If Your Child Is In 1st or 2nd Grade, Read This! - https://t.co/flVtsy8ypd #BlackExcellence #BlackTwitter #SupportBlackBusiness https://t.co/Pk4hNpckwb
# 37941                                                                                                                                         If Your Child Is In Pre-K or Kindergarten, Read This Right Now! - https://t.co/bgPaAAGQKm #BlackExcellence #BlackTwitter #SupportBlackBusiness https://t.co/mRHNmk3iAy
# 37942                                                                                                                                                        If Your Child Is In 1st or 2nd Grade, Read This! - https://t.co/flVtsy8ypd #BlackExcellence #BlackTwitter #SupportBlackBusiness https://t.co/Pk4hNpckwb
# Name: text, Length: 18023, dtype: object

# %% [markdown]
# # <font color="orange"> Clean the data <font/>

# %%
import re

import gensim
from gensim import corpora, models
from gensim.parsing.preprocessing import STOPWORDS

import nltk 
from nltk import word_tokenize, pos_tag
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Clean up the text

# %%
mylist = []
def clean_up_fun(data):
    
    for index, row in enumerate(data):

        ttext= str(row)
        #to lowercase
        ttext= ttext.lower()
        #remove numeric characters
        ttext = re.sub(r'\d*','', ttext)        
        
        #tokenize the data by whitespace
        tokens = nltk.tokenize.WhitespaceTokenizer().tokenize(ttext)
      
        #remove hashtag tokens (search tokens that start with hashtag)
        tokens = [t for t in tokens if not re.search('^#', t) ]
        #remove url tokens (search tokens that start with https)
        tokens = [t for t in tokens if not re.search('^https', t) ]
        #remove @ tokens (search tokens that start with @)
        tokens = [t for t in tokens if not re.search('^@', t) ]
        #remove periods, commas, exclamations
        #tokens = [re.sub("[\.,!:?/\[\]*]", '', t) for t in tokens]
        
        # join the tokens back into a string so when do non alphabet function can re-tokenize and get clean tokens
        ttext = " ".join(tokens)
        #remove all non-alphabet characters from string
        regex = re.compile('[^a-z]')
        ttext = regex.sub(' ', ttext)
        
        #tokenize the data by whitespace
        tokens = nltk.tokenize.WhitespaceTokenizer().tokenize(ttext)
        #get rid of amp
        tokens = [t for t in tokens if not t == "amp"]

        #lemmatize text**********

        def get_wordnet_pos(word):
            """Map POS tag to first character lemmatize() accepts"""
            tag = nltk.pos_tag([word])[0][1][0].upper()
            tag_dict = {"J": wordnet.ADJ,
                       "N" : wordnet.NOUN,
                       "V" : wordnet.VERB,
                       "R" : wordnet.ADV}
            return tag_dict.get(tag, wordnet.NOUN)
        try:
            tokens = [WordNetLemmatizer().lemmatize(word, get_wordnet_pos(word)) for word in tokens]
        except:
            print("no lemma")
        #*************

        #remove stop words and words less than 3 characters; right now I'm going to keep in stopwords
        #tokens = [w for w in tokens if len(w)>2]
        tokens = [w for w in tokens if not w in gensim.parsing.preprocessing.STOPWORDS and len(w) > 2]

        
        mylist.append([index, tokens])
        
    return(mylist)

mylist = clean_up_fun(df.text)

# %%
text_df = pd.DataFrame(mylist, columns= ["indx", "clean_text"])

# %%
#reunite the cleaned text with the other fields from the original data frame
text_df2 = pd.merge(df, text_df, left_index=True, right_on="indx").drop("indx", axis=1)

# %% [markdown]
# Once we have cleaned data in a frame, wanted to make sure I removed duplicates. The orginal data frame was 20300, but dropping duplicates in the text column resulted in just 509 remaining tweets.
#
# Dropping duplicates on text and date resulted in 1011 remaining tweets.
#
# I'm not that familiar with how twitter works, but in general is it just retweeting the same things? Or is the method of pulling in the tweets the reason that yielded so many duplicates? I'm not really sure, but proper methodology of pulling tweets is beyond the scope of this analysis. However, 500 tweets is not many to make a robust analysis.

# %%
print(len(text_df2))
text_df2 = text_df2.drop_duplicates(["text"])
print(len(text_df2))
text_df2.iloc[:,:6].tail(10)
# Out:
# 611
# 611
#              date             user                   location  \
# 20597  2020-05-06     1naturalzeta                        NaN
# 20598  2020-05-06   MissionaryBLMM  🇺🇸ConstitutionProtected💻🌏
# 20605  2020-05-06  BlackPressRadio                        USA
# 20739  2020-05-04    PanAfricology            South Africa 🇿🇦
# 20792  2020-05-03          SkSteev   Toronto, Ontario, Canada
# 20830  2020-05-03        Khosahere                   Pakistan
# 20860  2020-05-03     Mrizkhan1987                   Pakistan
# 20861  2020-05-03      Mrizkhan001                   Pakistan
# 20874  2020-05-03    PanAfricology            South Africa 🇿🇦
# 20889  2020-05-03  trinitywhite_14                        NaN
#
#                                                                                                                                                                                                               hashtags  \
# 20597                                                                                                                                                                                     ['LetitiaJames', 'DeBlasio']
# 20598                                                                                                                                                                            ['End', 'BLMLawsuit', 'BlackTwitter']
# 20605                                                                                  ['ArrestTheMayor', 'BillDeBlasio', 'NYCMayor', 'Homeless', 'homelesscantstayhome', 'HomelessFraud', 'NYCMayor', 'BlackTwitter']
# 20739  ['Chinese', 'China', 'ChinaLiedPeopleDied', 'WHO', 'lockdown', 'ChinaMustPay', 'Africansinchina', 'BritishAmericanTobacco', 'VaalTwitter', 'sabcnews', 'day39oflockdown', 'Vaal', 'BlackChina', 'BlackTwitter']
# 20792                                                                                                                                                                                                 ['BlackTwitter']
# 20830                                                                                                                                                                                                 ['BlackTwitter']
# 20860                                                                                                                                                                                                 ['BlackTwitter']
# 20861                                                                                                                                                                                                 ['BlackTwitter']
# 20874                                                                                                             ['Chinese', 'China', 'Nigerians', 'SouthAfricans', 'ProfLumumba', 'AfricansInChina', 'BlackTwitter']
# 20889                                                                                                                                                         ['BlackTwitter', 'BlackLivesMatter', 'racism', 'racist']
#
#       urls  \
# 20597   []
# 20598   []
# 20605   []
# 20739   []
# 20792   []
# 20830   []
# 20860   []
# 20861   []
# 20874   []
# 20889   []
#
#                                                                                                                                                                                                                                                                                                               text
# 20597  BREAKING NEWS: NY State Atty Gen #LetitiaJames MUST ARREST #DeBlasio or be recalled from her position. It's her job to ARREST THE MAYOR! If she doesn't she can be RECALLED. They intentionally kept NY open and it's causing the entire country to suffer. #BlackTwitter @NYCCouncil https://t.co/BbsgM...
# 20598  @SpeakerPelosi #End BlackLivesMatter© Copyright Infringement\n#BLMLawsuit\n#BlackTwitter @NBA @NFL @MLB\nIF YOU GAVE💰TO #BLM ORGS, WEBSITES, @StateDept @UN GROUPS OR @BLMAtSchool FRAUD; ..LARCENY occurred!🚔\nTheir #GlobalNetwork IS IN DELAWARE! @BIDEN\n&amp; I REQUEST, YOUR MONEY BE RETURNED To ...
# 20605  FAILURE TO PROTECT: NYC FAILED to close ALL BRIDGES and TUNNELS in NYC and TEST ERRRRRRBODY or #ArrestTheMayor #BillDeBlasio @NYCMayorsOffice\n #NYCMayor STOLE $2.5 BILLION from #Homeless NYers #homelesscantstayhome  #HomelessFraud #NYCMayor \n@NYGovCuomo @NYCCouncil \n#BlackTwitter https://t.co...
# 20739  #Chinese are making food made with Crap. Be aware of what u eat if u go to #China or eat sonething made in China\n\n#ChinaLiedPeopleDied #WHO  #lockdown #ChinaMustPay #Africansinchina\n#BritishAmericanTobacco\n#VaalTwitter #sabcnews #day39oflockdown #Vaal #BlackChina #BlackTwitter https://t.co/R...
# 20792                                                                                                                                                @SkSteev Here comes #BlackTwitter to defend their lack of parenting skills or, failing that, prohibit others from critiquing them by pulling the racist card.
# 20830                                                                                                                                                                                                      I have black hair only. No black T shirt or kurta. Gareeb kinda\n #BlackTwitter https://t.co/ofnruJf82E
# 20860                                                                                                                                                Downfall of nations do not occur due to conspiracy or lack of wealth, rather it occurs because of their moral depravity.#BlackTwitter https://t.co/1OrN4CT0z9
# 20861                                                                                                                                                Downfall of nations do not occur due to conspiracy or lack of wealth, rather it occurs because of their moral depravity.#BlackTwitter https://t.co/kzUScNMFyb
# 20874                 “It is not our Tanzanian-ness or Angola-ness that matters. It is our African-ness...When the #Chinese terrorize us in #China they make no distinction between #Nigerians &amp; #SouthAfricans...all they see is our Black skin.” Prof Lumumba\n#ProfLumumba \n#AfricansInChina #BlackTwitter
# 20889                                                                                                                                                                                                      Sooooo can we cancel them or??? #BlackTwitter #BlackLivesMatter #racism #racist https://t.co/ChWEREAycd

# %% [markdown]
# Clean up locations. Upon first glance at the data, it looks like US, India, and Pakistan may be dominant locations so let's try to normalize the text for these to get better counts down the line

# %%
# check if a location ends with any of these strings. if so normalize it.
text_df2["location"] = [ "India" if re.search('india$', str(i).lower().strip()) else i for i in text_df2.location ]
text_df2["location"] = [ "Pakistan" if re.search('pakistan$', str(i).lower().strip()) else i for i in text_df2.location ]
text_df2["location"] = [ "USA" if re.search('usa$', str(i).lower().strip()) else i for i in text_df2.location ]
text_df2["location"] = [ "USA" if re.search('united states$', str(i).lower().strip()) else i for i in text_df2.location ]

# %%
text_df2.dtypes
# Out:
# date          object
# user          object
# location      object
# hashtags      object
# urls          object
# text          object
# clean_text    object
# dtype: object

# %%
from datetime import datetime

# %%
text_df2["date"] = pd.to_datetime(text_df2.date)

# %% [markdown]
# ## <font color ="blue"> Explore Data <font/>

# %% [markdown]
# Let's see how many tweets per day. Remove the timestamp from the date column

# %%
text_df2["date"] = text_df2["date"].dt.date

# %%
cnt = text_df2["date"].value_counts()
cnt.values

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(cnt.index,cnt.values, color="orange")
ax.set_ylabel("Number of Tweets")
plt.xticks(rotation=45)
plt.title("Tweets per Day")
plt.show()
# Out:
# /anaconda/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Look at word frequencies. Below we join the tokens in each row as a string into a list. Then we collapse the list into one big string. That way we can check out most frequent words and most frequent bigrams

# %%
#text needs to be in one big string to do ngrams
bigstring = " ".join([" ".join(i) for i in text_df2.clean_text ])

# %%
from nltk.util import ngrams
 
# Function to generate n-grams from sentences.
def extract_ngrams(data, num):
    n_grams = ngrams(nltk.word_tokenize(data), num)
    return [ ' '.join(grams) for grams in n_grams]

# %%
bgrams = extract_ngrams(bigstring,2)
freqBgrams = nltk.FreqDist(bgrams)
topBgrams = freqBgrams.most_common(20)

# %%
topBgrams
# Out:
# [('black people', 33),
#  ('naughty nice', 11),
#  ('nice spank', 11),
#  ('spank spank', 11),
#  ('black woman', 10),
#  ('child grade', 10),
#  ('grade read', 10),
#  ('child pre', 10),
#  ('pre kindergarten', 10),
#  ('kindergarten read', 10),
#  ('read right', 10),
#  ('social distance', 10),
#  ('black twitter', 9),
#  ('black man', 9),
#  ('wan na', 7),
#  ('williams chicken', 7),
#  ('american problem', 7),
#  ('demand justice', 7),
#  ('african american', 6),
#  ('social medium', 6)]

# %%
Onegrams = extract_ngrams(bigstring,1)
freqOnegrams = nltk.FreqDist(Onegrams)
topOnegrams = freqOnegrams.most_common(20)
topOnegrams
# Out:
# [('black', 216),
#  ('people', 101),
#  ('white', 73),
#  ('like', 70),
#  ('time', 38),
#  ('know', 37),
#  ('need', 35),
#  ('child', 35),
#  ('want', 35),
#  ('let', 31),
#  ('love', 30),
#  ('twitter', 29),
#  ('think', 29),
#  ('look', 28),
#  ('thing', 28),
#  ('right', 26),
#  ('start', 26),
#  ('woman', 26),
#  ('man', 25),
#  ('feel', 25)]

# %%
#What are the most frequent hashtags?
#one big string of hashtags
bighash = " ".join([re.sub("[-_\.,!:?/\[\]*']","", i).lower() for i in text_df2.hashtags ])

Onegrams = extract_ngrams(bighash,1)
freqOnegrams = nltk.FreqDist(Onegrams)
topOnegrams = freqOnegrams.most_common(30)
topOnegrams
# Out:
# [('blacktwitter', 528),
#  ('blackexcellence', 36),
#  ('covid19', 24),
#  ('blacklivesmatter', 22),
#  ('bluetwitter', 12),
#  ('blackaf', 10),
#  ('black', 10),
#  ('ahmaudarbery', 10),
#  ('whiteprivilege', 9),
#  ('ados', 9),
#  ('supportblackbusiness', 8),
#  ('racism', 8),
#  ('blackpeople', 7),
#  ('justiceforahmaudarbery', 7),
#  ('blackgirlmagic', 6),
#  ('uk', 6),
#  ('france', 6),
#  ('germany', 6),
#  ('australia', 6),
#  ('canada', 6),
#  ('stayhome', 6),
#  ('blackwomen', 6),
#  ('racist', 6),
#  ('arrestthemnow', 6),
#  ('arrestthemallnow', 6),
#  ('redtwitter', 5),
#  ('covidー19', 5),
#  ('whitesupremacy', 5),
#  ('blm', 5),
#  ('covid', 5)]

# %%
# Import the wordcloud library
from wordcloud import WordCloud
# Join the different processed titles together.
#long_string = " ".join([" ".join(i) for i in text_df2.clean_text ])
# Create a WordCloud object
bighash1 = re.sub('blacktwitter','', bighash).strip()
#regex.sub(' ', ttext)
wordcloud = WordCloud(background_color="black", max_words=5000, contour_width=3, colormap='YlOrRd')
# Generate a word cloud
wordcloud.generate(bighash1)
# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1A28A83A58>

# %% [markdown]
# Where around the world are the tweets coming from?

# %%
[print(idx, i) for idx,i in zip(text_df2.location.value_counts().index, text_df2.location.value_counts())]
# Out:
# USA 51
# Pakistan 22
# India 21
# Global 15
# Los Angeles, CA 9
# southeastern michigan 6
# Worldwide  6
# Your girl house on y'all bed  6
# Chicago, IL 5
# Brooklyn, NY 4
# New York, NY 4
# Boundless 4
# Atlanta, GA 4
# South Africa 3
# England, United Kingdom 3
# Dallas, TX 3
# London, England 3
# NYC 3
# South Africa 🇿🇦 3
# Washington, DC 3
# Manhattan, NY 3
# Self Love via Self Awareness 3
# Nigeria 3
# Baltimore, MD 3
# CA 3
# Centurion, South Africa 2
# Seattle, WA 2
# mars 🍕⚽️🌈  2
# New York 2
# Kansas City, MO 2
# Philadelphia, PA 2
# 🙏मातृभूमि/ भारत🙏 USA. 2
# east905 Toronto 2
# Canada 2
# Ontario, Canada 2
# Dubai, United Arab Emirates 2
# OHIO 2
# Minneapolis, MN 2
# Everywhere 2
# Everywhere Online 2
# Manhattan 10040 2
# Birmingham, England 2
# Nashville, TN 2
# New Orleans, LA 2
#  420 2
# ʲᵘⁿᵍʷᵒᵒˢ ᵇʳᵃⁱⁿ 2
# Fort Llatikcuf AZ. I shit MAGA-turds even more than Donut Twitter donut holes. #StillWithHer McKinney 08/Stein 12/Stein 16 2
# Portland, Oregon 2
# Las Vegas, NV 2
# In My Black Skin & Breathing! 2
# Cape Town, South Africa 2
# Chicago 2
# Toronto, Ontario, Canada 1
# کراچی, پاکستان 1
# nowwhere 1
# اسلام آباد, پاکستان 1
# stealth 1
# 𝔸𝕟𝕚𝕞𝕖 𝕎𝕠𝕣𝕝𝕕 1
# krugerdorp,Pine Haven 1
# Charleston, S.C. U.S.A. 1
# La la land  1
# Beautiful Southern California 1
# Detroit Michigan  1
# Huntsville, Alabama 1
# नई दिल्ली, भारत 1
# Sydney, New South Wales 1
# London, UK 🏭 1
# 🇺🇸ConstitutionProtected💻🌏 1
# Austin, TX 1
# at the grave of my loving wife 1
# My  City!! 1
# JA, FL, DC, NY and counting 1
# سرگودھا, پاکستان 1
# غنی خان دے کلی#Islamia college 1
# Jamrock 1
# Bakersfield , CA 1
# Los Angeles AKA Love Allah 1
# Worldwide 1
# South Korea 1
# Allahabad-Noida-Chennai 1
# Planet Earth🌎 1
# Radio Land  1
# Baton Rouge, LA 1
# Spectral Extant 1
# 🌴☁✨ 916 1
# All Over The World 1
# Tennessee  1
# Travel 1
# Where I want to be. 1
# Montreal 1
# Florida 1
# whr am i?thats a good question 1
# Boise, ID 1
# Me hu he nahi is duniya ki 1
# san diego 1
# 95453 24533 67 https://www.paypal.me/enrgzz 1
# Atlanta, Georgia 1
# http://bit.ly/4kChecks 1
# Gullah Gullah Island ! ✈⛵ 1
# ✪ 1
# Vizag 1
# Qatar +974 31491000 whatsApp 1
# ADEYIPO VILLAGE,OYO,NIGERIA 1
# astéri 1
# Now 1
# خاکِ جاناں  1
# Washington DC  1
# Angola 1
# ERRWHERE 1
# UK 1
# Odendaalsrus/Rustenburg 🇿🇦 1
# Tennessee 1
# Dystopia 1
# San Diego, CA 1
# Lakshadweep 1
# Last Nerve, Boston, MA, World 1
# Punta Cana, Dominican Republic 1
# Earth  1
# Atlanta GA 1
# Toledo, OH 1
# kerala 1
# Follow me IG:Clermoninspires 1
# where everybody knows my name 1
# Omaha, NE 1
# City of Angels, The People's Republic of California 1
# Global Citizen 1
# SOME WHERE HELiCOPTERS GO 1
# South Pacific Paradise 1
# Mars, Space 1
# Iowa 1
# Pittsburgh, PA 1
# Mohali, chandigarh  1
# Phoenix AZ 1
# Always with Goddes re.ra.nut 1
# SteamEdinburgh 1
# Chicago ✈️ Toledo ✈️Iowa City 1
# sunflowerville 😊💆🏾🌻🆓 1
# Toronto, Ontario 1
# Pensacola, FL 1
# home 1
# Paris, TX 1
# Atlanta 1
# Delhi / London  1
# Afuraka_Afuraitkait soweto 1
# Harrisburg, Pa 1
# Virginia  1
# Taunton, MA 1
# NJ/NC 1
# Bryans Road, MD 1
# Miami, FL 1
# Midwest 1
# Atlanta/Nashville .  1
# Milwaukee, WI 1
# $thygeekgoddess 1
# Detroit, MI 1
# Earth 1
# Pretoria, South Africa 1
# City of Wind 1
# Fayetteville, NC 1
# Kenya 1
# BIRMINGHAM,AL 1
# South Africa,  1
# Harlem 1
# BookMe: tashyra@3twelvePR.com 1
# Maryland 1
# Italia 1
# Waukegan, IL 1
# Elon Musk's Penthouse  1
# Nottingham 1
# Wolverhampton, England 1
# London UK 1
# Y401SODAseedA\VenTOX!NATOR 1
# Palm Beach, Florida.  Atlanta  1
# DC 1
# CHAND PE HAI APUN 1
# Inglewood, CA 1
# Mad city 1
# Depression 1
# #DMV 1
# حیدر آباد, پاکستان 1
# Los Angeles, CA/ Atl 1
# bed 1
# merkato bete 1
# Southend-on-Sea, East 1
# everywhere  1
# 📍IL 1
# Thailand 1
# github.com/Xtremilicious 1
# Gaborone, Botswana 1
# Kelowna, British Columbia 1
# فیصل آباد، پنجاب، پاکستان 1
# Woodstown, NJ 1
# Phoenix, AZ 1
# Nerul, Navi Mumbai 1
# Dallas, TX/Houston, TX 📍 1
# World wide 1
# Avalon, NJ 1
# The Republic of Wakanda 1
# HARLEM, NY 1
# Jaipur 1
# historically intense south 1
# Wakanda 1
# layyah 1
# Brisbane, Queensland 1
# pind dadan khan 1
# Schleep. 1
# In a state of disbelief 1
# The high ground  1
# Singapore, Bangkok, Jakarta. 1
# New York, NY  1
# کیا ضرورت میرا ملک پاکستان ہے  1
# MS 1
# Islamabad 1
# United Kingdom 1
# Houston, TX 1
# Bowie, MD 1
# Richmond, VA 1
# Bronx, New York 1
# ILLINOIS 1
# 🇵🇰#PTIMemberSince1999 1
# Lala land 1
# महाराष्ट्र, भारत  1
# Islamabad  1
# Ontario, CA 1
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
cnt = text_df2["location"].value_counts()
cnt.values

#fig = plt.figure()
ax = plt.subplots(figsize=(20,5))
# the 1: is to get rid of the first observation, which has a high count for an empty label
# and only plotting the top third
plt.bar(cnt.index[1:round(len(cnt)/3)], cnt.values[1:round(len(cnt)/3)], color="green") 
plt.ylabel("Number of Tweets")
plt.xticks(rotation=75, size = 8)
plt.title("Number of Tweets by Location (Top third)")
plt.show()

# %% [markdown]
# Above we can see that the tweets are coming from a variety of places, across the US and around the world. Outside of the US, there seemed to be a good amount of tweets from India and Pakistan. I wonder why they would be using that hashtag.

# %%
text_df2[text_df2["location"] == "Pakistan"]
# looking at some of the Pakistan tweets, they're all over the place, from fashion to quotes of people, and self help to nonsensical
text_df2[text_df2["location"] == "India"]
#India also looks like it deals with clothes, but seems to have some awareness that this hashtag may be meant for a movement of black people
# Out:
#              date             user location  \
# 308    2020-04-30           rhtmjn    India
# 352    2020-04-29         Gautam25    India
# 353    2020-04-29  SouravS73745058    India
# 360    2020-04-29  Himansh21294150    India
# 391    2020-04-28    JeetOffIcial6    India
# 446    2020-04-28  barelyxhumorous    India
# 535    2020-04-27  thasaphotograph    India
# 556    2020-04-27         RS_dilli    India
# 576    2020-04-27     rituraj_prht    India
# 583    2020-04-27  munnachatterjee    India
# 595    2020-04-27         GENEABHI    India
# 638    2020-04-27     poornima2oct    India
# 639    2020-04-27     priyalpoddar    India
# 642    2020-04-27      BJoshibeena    India
# 649    2020-04-27   MuthuRangasamy    India
# 663    2020-04-27      itsmeAnu183    India
# 665    2020-04-27     sakshii_jain    India
# 675    2020-04-27     RahulSingh_I    India
# 678    2020-04-27        facts2507    India
# 680    2020-04-27    Bantish_bunny    India
# 20433  2020-05-08       kaizad3770    India
#
#                                                                                                                                                                 hashtags  \
# 308                                                                                                                                                     ['BlackTwitter']
# 352                                                                                                                                          ['Twitter', 'BlackTwitter']
# 353                                            ['IrrfanKhan', 'IrfanKhan', 'RIPIrrfanKhan', 'Legend', 'lunchbox', 'BlackTwitter', 'RIPLegend', 'Bollywood', 'RIPLegend']
# 360                                                                                                                                      ['BlueTwitter', 'BlackTwitter']
# 391                                                                                                                                       ['RedTwitter', 'BlackTwitter']
# 446                                                                                                                                      ['bluetwitter', 'blacktwitter']
# 535                                                                                                                                                                   []
# 556                                                                                                                             ['BlackTwitter', 'CagedBeautyWhatAPity']
# 576                                                                                                                                                     ['BlackTwitter']
# 583                                                                                                                                       ['BlackTwitter', 'ProfilePic']
# 595                                                                                                                                                     ['BlackTwitter']
# 638                                                                                                                                                     ['BlackTwitter']
# 639                                                                                                                                    ['blacktwitter', 'yellowtwitter']
# 642                                                                                                           ['black', 'BlackTwitter', 'goodmorning', 'mondaythoughts']
# 649                                                                                                                                                                   []
# 663                                                                                                                                                     ['BlackTwitter']
# 665                                                                                                                                                     ['BlackTwitter']
# 675                                                                                                                      ['BlueTwitter', 'BlackTwitter', 'SmileTwitter']
# 678    ['BlackTwitter', 'MondayMotivation', 'mondaythoughts', 'TharNeedsWater', 'TablighiJamaat', 'COVIDー19', 'COVID', 'follobackforfolloback', 'follotrick', 'follome']
# 680                                                                                                                                                     ['BlackTwitter']
# 20433                                                                                              ['AfricanAmericans', 'blacktwitter', 'antiblack', 'justiceforahmuad']
#
#                                                                                                                                                                                              urls  \
# 308                                                                                                                                                                                            []
# 352                                                                                                                                                                                            []
# 353                                                                                                                                                                                            []
# 360                                                                                                                                                                                            []
# 391                                                                                                                                                                                            []
# 446                                                                                                                                                                                            []
# 535                                             [{'url': 'https://t.co/LLPRM2WWQq', 'expanded_url': 'https://youtu.be/7N330vc6A3U', 'display_url': 'youtu.be/7N330vc6A3U', 'indices': [96, 119]}]
# 556                                                                                                                                                                                            []
# 576    [{'url': 'https://t.co/oOXVIW2gFb', 'expanded_url': 'https://twitter.com/saahilmenghani/status/1254768460153761797', 'display_url': 'twitter.com/saahilmenghani…', 'indices': [248, 271]}]
# 583                                                                                                                                                                                            []
# 595                                                                                                                                                                                            []
# 638                                                                                                                                                                                            []
# 639                                                                                                                                                                                            []
# 642                                                                                                                                                                                            []
# 649                                                               [{'url': 'https://t.co/YN1y23s66X', 'expanded_url': 'https://adylist.com/', 'display_url': 'adylist.com', 'indices': [73, 96]}]
# 663                                                                                                                                                                                            []
# 665                                                                                                                                                                                            []
# 675                                                                                                                                                                                            []
# 678                                                                                                                                                                                            []
# 680                                                                                                                                                                                            []
# 20433                                                                                                                                                                                          []
#
#                                                                                                                                                                                                                                                                                                               text  \
# 308                                                                                                                                                                                                                 What is black twitter? Is it a seperate app or a community on twitter? Pls help! #BlackTwitter
# 352                                                                  What's #Twitter and its founder's responsibility to control so much hatred being spread against mankind, religion using your platform. Should you not be looking into this or you are silently enjoying @TwitterSafety @Twitter #BlackTwitter
# 353                                                                                      #IrrfanKhan #IrfanKhan #RIPIrrfanKhan #Legend #lunchbox #BlackTwitter #RIPLegend #Bollywood He was meant to rule the acting industry in his 80's or 90's...but God had other plans.....#RIPLegend https://t.co/8BNFCw2uEk
# 360                                                                                                                                                                                                                 @AwanishSharan You are on top sir in every challenge whether #BlueTwitter or  #BlackTwitter 😊😊
# 391                                                                                                                                                                                                                                                                    What is it ? #RedTwitter OR #BlackTwitter ?
# 446                                                                                                                                 Millennial culture is trolling indian aunties for doing saree challenge on whatsapp while tweeting some shit with #bluetwitter or #blacktwitter\nWhat is this behaviour pooja?
# 535                                                Are you Really "Black" or "African American?"... Neither (Here's Why)  |... https://t.co/LLPRM2WWQq via @YouTube You are not Black. “Black” has no legal standing according to Blacks Law Dictionary. Can own no land, etc. #BlackTwitter #BlackTwitterMovement
# 556                                          Now #BlackTwitter ! Come on!! Narcissism during the highly stressful lockdown period is totally understandable. And it'd also help, perhaps. But why these lame excuses?? Just say  #CagedBeautyWhatAPity.. or something like that &amp; keep posting your pics!!! :)
# 576                            Just when I was thinking only about posting my #BlackTwitter entry as well, featuring @saahilmenghani again, he himself did it 😄🤘\n\nOur thinking ends where @saahilmenghani's starts 🙌\n\nBlack or Blue, @saahilmenghani is always the best. He is boss! 🙏 https://t.co/oOXVIW2gFb
# 583                                                                                                                                                                                                                                                  #BlackTwitter \nor #ProfilePic or.... https://t.co/TvYChOpKfj
# 595                                                                                                                                              Does this qualify for #BlackTwitter🖤 ?\nPS please ignore my not so smart looks focus on black colour or the map on the background. Hehehe https://t.co/mJPDEJTcbc
# 638                                                                                                                                                                    Because #BlackTwitter is trending....why don't you try...Anyway black is my favorite color whether suit or saree... https://t.co/JxMNhiL5xU
# 639                                                                                                                                                                                                                                          Now the question is should I go for #blacktwitter or #yellowtwitter 🤔
# 642                                                                                                                                                                                                                Any time #black day or night #BlackTwitter #goodmorning #mondaythoughts https://t.co/uBDXOIFn1I
# 649    BUY OR SELL USED SOFA\nONLY AT ADYLIST...!\n.\nVisit Website: https://t.co/YN1y23s66X\nor\nDownload The App Now: https://t.co/CU8bt7Ipzj\n.\n#adylist #buy #sell #used #secondhand #products #online #lockdownhustle #BlackTwitter #GoogleDoodle #K3TitleTrack #saffron #PMKcallsShutTASMACever https://...
# 663                                                                                            #BlackTwitter Sorry, I don’t like to wear black and I don’t like black clothes, in almost 39 years of my life, I have had 3 black clothes and I have put on black only just 7 or 8 times and I hate all those days.
# 665                                                                                                                                                                                I wish everyone can see life in either Black or White,  every other colour is overrated.  #BlackTwitter https://t.co/XKMyajimWV
# 675                                                                                                                                                                  Good morning! I don't have anything to contribute to #BlueTwitter or #BlackTwitter , but here's one for #SmileTwitter https://t.co/821kBby37t
# 678                         After 3 to 4 months of having a crush on someone, you either fall in love with that person or become interested in someone new.\n#BlackTwitter  #MondayMotivation  #mondaythoughts  #TharNeedsWater  #TablighiJamaat  #COVIDー19  #COVID  #follobackforfolloback  #follotrick  #follome
# 680                                                                                                                                     @Paprikaashh See the problem is not in Colors. It’s in how they are representing &amp; connecting it with religion or politics\n\nAt present #BlackTwitter is on its way 😂
# 20433                           @OurMayors #AfricanAmericans #blacktwitter #antiblack @BarackObama #justiceforahmuad  America will find a cure or vaccine for #coronavirus  but America will never find a vaccine to wipe out #racism. @CNN @WSJ @BBCWorld @BrunswickNews #Racism is a bigger disease than #corona
#
#                                                                                                                   clean_text
# 308                                                           [black, twitter, seperate, app, community, twitter, pls, help]
# 352              [founder, responsibility, control, hatred, spread, mankind, religion, use, platform, look, silently, enjoy]
# 353                                                                       [meant, rule, act, industry, god, plan, riplegend]
# 360                                                                                                         [sir, challenge]
# 391                                                                                                                       []
# 446                   [millennial, culture, troll, indian, aunty, saree, challenge, whatsapp, tweet, shit, behaviour, pooja]
# 535                             [black, african, american, black, black, legal, stand, accord, black, law, dictionary, land]
# 556    [come, narcissism, highly, stressful, lockdown, period, totally, understandable, help, lame, excuse, like, post, pic]
# 576                                                 [think, post, entry, feature, think, end, start, black, blue, best, bos]
# 583                                                                                                                       []
# 595                                            [qualify, ignore, smart, look, focus, black, colour, map, background, hehehe]
# 638                                                                        [trend, try, black, favorite, color, suit, saree]
# 639                                                                                                               [question]
# 642                                                                                                       [time, day, night]
# 649                                                           [buy, sell, use, sofa, adylist, visit, website, download, app]
# 663                     [sorry, like, wear, black, like, black, clothes, year, life, black, clothes, black, time, hate, day]
# 665                                                                             [wish, life, black, white, colour, overrate]
# 675                                                                                              [good, morning, contribute]
# 678                                                                      [month, crush, fall, love, person, interested, new]
# 680                                                   [problem, color, represent, connect, religion, politics, present, way]
# 20433                                                         [america, cure, vaccine, america, vaccine, wipe, big, disease]

# %% [markdown]
# ## <font color="red"> Getting an Idea of Overall Topics <font/>

# %%
# Import the wordcloud library
from wordcloud import WordCloud
# Join the different processed titles together.
long_string = " ".join([" ".join(i) for i in text_df2.clean_text ])
# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
# Generate a word cloud
wordcloud.generate(long_string)
# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1A29A21E10>

# %% [markdown]
# topic modelling may be inappropriate because of lack of data. Maybe we use tf-idf to get important words and embeddings to bring context to them. but is this data too small for embeddings as well. And what about just plain old clustering

# %% [markdown]
# ## Embeddings

# %%
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot

# %%
# train model
model = Word2Vec(text_df2.clean_text, min_count=1, size = 10, sg=1) #sg=1 is for skipgram, 0 is for CBOW

# %%
# fit a 2d PCA model to the vectors
X = model[model.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# create a scatter plot of the projection
fig = pyplot.figure( figsize=(18, 11))

pyplot.scatter(result[:, 0], result[:, 1])
words = list(model.wv.vocab)
for i, word in enumerate(words):
    pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %% [markdown]
# ## Hierarchical Clustering

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import scipy.cluster.hierarchy as shc

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# for each sentence (in our case work order text), from the set of sentences, word embeddings of each word is summed
# an in the end divided by the number of words in the sentence
# This is to get the average of all word embeddings in a sentence, so that we can have vector representations of the sentence
# that we can then use in our next algorithm

def sent_vectorizer(sent, model):
    sent_vec = []
    numw = 0
    for w in sent:
        try:
            if numw == 0:
                sent_vec = model[w]
            else:
                sent_vec = np.add(sent_vec, model[w])
            numw += 1
        except:
            pass
   
    return np.asarray(sent_vec) / numw

# %%
sent_embeddings = []
embedding_df = pd.DataFrame()
#for i in list(range(len(trade_lst))):
   
#for each work order, vectorize the sentences and if the vector isn't empty, add to s_embed list
s_embed = []
for sentence in list(text_df2["clean_text"]):
    s_vec = sent_vectorizer(sentence, model)
    if len(s_vec != 0):
        s_embed.append(s_vec)
    else:
        s_embed.append("NA")
   # once have run through every work order in a trade, add vectors for that trade to sent_embeddings list
##sent_embeddings.append(s_embed)
#embed_d = pd.merge(corpus_df[corpus_df["wo_trade_name"] == trade_lst[i]].reset_index().drop('index', axis=1),
 #                    pd.DataFrame(s_embed), left_index=True, right_index=True).dropna().reset_index(drop=True)
#embedding_df = embedding_df.append(embed_d)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:12: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if sys.path[0] == '':
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
#add the embeddings to data frame so can cohesively deal with tweets that don't have embeddings
text_df2["embeddings"] = s_embed
# remove the rows that have an NA for embeddings
text_df2 = text_df2[text_df2["embeddings"] != "NA"]

# %%
print(len(list(text_df2["clean_text"])))
print(len(s_embed))
list(text_df2["embeddings"])
# Out:
# 611
# 620
# [array([ 0.01517817, -0.01057257,  0.0079196 ,  0.01833173,  0.00771539,
#          0.01530175,  0.01186292, -0.00022983,  0.01345513, -0.00234156],
#        dtype=float32),
#  array([ 0.01016922, -0.00093052, -0.02539727,  0.01901639,  0.02482907,
#          0.01210195,  0.00745304, -0.00546444,  0.03222998, -0.00316815],
#        dtype=float32),
#  array([ 0.03717554, -0.04459179,  0.00093786,  0.01241294,  0.02789574,
#          0.04151504, -0.02691048,  0.02826664,  0.01596846,  0.02191466],
#        dtype=float32),
#  array([ 0.02453011, -0.02687245, -0.05033322,  0.04214034,  0.06631628,
#          0.01493156,  0.04316994, -0.02746585,  0.07341345, -0.01471106],
#        dtype=float32),
#  array([ 0.03443517,  0.01651835, -0.00996395,  0.05377489, -0.03238066,
#         -0.01793316, -0.03678505,  0.02996544,  0.04467662,  0.04540978],
#        dtype=float32),
#  array([ 0.03574994, -0.0049494 , -0.02170825,  0.03368957,  0.06321623,
#          0.00491108,  0.01446106, -0.00830363,  0.07369742, -0.01314476],
#        dtype=float32),
#  array([ 0.02876766, -0.01979692, -0.02369686,  0.04185418,  0.07219008,
#          0.00994714,  0.0070787 , -0.01253771,  0.06920341, -0.02379008],
#        dtype=float32),
#  array([ 0.022595  , -0.00813331, -0.00333145, -0.00420817,  0.01453847,
#          0.00827083,  0.01098852, -0.00835723,  0.00731137, -0.00354979],
#        dtype=float32),
#  array([ 0.02876586, -0.01090997,  0.00116833,  0.03152713,  0.03714029,
#          0.01619977,  0.00730216, -0.00964858,  0.05618157, -0.01961139],
#        dtype=float32),
#  array([ 0.00769958,  0.00419058, -0.01176717,  0.04620846,  0.04215509,
#          0.00867973,  0.00698397, -0.01231198,  0.07064925, -0.00576484],
#        dtype=float32),
#  array([ 0.00072721,  0.01304367,  0.04396329, -0.04622052,  0.00443112,
#          0.00835377, -0.00930468, -0.04275382, -0.01094121, -0.04706339],
#        dtype=float32),
#  array([ 0.07881615, -0.0343176 , -0.02311314,  0.04058526,  0.08579449,
#          0.02622419,  0.04077887, -0.01482268,  0.10644834, -0.04052762],
#        dtype=float32),
#  array([ 0.0127713 , -0.00580406, -0.02229378,  0.02453148,  0.03421538,
#          0.01616883,  0.02833161,  0.00718541,  0.04531517, -0.0184763 ],
#        dtype=float32),
#  array([ 0.02511625, -0.0066178 , -0.03179378,  0.03695168,  0.04449662,
#          0.01180221,  0.01827317,  0.00078761,  0.07638834, -0.02228846],
#        dtype=float32),
#  array([ 0.02658236, -0.00380032, -0.0345072 ,  0.03313774,  0.04799499,
#          0.0151082 ,  0.03111745, -0.01090069,  0.03452853, -0.01398623],
#        dtype=float32),
#  array([ 0.0305249 , -0.03270341, -0.02533047,  0.05201132,  0.03863252,
#          0.02145731,  0.02176645, -0.01010652,  0.06429598, -0.00389667],
#        dtype=float32),
#  array([-0.02588607, -0.04129764,  0.00673557,  0.03291151, -0.01880519,
#         -0.00105391, -0.01780401, -0.03405803, -0.02111054,  0.02611857],
#        dtype=float32),
#  array([ 0.05286561, -0.01870256, -0.02577273,  0.05477651,  0.0482284 ,
#         -0.01289381,  0.02476319, -0.02117283,  0.08930535, -0.03103533],
#        dtype=float32),
#  array([ 0.02883351, -0.0433707 , -0.03595468,  0.05239889,  0.04407696,
#          0.04173451,  0.02026122, -0.01471919,  0.0815187 , -0.00462862],
#        dtype=float32),
#  array([ 0.04592706, -0.01280899, -0.02340661,  0.07466849,  0.0688114 ,
#         -0.01806122,  0.02288746, -0.02886455,  0.08097909, -0.01038267],
#        dtype=float32),
#  array([ 0.10429756, -0.02372527, -0.01014638,  0.03237127,  0.13529429,
#          0.07240656,  0.00491042, -0.06638626,  0.07525378, -0.04937332],
#        dtype=float32),
#  array([ 0.0228579 , -0.01276147, -0.02677314,  0.04291015,  0.04026073,
#          0.01983215,  0.01150843, -0.00968615,  0.06983102, -0.00455864],
#        dtype=float32),
#  array([ 0.03288153, -0.00887573, -0.02482898,  0.03308144,  0.06944916,
#          0.01567715,  0.02672773, -0.00700047,  0.08093093, -0.02487068],
#        dtype=float32),
#  array([ 0.01067218, -0.01377535, -0.01897249,  0.02958583,  0.03084598,
#          0.00462375,  0.01927561, -0.00181798,  0.05004831, -0.00757661],
#        dtype=float32),
#  array([ 0.01690192,  0.00279593, -0.01226665,  0.00229788,  0.00910906,
#          0.01323883, -0.00291678, -0.01057192,  0.02365042, -0.00518412],
#        dtype=float32),
#  array([ 0.03834654, -0.01139749, -0.00467508,  0.03275437,  0.02731357,
#          0.01411679, -0.01329035, -0.00591815,  0.05314722,  0.0107354 ],
#        dtype=float32),
#  array([-0.0065872 , -0.01685779, -0.00383078,  0.00630086,  0.02699412,
#         -0.00087154, -0.01005192,  0.0033937 ,  0.02213181, -0.01472992],
#        dtype=float32),
#  array([ 0.02837241, -0.01962712, -0.01670755,  0.04328363,  0.04322421,
#          0.01730051,  0.01889431, -0.00917702,  0.06327865, -0.0173457 ],
#        dtype=float32),
#  array([ 0.03387921, -0.00475961, -0.00603646,  0.04244644,  0.03954505,
#          0.02082746,  0.00061447,  0.00553852,  0.07193424, -0.00672707],
#        dtype=float32),
#  array([ 0.0349266 , -0.03452349, -0.02691103,  0.03940735,  0.02990975,
#          0.03457117,  0.0370612 , -0.00445096,  0.06319779,  0.01155263],
#        dtype=float32),
#  array([ 0.02818149, -0.00286337, -0.02306443,  0.04600369,  0.04803273,
#          0.00499452,  0.02168349, -0.02321617,  0.08094003, -0.01400964],
#        dtype=float32),
#  array([ 0.0254696 , -0.00641432, -0.01281609,  0.0409643 ,  0.04820697,
#          0.02464537,  0.0282554 , -0.0044313 ,  0.05907908, -0.02032617],
#        dtype=float32),
#  array([ 0.00582496, -0.00835153, -0.01311965,  0.02416418,  0.01391195,
#          0.01889788,  0.00985544,  0.0034074 ,  0.05153472,  0.00472477],
#        dtype=float32),
#  array([ 0.16902626, -0.05411357, -0.13104771,  0.24057443,  0.25064397,
#          0.04803468,  0.07334536, -0.05229334,  0.35449332, -0.10021587],
#        dtype=float32),
#  array([-0.03221454, -0.03513326,  0.03894813,  0.02853375,  0.00678498,
#         -0.04406046,  0.01559187,  0.01549286,  0.02472692, -0.02824052],
#        dtype=float32),
#  array([ 0.00130163,  0.01128499,  0.00155381,  0.01509723,  0.01078661,
#          0.02055898, -0.01320857, -0.01099642,  0.01629161, -0.01426195],
#        dtype=float32),
#  array([ 0.02393612,  0.00471077, -0.02689571,  0.02422181,  0.04317051,
#          0.02129241,  0.01784514, -0.00731823,  0.06046401, -0.00535645],
#        dtype=float32),
#  array([ 0.04215661, -0.02522094, -0.02419612,  0.04538209,  0.06377836,
#          0.01863506,  0.01831886, -0.00268334,  0.09870744, -0.01940064],
#        dtype=float32),
#  array([ 0.00425489,  0.01581709, -0.02466352,  0.01838213,  0.01663153,
#          0.00442945,  0.00835425,  0.00643421,  0.04445263, -0.00220745],
#        dtype=float32),
#  array([ 0.00522873, -0.00671985, -0.00780752,  0.02834997,  0.02570431,
#          0.00579915,  0.02707716,  0.01623798,  0.03284834,  0.00645747],
#        dtype=float32),
#  array([ 0.01792334, -0.00224253, -0.01522085,  0.0317629 ,  0.03071925,
#          0.00866536,  0.02074078,  0.01833272,  0.04487588, -0.00191216],
#        dtype=float32),
#  array([ 0.03191335, -0.01684678, -0.03554395,  0.05657568,  0.06686153,
#          0.01669776,  0.0235526 , -0.00594446,  0.10113397, -0.01891694],
#        dtype=float32),
#  array([ 0.01263007, -0.00490387, -0.01651695,  0.03077859,  0.02421704,
#          0.01549985,  0.01085601, -0.00420608,  0.03330361, -0.00822675],
#        dtype=float32),
#  array([ 0.0303414 , -0.00067422, -0.01289083,  0.04976582,  0.05137855,
#          0.00142089,  0.02383718, -0.00676307,  0.06205346, -0.01860206],
#        dtype=float32),
#  array([ 0.06456713, -0.0401312 , -0.06864034,  0.10909225,  0.09453645,
#          0.02968502,  0.02872049,  0.00312304,  0.17003456, -0.04872629],
#        dtype=float32),
#  array([-0.02604154,  0.03803775, -0.04396643,  0.02918131, -0.00163022,
#          0.00860844,  0.00951676,  0.02846743,  0.00373869,  0.03392748],
#        dtype=float32),
#  array([ 0.05048649, -0.02286862, -0.0433067 ,  0.06461576,  0.07767949,
#          0.02270905,  0.0271166 , -0.00915326,  0.12089555, -0.02902975],
#        dtype=float32),
#  array([ 0.015273  , -0.04277818, -0.02392516,  0.02324075,  0.01031008,
#          0.00104827, -0.00365147,  0.01539496,  0.02441006, -0.0434408 ],
#        dtype=float32),
#  array([ 0.07894729, -0.01207274, -0.03766111,  0.06467634,  0.07666455,
#          0.01407462,  0.01227407, -0.02558931,  0.11348414, -0.02859305],
#        dtype=float32),
#  array([ 0.02724558, -0.00796075, -0.03051032,  0.06131108,  0.06495444,
#          0.01915549,  0.01419002, -0.00172187,  0.06214685, -0.03202166],
#        dtype=float32),
#  array([ 0.01607214, -0.01995818, -0.02501222,  0.02359839,  0.02488529,
#          0.01184392,  0.01848268,  0.00028828,  0.05902858,  0.00653526],
#        dtype=float32),
#  array([ 0.00523423, -0.011271  ,  0.01673228,  0.0279971 ,  0.00124865,
#          0.01725665,  0.0091908 ,  0.00993199,  0.07802087,  0.01143293],
#        dtype=float32),
#  array([ 0.02075884, -0.00057953, -0.01256343,  0.02772047,  0.03823152,
#          0.01861959, -0.00089013, -0.0027095 ,  0.06181967, -0.00792716],
#        dtype=float32),
#  array([ 0.03322046, -0.01412478, -0.01094092,  0.02995566,  0.03096658,
#          0.00682334,  0.00946975, -0.00371944,  0.05952769,  0.00152524],
#        dtype=float32),
#  array([ 0.028574  , -0.01991621, -0.03984871,  0.04633029,  0.04110986,
#          0.01523383,  0.02652243, -0.0037009 ,  0.06962308, -0.02011783],
#        dtype=float32),
#  array([ 0.02003305, -0.01002061, -0.02162562,  0.03341717,  0.03446409,
#          0.01351541,  0.02660123,  0.02207561,  0.03124324, -0.01763391],
#        dtype=float32),
#  array([ 0.04229105, -0.00261722, -0.06625167,  0.07862419,  0.110971  ,
#          0.01413371,  0.02291089, -0.02616814,  0.14481257, -0.01464552],
#        dtype=float32),
#  array([ 0.0079255 , -0.00677583, -0.00368088,  0.01534775,  0.03277215,
#         -0.00237177,  0.01240093,  0.00329615,  0.04766607, -0.01136726],
#        dtype=float32),
#  array([ 0.02450393, -0.00177396, -0.01693889,  0.03169825,  0.04731844,
#          0.00640504,  0.00147504, -0.01680996,  0.05646359, -0.00514698],
#        dtype=float32),
#  array([ 0.03211536, -0.02159526, -0.03793295,  0.06225941,  0.07337856,
#          0.02313839,  0.03188567, -0.01558013,  0.10074998, -0.02975601],
#        dtype=float32),
#  array([ 0.0065088 , -0.01359618, -0.00840176,  0.01668691,  0.02420424,
#          0.01630566,  0.01459363,  0.00546598,  0.04446411,  0.00065833],
#        dtype=float32),
#  array([ 0.00609656, -0.02188568, -0.0393686 ,  0.01958362,  0.02918916,
#          0.0118343 , -0.00627377, -0.0119065 ,  0.02298984, -0.02547595],
#        dtype=float32),
#  array([ 0.02929496, -0.00137335, -0.03396229,  0.04924634,  0.045857  ,
#          0.00904118,  0.01317439, -0.0102646 ,  0.07977679, -0.01376942],
#        dtype=float32),
#  array([ 0.02263032, -0.01959259, -0.01137272,  0.03148012,  0.04433745,
#          0.00644367,  0.01754857, -0.0066917 ,  0.06036346, -0.01503982],
#        dtype=float32),
#  array([ 0.05801642, -0.00287381,  0.0237576 , -0.01295922,  0.06489662,
#         -0.03572747, -0.04286978, -0.01470033,  0.10174577, -0.0737799 ],
#        dtype=float32),
#  array([ 0.04913568, -0.03382111, -0.06300976,  0.06677002,  0.09461329,
#          0.03642024,  0.01859477,  0.01472546,  0.10082868, -0.03478555],
#        dtype=float32),
#  array([ 0.01172   , -0.01158462, -0.01476735,  0.02581084,  0.03560672,
#          0.01139062,  0.00456678, -0.00626649,  0.06281552, -0.01619197],
#        dtype=float32),
#  array([ 0.04122913, -0.02283826, -0.02096161,  0.03634317,  0.04414498,
#          0.02698977,  0.02379467, -0.00237134,  0.08662373,  0.0059995 ],
#        dtype=float32),
#  array([-0.04005383, -0.00984238, -0.0412292 , -0.03689767, -0.00367996,
#          0.02103866,  0.00754852,  0.01979243, -0.00359102,  0.00898364],
#        dtype=float32),
#  array([ 0.05286561, -0.01870256, -0.02577273,  0.05477651,  0.0482284 ,
#         -0.01289381,  0.02476319, -0.02117283,  0.08930535, -0.03103533],
#        dtype=float32),
#  array([ 9.9876076e-03, -4.6275114e-03, -2.7766712e-02,  4.8399959e-03,
#          1.4404171e-02,  1.6460562e-02,  2.2406096e-03, -4.5036552e-03,
#         -8.7709195e-05, -1.6892947e-02], dtype=float32),
#  array([ 0.04592706, -0.01280899, -0.02340661,  0.07466849,  0.0688114 ,
#         -0.01806122,  0.02288746, -0.02886455,  0.08097909, -0.01038267],
#        dtype=float32),
#  array([ 0.04668691, -0.00298038,  0.00139482,  0.03783092,  0.04802645,
#          0.03456447,  0.02142359, -0.00912503,  0.0548274 , -0.00711614],
#        dtype=float32),
#  array([ 0.06110225, -0.04274496, -0.03467155,  0.06553464,  0.09641998,
#          0.01988161,  0.01613832, -0.00344233,  0.12083906,  0.00152802],
#        dtype=float32),
#  array([ 0.02029163, -0.01126005, -0.01136468,  0.02890447,  0.03554058,
#          0.00993027,  0.01123021,  0.02388702,  0.04420451, -0.01700348],
#        dtype=float32),
#  array([ 0.0240007 ,  0.00481253, -0.01286038,  0.02716105,  0.02872507,
#          0.00619718,  0.00019215, -0.01385078,  0.04802233, -0.01675296],
#        dtype=float32),
#  array([ 0.04576503, -0.00586823, -0.03161725,  0.057756  ,  0.08069803,
#          0.03566816,  0.01596804, -0.01327204,  0.07850902,  0.0066175 ],
#        dtype=float32),
#  array([ 0.04576503, -0.00586823, -0.03161725,  0.057756  ,  0.08069803,
#          0.03566816,  0.01596804, -0.01327204,  0.07850902,  0.0066175 ],
#        dtype=float32),
#  array([ 0.02304858, -0.01541968, -0.01609133,  0.04406514,  0.03873464,
#          0.02165076,  0.01004579, -0.00626989,  0.06685023, -0.01055942],
#        dtype=float32),
#  array([ 0.09098613, -0.04715541, -0.01934142,  0.04173306,  0.08251847,
#          0.00926976, -0.01907867, -0.00072092,  0.12527347, -0.02467209],
#        dtype=float32),
#  array([ 0.01560682, -0.00879533, -0.06197635,  0.02817902,  0.03626598,
#          0.0153505 ,  0.03509206, -0.00486635,  0.07651167, -0.00670398],
#        dtype=float32),
#  array([ 0.03360709, -0.00592348, -0.00380561,  0.02593758,  0.03759242,
#          0.01053924,  0.01115627, -0.00411283,  0.04723412, -0.01792121],
#        dtype=float32),
#  array([ 0.01433436, -0.00375479, -0.01295517,  0.05150853,  0.04575118,
#          0.00486675,  0.01220604, -0.01563719,  0.08115396, -0.03012727],
#        dtype=float32),
#  array([ 0.03382637, -0.01118866, -0.02834269,  0.03330823,  0.02679551,
#          0.00415471, -0.00252492,  0.00511313,  0.05036179, -0.00630577],
#        dtype=float32),
#  array([ 0.0136363 , -0.00706981, -0.01214971,  0.01264345,  0.02172652,
#          0.00743146,  0.01039855, -0.00733805,  0.04285914, -0.01082517],
#        dtype=float32),
#  array([ 0.00515336, -0.00743058, -0.01313101,  0.0147869 ,  0.02565008,
#         -0.00781146,  0.00799705,  0.01097928,  0.02324604,  0.01279078],
#        dtype=float32),
#  array([ 0.02256696, -0.00659716, -0.01505782,  0.02980352,  0.02920222,
#          0.00567105,  0.02866554, -0.00078505,  0.02502383, -0.00970371],
#        dtype=float32),
#  array([ 0.04311684, -0.00985515, -0.04817341,  0.05469312,  0.05337853,
#          0.0154988 ,  0.0230245 , -0.02118639,  0.08523843, -0.011016  ],
#        dtype=float32),
#  array([ 0.04124477, -0.01220505, -0.0560832 ,  0.09165787,  0.1125155 ,
#          0.05983756,  0.01381615, -0.02384624,  0.10425384, -0.04880018],
#        dtype=float32),
#  array([ 0.02300821, -0.00433122, -0.02299209,  0.01299127,  0.02124541,
#          0.02438399,  0.00117781, -0.00068295,  0.03539861, -0.00913649],
#        dtype=float32),
#  array([ 0.05801642, -0.00287381,  0.0237576 , -0.01295922,  0.06489662,
#         -0.03572747, -0.04286978, -0.01470033,  0.10174577, -0.0737799 ],
#        dtype=float32),
#  array([ 0.02224993, -0.00446283, -0.02469572,  0.03582142,  0.05374065,
#          0.00077547,  0.01433109, -0.01716116,  0.06544012, -0.00692773],
#        dtype=float32),
#  array([ 0.01756307, -0.01601776, -0.0203905 ,  0.02600587,  0.03276815,
#          0.01633053,  0.00101055, -0.00534904,  0.05599556, -0.00903554],
#        dtype=float32),
#  array([ 0.01116445,  0.00927841, -0.01648541,  0.02786493,  0.01217868,
#          0.01291415,  0.00412205, -0.01794884,  0.00291351, -0.00539758],
#        dtype=float32),
#  array([ 0.04592706, -0.01280899, -0.02340661,  0.07466849,  0.0688114 ,
#         -0.01806122,  0.02288746, -0.02886455,  0.08097909, -0.01038267],
#        dtype=float32),
#  array([ 0.03503156, -0.01811475, -0.01240952,  0.03240081,  0.03468658,
#          0.01420177, -0.00248693,  0.00703439,  0.05770301,  0.00815937],
#        dtype=float32),
#  array([ 0.04618119,  0.01061887, -0.0044531 ,  0.01174295,  0.02417278,
#          0.00297673, -0.00370811, -0.00017398,  0.04209843, -0.00538323],
#        dtype=float32),
#  array([ 0.03398031, -0.02789387, -0.01336446,  0.0255839 ,  0.0574572 ,
#          0.01946133,  0.0089827 ,  0.02217702,  0.03737385, -0.00206373],
#        dtype=float32),
#  array([ 0.04158163, -0.00858798, -0.03661583,  0.05736844,  0.05544698,
#          0.03023147,  0.03235874, -0.01284315,  0.10930098, -0.02987038],
#        dtype=float32),
#  array([ 0.03302198, -0.02349739, -0.02047511,  0.05967818,  0.06132221,
#          0.02174603,  0.011541  , -0.01284561,  0.07522132, -0.01627254],
#        dtype=float32),
#  array([ 0.05286561, -0.01870256, -0.02577273,  0.05477651,  0.0482284 ,
#         -0.01289381,  0.02476319, -0.02117283,  0.08930535, -0.03103533],
#        dtype=float32),
#  array([ 0.06053032, -0.01653148, -0.03936062,  0.08491   ,  0.06525758,
#          0.01798386,  0.03058901, -0.00668223,  0.1134018 , -0.03597459],
#        dtype=float32),
#  array([ 0.06145477, -0.01131137, -0.03400115,  0.07263406,  0.0960421 ,
#          0.03740625,  0.03080783, -0.01110116,  0.11644413, -0.0156628 ],
#        dtype=float32),
#  array([ 0.06793666, -0.04391371, -0.01401856,  0.06994919,  0.08060089,
#          0.02970521,  0.02788455, -0.02282561,  0.09847537, -0.01247669],
#        dtype=float32),
#  array([ 0.04744712, -0.01394305, -0.01273035,  0.02464381,  0.06392396,
#         -0.00622097,  0.01709336, -0.00991   ,  0.06602661,  0.00357408],
#        dtype=float32),
#  array([ 0.04839747, -0.02559435, -0.03019476,  0.06158503,  0.06791271,
#          0.02119962,  0.03100105, -0.01023121,  0.08927947, -0.02096786],
#        dtype=float32),
#  array([ 0.03575895, -0.01141983, -0.00032918,  0.03516002,  0.03176813,
#          0.00217066,  0.01536242,  0.00266181,  0.05588754, -0.01192074],
#        dtype=float32),
#  array([ 0.03634305, -0.01977456, -0.02414037,  0.02114784,  0.02370149,
#          0.02237452,  0.00654712, -0.00988357,  0.03780369, -0.02469374],
#        dtype=float32),
#  array([ 0.06804261, -0.03023438, -0.0480451 ,  0.06504705,  0.07561249,
#          0.02300907,  0.04767182, -0.00333713,  0.13126367, -0.01641059],
#        dtype=float32),
#  array([ 0.01870882, -0.01589529, -0.02362263,  0.01681518,  0.01528569,
#          0.006996  ,  0.02240411, -0.00172177,  0.04902712, -0.01891619],
#        dtype=float32),
#  array([ 0.03959171, -0.01017303, -0.00095832,  0.0201437 ,  0.04680288,
#          0.0123994 ,  0.03205784, -0.00179889,  0.0819471 , -0.01079361],
#        dtype=float32),
#  array([ 0.04501777, -0.01799849, -0.02714496,  0.04579832,  0.06158173,
#          0.01238181,  0.01568464, -0.00550717,  0.07595578, -0.01084137],
#        dtype=float32),
#  array([ 0.00524622, -0.01148374, -0.01427549,  0.02179362,  0.04170332,
#          0.00846475,  0.01188616, -0.02409465,  0.04970836, -0.0095184 ],
#        dtype=float32),
#  array([ 0.02611468, -0.01838258, -0.01030099,  0.02321313,  0.03427225,
#          0.02116756,  0.01756528, -0.0045441 ,  0.04312116,  0.00317813],
#        dtype=float32),
#  array([ 0.03097091, -0.02727574, -0.01477673,  0.02266271,  0.05204194,
#          0.01733206,  0.0076063 , -0.00784945,  0.06253526, -0.00962451],
#        dtype=float32),
#  array([ 0.04383861, -0.0203008 , -0.03547033,  0.04422216,  0.06216856,
#          0.01784785,  0.04633554, -0.01224737,  0.10437465, -0.01243826],
#        dtype=float32),
#  array([ 0.01947719, -0.01854564, -0.03424807,  0.03691176,  0.04377709,
#          0.03514745,  0.00097966, -0.00767098,  0.05658399, -0.00340427],
#        dtype=float32),
#  array([ 0.0283866 , -0.0173392 , -0.03198135,  0.0283938 ,  0.06072698,
#          0.01923515,  0.01230262, -0.00247194,  0.06243027, -0.01438407],
#        dtype=float32),
#  array([ 0.04337047, -0.02273963, -0.04745212,  0.05019185,  0.07091944,
#          0.02150911,  0.02557426, -0.00780555,  0.0932855 , -0.01983216],
#        dtype=float32),
#  array([ 0.02095128, -0.00608751, -0.01819342,  0.02322871,  0.02373284,
#          0.00165643,  0.00272109,  0.00548455,  0.04789566, -0.00975075],
#        dtype=float32),
#  array([ 0.03247764, -0.01126965, -0.01554837,  0.01949333,  0.04267647,
#          0.01463145,  0.00493335,  0.01076007,  0.07027585, -0.00624835],
#        dtype=float32),
#  array([ 0.01498967, -0.00819148, -0.00575524, -0.00417214, -0.00116084,
#         -0.00160554,  0.0265652 , -0.0299579 ,  0.00572142, -0.01006276],
#        dtype=float32),
#  array([ 0.023609  , -0.01347008, -0.02685257,  0.02621786,  0.02940385,
#          0.01964283,  0.01837415, -0.0009633 ,  0.04543801, -0.01195975],
#        dtype=float32),
#  array([ 0.06518777, -0.01864483, -0.04950962,  0.05924884,  0.06587984,
#          0.03041983,  0.02122524, -0.01252137,  0.11568075, -0.01957314],
#        dtype=float32),
#  array([ 0.01190205, -0.00675435, -0.01913958,  0.02372766,  0.02288295,
#         -0.01162535,  0.02538396, -0.00377549,  0.07192867, -0.01181327],
#        dtype=float32),
#  array([ 0.01974662,  0.00141732, -0.02056951,  0.0225985 ,  0.03193382,
#          0.02396519,  0.02293244,  0.00284733,  0.05811599, -0.01412011],
#        dtype=float32),
#  array([ 0.02039819, -0.00175013, -0.02193576,  0.02125111,  0.03609764,
#         -0.0042925 ,  0.02205516,  0.00899167,  0.04846522, -0.00194284],
#        dtype=float32),
#  array([ 0.03092506, -0.01810029, -0.04539532,  0.05623034,  0.07894401,
#          0.0147943 ,  0.02569704, -0.01466933,  0.10664862, -0.01396119],
#        dtype=float32),
#  array([ 0.03229727, -0.00189971, -0.0129205 ,  0.02480924,  0.06025323,
#          0.02292175,  0.01338315, -0.01723525,  0.04255516, -0.00738415],
#        dtype=float32),
#  array([ 0.00203418, -0.00557024, -0.01067358,  0.00386139,  0.00582549,
#          0.00424423, -0.00396104, -0.00832432,  0.00463158, -0.00965863],
#        dtype=float32),
#  array([ 0.0316214 , -0.01247047, -0.0247145 ,  0.03243512,  0.04564202,
#          0.00372797,  0.01006038, -0.00371615,  0.06548025, -0.00137292],
#        dtype=float32),
#  array([ 0.03172372,  0.00070047,  0.01144826,  0.02732185,  0.05473027,
#          0.02306053,  0.02297538,  0.00831163,  0.06770037, -0.01743617],
#        dtype=float32),
#  array([ 0.0093841 , -0.00103444, -0.02748799,  0.0315466 ,  0.04749072,
#          0.00243437,  0.02936314,  0.01555443,  0.04708584, -0.01902479],
#        dtype=float32),
#  array([ 0.04368373, -0.01828874, -0.03480665,  0.05448455,  0.10386568,
#          0.03666428,  0.00993856, -0.01592167,  0.0941289 , -0.03703628],
#        dtype=float32),
#  array([ 0.02828027, -0.01003113, -0.01371462,  0.02242379,  0.04040954,
#          0.01792695,  0.01907207, -0.01473915,  0.08092853, -0.01817004],
#        dtype=float32),
#  array([-0.01586197, -0.00435188, -0.01050424,  0.05457713,  0.04554841,
#         -0.00122702,  0.00720557, -0.00486142,  0.05637549, -0.01208226],
#        dtype=float32),
#  array([ 0.05224076, -0.03271648, -0.04985445,  0.06116392,  0.07147088,
#          0.02933392,  0.03848547, -0.01396407,  0.11949104, -0.01763402],
#        dtype=float32),
#  array([ 0.06193101, -0.0198153 , -0.02832452,  0.0510096 ,  0.08151042,
#          0.01781048,  0.02157463, -0.00255063,  0.10471755, -0.03564036],
#        dtype=float32),
#  array([ 0.04464795,  0.00130036, -0.04824913,  0.05758428,  0.04617867,
#         -0.00438583,  0.01762497, -0.0296623 ,  0.11756381, -0.02821746],
#        dtype=float32),
#  array([ 0.02796668, -0.00818865, -0.03137791,  0.02986303,  0.05222602,
#          0.02822255,  0.01142572, -0.01086079,  0.06163465, -0.01333045],
#        dtype=float32),
#  array([ 0.01724753, -0.00167513, -0.00967644,  0.00436591,  0.03105193,
#          0.01046631, -0.0005598 , -0.0094295 ,  0.04068471, -0.00781804],
#        dtype=float32),
#  array([ 0.04084754, -0.02481985, -0.0402137 ,  0.05449122,  0.07027829,
#          0.04303805,  0.02181934, -0.01008882,  0.08513489, -0.02224278],
#        dtype=float32),
#  array([ 0.05275046, -0.01104753, -0.06784721,  0.08778964,  0.10719963,
#          0.01705825,  0.04125034, -0.00935634,  0.12832959, -0.05579972],
#        dtype=float32),
#  array([ 0.00405315, -0.01783152, -0.03245758,  0.02076423,  0.03905983,
#          0.00535344,  0.01702068,  0.00386694,  0.03873203,  0.0212389 ],
#        dtype=float32),
#  array([ 0.01054776, -0.03235983, -0.01121901,  0.01360727,  0.02769981,
#          0.01382117,  0.00242031, -0.0072225 ,  0.05301113, -0.0252234 ],
#        dtype=float32),
#  array([ 0.0455466 , -0.03026334, -0.01640069,  0.04333824,  0.04941386,
#          0.0311115 , -0.00109811,  0.02345947,  0.07983556, -0.04206702],
#        dtype=float32),
#  array([ 0.04401626, -0.01892631, -0.01697352,  0.04235667,  0.07014602,
#          0.01440984,  0.01103782, -0.01458188,  0.09734672, -0.02743898],
#        dtype=float32),
#  array([ 0.02643375, -0.00918077, -0.00826182,  0.01727606,  0.03073518,
#          0.00703306, -0.00154696, -0.00588252,  0.03411808,  0.00150374],
#        dtype=float32),
#  array([ 0.05526851, -0.0286226 , -0.03308183,  0.05798677,  0.06658233,
#          0.0233323 ,  0.01942255, -0.01159128,  0.11039226, -0.02907292],
#        dtype=float32),
#  array([ 0.05801642, -0.00287381,  0.0237576 , -0.01295922,  0.06489662,
#         -0.03572747, -0.04286978, -0.01470033,  0.10174577, -0.0737799 ],
#        dtype=float32),
#  array([ 0.0552914 , -0.0108135 , -0.04437638,  0.05074554,  0.05382649,
#          0.0480511 ,  0.0466365 , -0.01577614,  0.07952568, -0.0018929 ],
#        dtype=float32),
#  array([ 0.05831781, -0.01048285, -0.03575443,  0.08557644,  0.07070896,
#          0.01543633,  0.02217889, -0.01720953,  0.13675746, -0.02046431],
#        dtype=float32),
#  array([-0.00785402,  0.01904723,  0.04231811,  0.03299631,  0.03164027,
#          0.03614721, -0.03958537,  0.01629576,  0.01514525,  0.04744944],
#        dtype=float32),
#  array([ 0.01388541, -0.00299306,  0.00054732,  0.01501208,  0.03807989,
#          0.01900554,  0.01322412, -0.01107829,  0.0227429 , -0.02465552],
#        dtype=float32),
#  array([ 0.02285966, -0.01933578, -0.02696224,  0.05646215,  0.03738671,
#          0.0263745 ,  0.01928954, -0.00434936,  0.05521477, -0.01770596],
#        dtype=float32),
#  array([ 0.04755025, -0.01952864, -0.01523287,  0.0463876 ,  0.05039274,
#          0.00750446,  0.02273014, -0.00859436,  0.08492246, -0.01696925],
#        dtype=float32),
#  array([ 0.04546199, -0.02777364, -0.03934558,  0.06805363,  0.09655368,
#          0.02925824,  0.00990907, -0.00044255,  0.10621171, -0.03887508],
#        dtype=float32),
#  array([ 0.02923462, -0.01845891, -0.02809677,  0.02134119,  0.06433402,
#          0.02489859,  0.02293196, -0.01106466,  0.06982541, -0.00871444],
#        dtype=float32),
#  array([ 0.06272415, -0.03654022, -0.06196715,  0.08773283,  0.10986261,
#          0.04053317,  0.0240494 , -0.00336029,  0.1341893 , -0.03664409],
#        dtype=float32),
#  array([ 0.04448254, -0.02455038, -0.04277325,  0.06017314,  0.07533918,
#          0.0210347 ,  0.00128159,  0.00996138,  0.08995113, -0.02629605],
#        dtype=float32),
#  array([ 0.02656531, -0.00484392, -0.0109462 ,  0.02849421,  0.03384395,
#          0.02067739,  0.0138718 , -0.02430007,  0.06794652, -0.00129659],
#        dtype=float32),
#  array([ 0.10068866,  0.01377787, -0.02587866,  0.06107991,  0.14240254,
#          0.04218599,  0.08502639, -0.02424564,  0.10413297,  0.01196366],
#        dtype=float32),
#  array([ 0.03639263, -0.02220658, -0.02879075,  0.04436075,  0.04622552,
#          0.01783208,  0.01036097, -0.00898983,  0.06649306,  0.00042375],
#        dtype=float32),
#  array([-0.0044665 , -0.0094749 , -0.0025505 , -0.00084381,  0.02918763,
#          0.01786929,  0.00828014, -0.00818768,  0.03132979, -0.00754346],
#        dtype=float32),
#  array([ 0.03379025, -0.01973011, -0.05019795,  0.06789554,  0.06422357,
#          0.01478228,  0.0195496 , -0.01489137,  0.10517159, -0.02047577],
#        dtype=float32),
#  array([ 0.03476544, -0.01965565, -0.00565632,  0.02288632,  0.04390663,
#          0.01182291,  0.01922392,  0.00233207,  0.05337865, -0.00445688],
#        dtype=float32),
#  array([ 0.07881615, -0.0343176 , -0.02311314,  0.04058526,  0.08579449,
#          0.02622419,  0.04077887, -0.01482268,  0.10644834, -0.04052762],
#        dtype=float32),
#  array([ 0.00608656, -0.00179922, -0.02447265,  0.01605462,  0.01699524,
#          0.00023963,  0.00381373, -0.00408901,  0.04205858, -0.00312933],
#        dtype=float32),
#  array([ 0.02605107, -0.01568698, -0.04089862,  0.02700617,  0.07725397,
#          0.03671433,  0.02843692,  0.00602248,  0.06993279, -0.03070339],
#        dtype=float32),
#  array([ 0.01473399, -0.01145482, -0.01036813,  0.02505637,  0.0256346 ,
#          0.02538167,  0.01199441, -0.01876194,  0.04237075, -0.0061796 ],
#        dtype=float32),
#  array([ 0.03924607, -0.01470904, -0.03429965,  0.02424197,  0.05633487,
#          0.0236888 ,  0.01777072, -0.01267846,  0.07765799, -0.0111152 ],
#        dtype=float32),
#  array([ 0.03653724, -0.00361449, -0.0312573 ,  0.02476678,  0.05003601,
#          0.02025999,  0.00511074,  0.0028605 ,  0.06403209, -0.01747226],
#        dtype=float32),
#  array([ 0.03147563, -0.01450919, -0.01884331,  0.03200659,  0.01555558,
#          0.00852938,  0.00988417, -0.00301908,  0.05217096, -0.01515073],
#        dtype=float32),
#  array([ 0.01447983, -0.01634199, -0.02507016,  0.03899163,  0.04006773,
#          0.01618599,  0.01676731, -0.01600683,  0.05038726, -0.00302378],
#        dtype=float32),
#  array([ 0.02738605, -0.01933753, -0.01960973,  0.05350085,  0.0384751 ,
#          0.01470225,  0.00267843, -0.00284898,  0.08361068, -0.01814895],
#        dtype=float32),
#  array([ 0.03563271, -0.00898335, -0.02272879,  0.02952156,  0.05237608,
#          0.02060223,  0.01147467,  0.00597726,  0.05954916, -0.01564823],
#        dtype=float32),
#  array([ 0.02829322, -0.00173292, -0.02276191,  0.01224967,  0.02727048,
#          0.01651661,  0.01600363, -0.00823022,  0.05735366, -0.02722684],
#        dtype=float32),
#  array([ 0.05286561, -0.01870256, -0.02577273,  0.05477651,  0.0482284 ,
#         -0.01289381,  0.02476319, -0.02117283,  0.08930535, -0.03103533],
#        dtype=float32),
#  array([ 0.04592706, -0.01280899, -0.02340661,  0.07466849,  0.0688114 ,
#         -0.01806122,  0.02288746, -0.02886455,  0.08097909, -0.01038267],
#        dtype=float32),
#  array([ 0.07466041, -0.01282018, -0.05168274,  0.08064834,  0.07801803,
#          0.01644998,  0.00845727, -0.01453037,  0.13480292, -0.00832292],
#        dtype=float32),
#  array([ 0.00335729, -0.00207428, -0.01634961,  0.03823899,  0.04085219,
#          0.0170925 ,  0.01402215,  0.00664063,  0.04744139, -0.00154427],
#        dtype=float32),
#  array([ 0.02376798, -0.0155794 , -0.02351054,  0.0180473 ,  0.03691973,
#          0.00854961,  0.00350872, -0.00970666,  0.06042743,  0.00187781],
#        dtype=float32),
#  array([ 8.1083020e-03,  9.1213069e-04, -2.6841627e-02,  4.2906757e-03,
#          2.9439721e-02, -4.8071041e-04,  1.2063093e-02, -4.1557010e-05,
#          5.9150200e-02, -5.3110030e-03], dtype=float32),
#  array([ 0.02530305, -0.01059342, -0.01320687,  0.05893369,  0.02727713,
#          0.01240733,  0.02102271, -0.02603171,  0.07739165,  0.00099115],
#        dtype=float32),
#  array([ 0.02936788, -0.0199225 , -0.03483027,  0.05074309,  0.04516087,
#          0.02190387,  0.02160053, -0.00559884,  0.07969064, -0.01961915],
#        dtype=float32),
#  array([ 0.10841882, -0.02888254, -0.0898756 ,  0.13288891,  0.1523795 ,
#          0.02306637,  0.03403824, -0.03953205,  0.198332  , -0.07418866],
#        dtype=float32),
#  array([ 0.01987748,  0.00571488,  0.00148771,  0.04422931,  0.01439651,
#          0.04977531, -0.01919133, -0.03681739,  0.0207423 , -0.00693883],
#        dtype=float32),
#  array([ 0.03166357, -0.01704472, -0.02907426,  0.04192103,  0.05439844,
#          0.01225301,  0.00909952, -0.01508022,  0.08897866, -0.02267157],
#        dtype=float32),
#  array([ 0.02790967, -0.0108545 , -0.01727693,  0.01952586,  0.05710686,
#          0.01527032,  0.02083395, -0.00690345,  0.0865368 , -0.0207766 ],
#        dtype=float32),
#  array([ 0.02384241, -0.00675745, -0.02664905,  0.04713198,  0.04267851,
#          0.00634204,  0.01267332, -0.00144954,  0.07388712, -0.00626314],
#        dtype=float32),
#  array([ 0.08218011, -0.00824094, -0.06397168,  0.10438501,  0.11413532,
#          0.03746056,  0.0514395 , -0.04239419,  0.18926723, -0.02745605],
#        dtype=float32),
#  array([ 0.02717144, -0.00532087, -0.01589816,  0.03099752,  0.04399375,
#          0.01242071,  0.01941193, -0.01430601,  0.07005645, -0.00703919],
#        dtype=float32),
#  array([ 0.0567709 , -0.02754658, -0.04747681,  0.03116467,  0.0577549 ,
#          0.02744873,  0.0026705 ,  0.01246538,  0.07117398, -0.02367867],
#        dtype=float32),
#  array([ 0.00555437, -0.01089355, -0.02505326,  0.00689485,  0.01360382,
#          0.00464737,  0.00884454, -0.00028785,  0.0422112 , -0.02085981],
#        dtype=float32),
#  array([ 0.04736388, -0.02289258, -0.03497285,  0.04132756,  0.0732813 ,
#          0.0226061 ,  0.0257973 , -0.01325794,  0.09714932, -0.02174899],
#        dtype=float32),
#  array([ 0.06579462, -0.0273261 , -0.05071776,  0.08455672,  0.11913009,
#          0.04006311,  0.04134098, -0.01484233,  0.13860632, -0.0375605 ],
#        dtype=float32),
#  array([ 0.01770725, -0.00205533, -0.00618565,  0.00347605,  0.02380147,
#          0.00226029,  0.0011606 ,  0.00804281,  0.04499698,  0.00053577],
#        dtype=float32),
#  array([ 0.02829322, -0.00173292, -0.02276191,  0.01224967,  0.02727048,
#          0.01651661,  0.01600363, -0.00823022,  0.05735366, -0.02722684],
#        dtype=float32),
#  array([ 0.02078542, -0.02608398, -0.02511284,  0.02127031,  0.05011111,
#          0.02233691,  0.02726867, -0.00287448,  0.10890851, -0.01091099],
#        dtype=float32),
#  array([ 0.02189814,  0.01415452, -0.01468375,  0.03144904, -0.01047918,
#          0.00521165,  0.01666131,  0.01787519,  0.04443347, -0.02897696],
#        dtype=float32),
#  array([ 0.02979183, -0.02257934, -0.01399735,  0.03061943,  0.02626431,
#          0.02170974,  0.01464583,  0.01196629,  0.03829794, -0.00727596],
#        dtype=float32),
#  array([ 0.02837796,  0.00255691, -0.02556955,  0.04701843,  0.03002074,
#         -0.00330635,  0.02827888, -0.00824121,  0.04773753, -0.00943616],
#        dtype=float32),
#  array([-0.00868167,  0.01645746,  0.00196444,  0.01162709,  0.032181  ,
#          0.01936254, -0.00049349, -0.00178266,  0.040861  , -0.00319881],
#        dtype=float32),
#  array([ 0.03870443, -0.02724272, -0.03053622,  0.04748182,  0.05620829,
#          0.0235231 ,  0.02962311, -0.01108711,  0.08898943, -0.02087292],
#        dtype=float32),
#  array([ 0.01638367, -0.01518449, -0.00861805,  0.0267265 ,  0.02963756,
#          0.0157866 ,  0.00161632,  0.00044575,  0.04353236, -0.01269344],
#        dtype=float32),
#  array([ 0.02719296, -0.00514769, -0.02465233,  0.0606204 ,  0.04771287,
#          0.01826911,  0.00993283, -0.00142481,  0.06961002, -0.01421015],
#        dtype=float32),
#  array([ 2.1871028e-02, -3.8637896e-05, -2.7363211e-02, -8.5772853e-03,
#          4.7740899e-02, -5.3949198e-03, -1.6793882e-02, -3.1748500e-03,
#          7.0650682e-02,  6.0387189e-03], dtype=float32),
#  array([ 0.02364941, -0.01294911, -0.01110882,  0.02383321,  0.01526676,
#          0.00802143,  0.01311161, -0.00378228,  0.03968462, -0.01119844],
#        dtype=float32),
#  array([-0.0036354 , -0.00658964, -0.01364962,  0.01739274,  0.00129614,
#         -0.01404862, -0.00715118,  0.01744092,  0.03066034, -0.00637803],
#        dtype=float32),
#  array([ 0.02257992, -0.00764273, -0.01882558,  0.02901854,  0.03011253,
#          0.00035175,  0.01136687, -0.01453446,  0.05334059, -0.01374332],
#        dtype=float32),
#  array([-0.01267759,  0.0160688 , -0.01928931,  0.02987438,  0.03356671,
#          0.02677017, -0.00787315,  0.00033491,  0.05595044, -0.03003621],
#        dtype=float32),
#  array([ 0.02495918, -0.01182351, -0.0391091 ,  0.049965  ,  0.06293722,
#          0.01864824,  0.01487431,  0.01340892,  0.07773639, -0.02762421],
#        dtype=float32),
#  array([ 0.01724039,  0.00312858, -0.00343764,  0.03182139,  0.03314697,
#          0.01764924,  0.02577235,  0.01045758,  0.04605899, -0.01241594],
#        dtype=float32),
#  array([ 0.02510222,  0.0083226 ,  0.00848439,  0.0292137 ,  0.03767748,
#          0.00820601,  0.02490111,  0.01641779,  0.01279015, -0.03741979],
#        dtype=float32),
#  array([ 0.00810247, -0.00038696, -0.0024668 ,  0.00307263,  0.01620912,
#         -0.00763818,  0.02119174,  0.01297413,  0.03047817, -0.00326394],
#        dtype=float32),
#  array([ 0.01923146, -0.02087214, -0.01766957,  0.03863377,  0.05005248,
#          0.02089218,  0.02437373,  0.00418602,  0.07091066, -0.01429019],
#        dtype=float32),
#  array([ 4.5666575e-02, -6.9770068e-03, -2.8243614e-02,  3.2709923e-02,
#          5.7319839e-02,  1.1593393e-02,  9.0591498e-03,  8.1330072e-05,
#          7.1257286e-02, -1.0182877e-02], dtype=float32),
#  array([ 0.04222666, -0.01812328, -0.035681  ,  0.02460939,  0.05149938,
#          0.02547088,  0.01126019,  0.01059024,  0.07205518, -0.02465751],
#        dtype=float32),
#  array([ 0.02559093, -0.00652126, -0.01705916,  0.02476014,  0.02471083,
#          0.00440678,  0.02096158, -0.01344693,  0.04879027,  0.00552641],
#        dtype=float32),
#  array([ 0.01149943,  0.01581358, -0.01569269,  0.01907806,  0.03525108,
#          0.01437973,  0.00271619,  0.00129975,  0.03325313, -0.0042168 ],
#        dtype=float32),
#  array([ 0.00185904, -0.00635799, -0.02139739,  0.01764682,  0.01641712,
#          0.00689314,  0.00245406,  0.00523792,  0.02062257,  0.0033373 ],
#        dtype=float32),
#  array([ 0.02060567, -0.00667975, -0.02315733,  0.03734478,  0.04259626,
#         -0.00132497,  0.00726572, -0.01256996,  0.06766715, -0.01533018],
#        dtype=float32),
#  array([ 0.03211114, -0.01864799, -0.02732742,  0.0316634 ,  0.03364625,
#          0.00634289,  0.02499248, -0.01642409,  0.05172354, -0.01755478],
#        dtype=float32),
#  array([ 0.05801642, -0.00287381,  0.0237576 , -0.01295922,  0.06489662,
#         -0.03572747, -0.04286978, -0.01470033,  0.10174577, -0.0737799 ],
#        dtype=float32),
#  array([ 0.02230175, -0.01379523, -0.01697765,  0.0399731 ,  0.03686557,
#          0.0008737 , -0.00618026,  0.00026084,  0.05713237, -0.00721368],
#        dtype=float32),
#  array([ 0.03134474, -0.03678142, -0.01272863,  0.03721583,  0.0386422 ,
#          0.02069633,  0.0117715 , -0.01568563,  0.06600902, -0.02386421],
#        dtype=float32),
#  array([ 0.02423979, -0.02053713, -0.01880243,  0.0365711 ,  0.04984559,
#          0.01319355,  0.00933101,  0.01773908,  0.04506938, -0.01519703],
#        dtype=float32),
#  array([ 0.0229328 , -0.0104501 , -0.0471723 ,  0.03940056,  0.05664215,
#          0.01777209,  0.00874539,  0.00667817,  0.08664434, -0.01166336],
#        dtype=float32),
#  array([ 0.00534379, -0.02456255, -0.01375938,  0.01176976,  0.01021156,
#          0.00399519,  0.00204611,  0.01479404,  0.02295817,  0.00100542],
#        dtype=float32),
#  array([ 0.03674204, -0.03196954, -0.03008188,  0.05913086,  0.05564953,
#          0.02203713,  0.02648633, -0.01355599,  0.08647963, -0.00932228],
#        dtype=float32),
#  array([ 0.01656347,  0.00585733, -0.02998384,  0.02110436,  0.0526045 ,
#          0.01523021, -0.00077621,  0.00467374,  0.0374033 , -0.01773735],
#        dtype=float32),
#  array([ 0.02249697, -0.00054433, -0.01995192,  0.02725382,  0.03607093,
#          0.00988317, -0.00253933, -0.00949922,  0.067655  ,  0.00432712],
#        dtype=float32),
#  array([ 0.01661964, -0.02940914,  0.01490865,  0.01792862,  0.01799335,
#         -0.00629885,  0.00752654, -0.00661007,  0.05136294, -0.00027666],
#        dtype=float32),
#  array([ 0.00255271, -0.01138451, -0.00869512,  0.00071151,  0.02345919,
#          0.00048364,  0.00618185, -0.01095359,  0.04317784, -0.00874701],
#        dtype=float32),
#  array([ 0.0561137 , -0.01294207, -0.03582384,  0.05086004,  0.05406812,
#          0.02301043,  0.00551784, -0.01672011,  0.07762728, -0.02013158],
#        dtype=float32),
#  array([ 0.0171069 , -0.01293855, -0.01975836,  0.02743049,  0.02524238,
#          0.00175594, -0.0014813 ,  0.00395463,  0.03792129, -0.00480222],
#        dtype=float32),
#  array([ 0.01532171,  0.00945008,  0.01356111, -0.00053806,  0.03442724,
#          0.01366806,  0.02338015,  0.00095735,  0.04595817, -0.00773539],
#        dtype=float32),
#  array([ 0.01435932,  0.0005183 , -0.02173799,  0.01469944,  0.01810151,
#          0.01510932,  0.00478937, -0.00317264,  0.03646256,  0.00088295],
#        dtype=float32),
#  array([ 0.00076315, -0.01003575, -0.01814195,  0.00412658,  0.01477003,
#          0.00927696,  0.0083969 , -0.01044111,  0.04064959, -0.01155823],
#        dtype=float32),
#  array([-0.00226668, -0.02144883, -0.01350327,  0.01871105,  0.04573935,
#         -0.00447994,  0.00572005,  0.0116451 ,  0.03816915, -0.01027163],
#        dtype=float32),
#  array([ 0.02984358, -0.01333847, -0.03298492,  0.04406277,  0.05853687,
#          0.01238973,  0.01977783,  0.00261915,  0.05527181, -0.01091356],
#        dtype=float32),
#  array([ 3.6413953e-02,  8.8009983e-05, -3.3389255e-02,  1.9965388e-02,
#          4.0026616e-02,  9.1753183e-03, -7.1899751e-03, -2.0224549e-02,
#          8.7873682e-02,  1.1958694e-02], dtype=float32),
#  array([ 0.01412137, -0.00491448,  0.01558864,  0.01190346,  0.01067249,
#          0.0124913 ,  0.00948646,  0.0081675 ,  0.04173281, -0.00156973],
#        dtype=float32),
#  array([ 0.05381021, -0.01823117, -0.05047214,  0.08551122,  0.09987951,
#          0.03092028,  0.03183818, -0.01720651,  0.11924189, -0.04239735],
#        dtype=float32),
#  array([ 0.0238547 , -0.0063697 , -0.01656366,  0.02904039,  0.05415828,
#          0.02599529,  0.03510207,  0.00069483,  0.07011691, -0.01216132],
#        dtype=float32),
#  array([ 0.04592706, -0.01280899, -0.02340661,  0.07466849,  0.0688114 ,
#         -0.01806122,  0.02288746, -0.02886455,  0.08097909, -0.01038267],
#        dtype=float32),
#  array([ 0.03558056, -0.01408828, -0.01168152,  0.04714458,  0.06757915,
#          0.0205716 ,  0.0421854 , -0.02218631,  0.08517373, -0.01728931],
#        dtype=float32),
#  array([ 0.04881776, -0.00750914, -0.0354654 ,  0.04082862,  0.06184423,
#          0.01396633,  0.01956463, -0.0065759 ,  0.08428304, -0.02514423],
#        dtype=float32),
#  array([ 0.05286561, -0.01870256, -0.02577273,  0.05477651,  0.0482284 ,
#         -0.01289381,  0.02476319, -0.02117283,  0.08930535, -0.03103533],
#        dtype=float32),
#  array([ 0.01840228, -0.00823768, -0.01647909,  0.04086041,  0.05241447,
#          0.00362513, -0.00257962, -0.02645265,  0.05570628, -0.00277151],
#        dtype=float32),
#  array([ 0.03322669, -0.02512147, -0.021361  ,  0.0541173 ,  0.04441218,
#          0.01679059,  0.02274909, -0.00425377,  0.07379983, -0.03077086],
#        dtype=float32),
#  array([ 0.01909719, -0.00819001, -0.01157374,  0.02936765,  0.01835645,
#          0.01488379,  0.02144088,  0.00258032,  0.05755748, -0.00560097],
#        dtype=float32),
#  array([ 0.03899897, -0.01045632, -0.01925409,  0.03264409,  0.05593517,
#          0.01258949,  0.0119863 ,  0.00439108,  0.06529646, -0.01377779],
#        dtype=float32),
#  array([ 0.03334625, -0.0195701 , -0.02011042,  0.0377778 ,  0.04939311,
#          0.01573966,  0.03393027,  0.00417225,  0.0619577 , -0.02231889],
#        dtype=float32),
#  array([ 0.0279522 , -0.00173183, -0.01484194,  0.02243401,  0.02964216,
#          0.00656763,  0.00801054,  0.00190207,  0.05200695, -0.01161148],
#        dtype=float32),
#  array([ 0.02760996,  0.00025673, -0.00833993,  0.02573002,  0.04905593,
#          0.02049878,  0.00671389, -0.0185561 ,  0.05030738,  0.01494255],
#        dtype=float32),
#  array([ 0.02365619, -0.01694066, -0.03159455,  0.03617842,  0.05468826,
#          0.02384152,  0.01957738,  0.00879805,  0.06853957, -0.0327739 ],
#        dtype=float32),
#  array([ 0.02510641, -0.01270396, -0.01644758,  0.02889219,  0.02410761,
#          0.02551157,  0.02469481,  0.00592792,  0.04347062, -0.00059814],
#        dtype=float32),
#  array([ 0.03471826, -0.01467114, -0.02612317,  0.02937405,  0.04374537,
#          0.01525288,  0.03053942, -0.0083498 ,  0.07083704, -0.01467846],
#        dtype=float32),
#  array([ 0.01366546, -0.00777387, -0.00658472,  0.00808885,  0.02260912,
#          0.00273615,  0.00455527, -0.00802592, -0.00272661, -0.00914609],
#        dtype=float32),
#  array([ 0.03809192, -0.00748369, -0.03036014,  0.05831852,  0.07063765,
#          0.03058972,  0.02802826, -0.01343845,  0.08503044, -0.02616234],
#        dtype=float32),
#  array([ 0.00757156, -0.01967002, -0.00612609,  0.02400613,  0.01894963,
#          0.00761661,  0.02280331, -0.00671156,  0.02912779, -0.02450509],
#        dtype=float32),
#  array([ 0.10709037, -0.01751686, -0.07769578,  0.12635913,  0.11561787,
#          0.00769331,  0.03085531, -0.00225169,  0.19391696, -0.03379768],
#        dtype=float32),
#  array([ 0.01789236, -0.02512421, -0.01441505,  0.03230854,  0.0216805 ,
#         -0.03009323, -0.01292643,  0.01396443,  0.04387791, -0.0167236 ],
#        dtype=float32),
#  array([-0.00658881, -0.01267143, -0.00437985,  0.01352641,  0.03852566,
#          0.01523531,  0.01146905,  0.00332938,  0.02486675, -0.00676317],
#        dtype=float32),
#  array([ 0.06801423, -0.03652102, -0.06789064,  0.10288062,  0.10750719,
#          0.02707008,  0.03995827, -0.01096762,  0.19508211, -0.04352931],
#        dtype=float32),
#  array([ 0.05580522, -0.02668097, -0.03199681,  0.06558496,  0.07621361,
#          0.02825358,  0.03115299, -0.01032692,  0.1184429 , -0.02229625],
#        dtype=float32),
#  array([ 0.03112088, -0.00709086, -0.01403277,  0.01929704,  0.01989776,
#         -0.00505744,  0.02231266, -0.0067415 ,  0.05718195,  0.00708138],
#        dtype=float32),
#  array([ 0.04282982, -0.01565787, -0.03956378,  0.04917029,  0.07200337,
#          0.02720573,  0.02445404,  0.00311173,  0.11473726, -0.01879149],
#        dtype=float32),
#  array([-0.01845884,  0.00588881, -0.02475638, -0.02409489,  0.02281208,
#          0.03656235, -0.00291453,  0.01285412,  0.03293963,  0.03249097],
#        dtype=float32),
#  array([ 0.03766362,  0.00708644, -0.05491332,  0.03510277,  0.06304996,
#         -0.00502096,  0.05440633, -0.00543582,  0.05563974,  0.0083318 ],
#        dtype=float32),
#  array([ 0.08428667, -0.02816018, -0.08368686,  0.12260161,  0.10891306,
#          0.03799302,  0.05812221, -0.03059434,  0.21234708, -0.06292083],
#        dtype=float32),
#  array([ 0.08623284, -0.02020007, -0.07364907,  0.09679578,  0.10957916,
#          0.04071815,  0.06120711, -0.02193517,  0.16023171, -0.04558817],
#        dtype=float32),
#  array([ 0.0292094 , -0.00192829, -0.01457226,  0.03589066,  0.04179032,
#         -0.00518122,  0.01861214,  0.00743128,  0.04025008, -0.00315107],
#        dtype=float32),
#  array([ 0.03840703, -0.03801974, -0.02684308,  0.0548444 ,  0.04865642,
#          0.01801465,  0.02814438, -0.01293035,  0.06956164, -0.01597635],
#        dtype=float32),
#  array([ 0.03635198, -0.0189643 , -0.03941238,  0.04956682,  0.063575  ,
#          0.03026671,  0.01688851, -0.01021475,  0.08952289, -0.01271323],
#        dtype=float32),
#  array([ 0.00098155,  0.0025683 , -0.00343476,  0.02815927,  0.03215713,
#          0.00743026, -0.02254015, -0.01806196,  0.02012869, -0.01895579],
#        dtype=float32),
#  array([ 0.03824509, -0.01597748, -0.03208865,  0.04259975,  0.05233409,
#          0.01686557,  0.03182864, -0.00437808,  0.0763574 , -0.02589032],
#        dtype=float32),
#  array([ 0.06563725,  0.00993717, -0.04090267,  0.02712008,  0.02833669,
#         -0.00776782,  0.0497673 ,  0.0187817 ,  0.11609647, -0.01423352],
#        dtype=float32),
#  array([ 0.00728971, -0.02562617,  0.00337123,  0.02806124,  0.03537214,
#          0.0069048 ,  0.03112832,  0.00715031,  0.04902623, -0.00621291],
#        dtype=float32),
#  array([ 0.06566796, -0.02130368, -0.04279429,  0.09121792,  0.11664672,
#          0.02935866,  0.04293138, -0.02154862,  0.14943314, -0.0405573 ],
#        dtype=float32),
# ...
#          0.00645937,  0.02991032, -0.00114282,  0.06124778, -0.00600453],
#        dtype=float32),
#  array([ 0.02606334, -0.01442013, -0.00988181,  0.02515491,  0.01685174,
#          0.02239231,  0.00540254,  0.00113092,  0.04686811, -0.02514812],
#        dtype=float32),
#  array([ 0.0486137 , -0.01786932, -0.0289092 ,  0.04663679,  0.05474574,
#          0.02115708,  0.0240666 ,  0.01163694,  0.06912354, -0.02402027],
#        dtype=float32),
#  array([ 0.03029625, -0.01963058, -0.03377239,  0.05300897,  0.05949595,
#          0.01934175,  0.02018776,  0.01071986,  0.11183113, -0.02993607],
#        dtype=float32),
#  array([ 0.01849346, -0.01652478, -0.02155057,  0.05975413,  0.03915561,
#          0.00151157,  0.01773951, -0.00124724,  0.08004756, -0.01465073],
#        dtype=float32),
#  array([ 0.00142289, -0.00833989, -0.02630649,  0.01408691,  0.00609017,
#         -0.00385937, -0.01841921, -0.01832921,  0.05955019, -0.04656339],
#        dtype=float32),
#  array([ 0.05801642, -0.00287381,  0.0237576 , -0.01295922,  0.06489662,
#         -0.03572747, -0.04286978, -0.01470033,  0.10174577, -0.0737799 ],
#        dtype=float32),
#  array([ 0.03955534, -0.01300539, -0.01657022,  0.01123432,  0.06320029,
#          0.02767742,  0.01549293, -0.02836885,  0.08495217, -0.02051972],
#        dtype=float32),
#  array([ 0.0443739 , -0.00908441, -0.03203696,  0.07223869,  0.0831723 ,
#          0.03128305,  0.03283925, -0.02069894,  0.12266678, -0.0436647 ],
#        dtype=float32),
#  array([ 0.03317123, -0.03748111, -0.0307878 ,  0.04608359,  0.08353721,
#          0.03281178,  0.01043849, -0.00940691,  0.06831975, -0.03137158],
#        dtype=float32),
#  array([ 0.04936158, -0.02388826, -0.03173257,  0.03895132,  0.05318923,
#          0.01657182,  0.02257233,  0.00121982,  0.09050169, -0.01216068],
#        dtype=float32),
#  array([ 0.00425105, -0.00144922, -0.01727008,  0.04863288,  0.03320275,
#          0.02174966,  0.02202953, -0.0035797 ,  0.05142802, -0.02129141],
#        dtype=float32),
#  array([ 0.05286561, -0.01870256, -0.02577273,  0.05477651,  0.0482284 ,
#         -0.01289381,  0.02476319, -0.02117283,  0.08930535, -0.03103533],
#        dtype=float32),
#  array([ 0.04592706, -0.01280899, -0.02340661,  0.07466849,  0.0688114 ,
#         -0.01806122,  0.02288746, -0.02886455,  0.08097909, -0.01038267],
#        dtype=float32),
#  array([0.02853686, 0.01100162, 0.0031531 , 0.01533833, 0.0200797 ,
#         0.00352336, 0.00831409, 0.0174294 , 0.03109952, 0.00351314],
#        dtype=float32),
#  array([ 0.03263461, -0.00201487, -0.03825415,  0.05184594,  0.04764845,
#          0.01310535,  0.00958838, -0.03067379,  0.06868397,  0.01170426],
#        dtype=float32),
#  array([ 0.05970431, -0.0189348 , -0.04403601,  0.07105315,  0.11167872,
#          0.02665877,  0.02987786, -0.00540585,  0.11630432, -0.03200664],
#        dtype=float32),
#  array([ 0.04083997, -0.00549073, -0.03081116,  0.03970037,  0.05335225,
#          0.02022344,  0.01638683, -0.01906387,  0.05698466, -0.0131653 ],
#        dtype=float32),
#  array([ 0.04753311, -0.02136921, -0.04218659,  0.0741421 ,  0.05871737,
#          0.01229751,  0.02638424, -0.00602042,  0.13233109, -0.00786307],
#        dtype=float32),
#  array([ 0.05839231, -0.03264352, -0.04249466,  0.06653615,  0.07867032,
#          0.04061155,  0.03287438, -0.01559298,  0.11409061, -0.02066454],
#        dtype=float32),
#  array([ 0.04903204, -0.02685668, -0.03565778,  0.03790297,  0.0741375 ,
#          0.03003705,  0.02193969, -0.0246542 ,  0.09198262, -0.00744509],
#        dtype=float32),
#  array([ 0.03376779, -0.01141591, -0.02442551,  0.04294141,  0.06537925,
#          0.02185165,  0.01557546, -0.00023046,  0.07874418, -0.01528956],
#        dtype=float32),
#  array([ 0.02944718,  0.00023323, -0.00781454,  0.01654706,  0.00552626,
#         -0.00466801,  0.0017621 ,  0.01318591,  0.01797435, -0.00409644],
#        dtype=float32),
#  array([ 0.02624007, -0.00258516, -0.04108248,  0.02022491,  0.02947482,
#          0.02833004,  0.01160975,  0.01089142,  0.05413902, -0.01902876],
#        dtype=float32),
#  array([ 0.04981008, -0.0167185 , -0.02448215,  0.04858101,  0.03996007,
#          0.02257183,  0.02184349, -0.01335361,  0.08717953, -0.03259254],
#        dtype=float32),
#  array([ 0.02937728,  0.00408173, -0.01792217,  0.01688522,  0.02873758,
#          0.01527953,  0.00560797, -0.00452209,  0.04830913, -0.00841857],
#        dtype=float32),
#  array([ 0.02880444, -0.00325805, -0.04014364,  0.00491569,  0.01551781,
#          0.01573241, -0.00901603, -0.01371446,  0.00313243,  0.00352083],
#        dtype=float32),
#  array([ 0.03911539, -0.02252717, -0.02417078,  0.04230003,  0.0411476 ,
#          0.01504812,  0.01681573, -0.00705343,  0.08645803, -0.01956564],
#        dtype=float32),
#  array([ 0.02253025, -0.00861093, -0.02683043,  0.05905027,  0.04561928,
#          0.00040779,  0.02105744, -0.00459815,  0.06587678,  0.00349635],
#        dtype=float32),
#  array([ 0.03307623, -0.01659698, -0.01960134,  0.03691756,  0.056373  ,
#          0.02028426,  0.00879563, -0.01639562,  0.07693081, -0.01062641],
#        dtype=float32),
#  array([ 0.05404239, -0.01323027, -0.01428623,  0.04706843,  0.07626133,
#          0.03303148,  0.0154305 , -0.00292797,  0.09225638, -0.02307439],
#        dtype=float32),
#  array([ 0.01129998, -0.01986027, -0.02898589,  0.02649238,  0.03731013,
#          0.02436958,  0.00212997, -0.00432996,  0.01426349, -0.00800984],
#        dtype=float32),
#  array([ 0.03976706,  0.00076134, -0.01574148,  0.04045454,  0.04673939,
#          0.01674034,  0.02930907, -0.01126088,  0.08792575, -0.00701931],
#        dtype=float32),
#  array([ 0.04962001, -0.02469291, -0.03868955,  0.07092001,  0.07815   ,
#          0.01874929,  0.02051888, -0.01231092,  0.11768173, -0.01684469],
#        dtype=float32),
#  array([ 0.02721405, -0.00482788, -0.01806371,  0.01540005,  0.04481499,
#          0.01784155,  0.02193848, -0.00543293,  0.06109145, -0.01758853],
#        dtype=float32),
#  array([ 0.01610013,  0.00174638, -0.01484684,  0.015407  ,  0.02526042,
#          0.01135356,  0.00057677, -0.00673439,  0.03074413,  0.00661599],
#        dtype=float32),
#  array([ 0.05637254, -0.03506194, -0.04874066,  0.07261621,  0.1089103 ,
#          0.02011366,  0.04454296, -0.03939735,  0.12657984, -0.02802461],
#        dtype=float32),
#  array([ 0.00288543, -0.0233498 , -0.00909558,  0.0289203 ,  0.02936562,
#          0.00519173,  0.02997779,  0.00344092,  0.05668661, -0.01432788],
#        dtype=float32),
#  array([ 0.00599722, -0.02213636, -0.01748447,  0.02907969,  0.03498638,
#          0.00854155, -0.00607247,  0.00033274,  0.05298652, -0.0112152 ],
#        dtype=float32),
#  array([ 0.04387878, -0.02259225, -0.02824358,  0.02985406,  0.07548171,
#          0.02809496,  0.04202963, -0.00855784,  0.07809561, -0.02400083],
#        dtype=float32),
#  array([ 0.03516962, -0.01871862, -0.06071125,  0.07715002,  0.11982591,
#          0.03610359,  0.04190244, -0.03541076,  0.11083959, -0.02994228],
#        dtype=float32),
#  array([ 0.06086729, -0.01792534, -0.05232967,  0.07686178,  0.10116543,
#          0.02392545,  0.04519806, -0.02162234,  0.1375601 , -0.01779409],
#        dtype=float32),
#  array([ 0.05801642, -0.00287381,  0.0237576 , -0.01295922,  0.06489662,
#         -0.03572747, -0.04286978, -0.01470033,  0.10174577, -0.0737799 ],
#        dtype=float32),
#  array([ 0.01482337, -0.01617125, -0.01063297,  0.04278173,  0.00785345,
#         -0.00879465,  0.03091477, -0.00959013,  0.03780564, -0.01398188],
#        dtype=float32),
#  array([ 0.01639011, -0.01223734, -0.01174378,  0.03319665,  0.0380293 ,
#          0.02523937,  0.01898263, -0.01115476,  0.06255381, -0.02128107],
#        dtype=float32),
#  array([ 0.03771308, -0.00561663, -0.030885  ,  0.048322  ,  0.06987647,
#          0.01504242,  0.01539435, -0.00688913,  0.0917082 , -0.0237552 ],
#        dtype=float32),
#  array([ 0.01000527,  0.00521   , -0.00438528,  0.02624791,  0.02900657,
#          0.00749014,  0.001396  , -0.02494236,  0.04738816,  0.00476371],
#        dtype=float32),
#  array([ 0.04890457, -0.02618774, -0.05377234,  0.08604147,  0.07106444,
#          0.0386305 ,  0.02184642, -0.02360942,  0.11571286, -0.0362756 ],
#        dtype=float32),
#  array([ 0.03998886, -0.00493126, -0.03459626,  0.06218689,  0.09037368,
#          0.0174037 ,  0.01321806, -0.01694801,  0.12030992, -0.03267529],
#        dtype=float32),
#  array([ 0.02235806, -0.00050582, -0.03785811,  0.03507077,  0.03235189,
#         -0.00489928,  0.00182112, -0.00609397,  0.04955491, -0.02418439],
#        dtype=float32),
#  array([ 0.02982125, -0.01956776, -0.02680432,  0.03929477,  0.03478626,
#          0.03385368,  0.02542007, -0.00484916,  0.06593155,  0.0008466 ],
#        dtype=float32),
#  array([ 0.00936319, -0.00751146, -0.001585  ,  0.01575121,  0.01974507,
#         -0.00593732,  0.02491604,  0.01601031,  0.02652969, -0.0117032 ],
#        dtype=float32),
#  array([ 0.04456123, -0.0268294 , -0.01752132,  0.06096672,  0.07311455,
#          0.01601659,  0.02179833, -0.01746942,  0.10864984, -0.00812555],
#        dtype=float32),
#  array([ 0.02280116, -0.02862995, -0.02175029,  0.04059919,  0.00251401,
#          0.00948607,  0.01344827,  0.00388641,  0.04429103, -0.01520926],
#        dtype=float32),
#  array([ 0.04494949, -0.03146056, -0.02894911,  0.02766132,  0.05834897,
#          0.03189486,  0.02687214, -0.01163586,  0.09830027, -0.01780217],
#        dtype=float32),
#  array([ 0.02572574, -0.01682105, -0.02087381,  0.06202559,  0.06653692,
#          0.0227322 ,  0.04020362, -0.02401097,  0.08790255, -0.03432548],
#        dtype=float32),
#  array([ 0.04936641, -0.01894781, -0.03622539,  0.05775543,  0.07670305,
#          0.02370945,  0.02585039,  0.00026601,  0.10539002, -0.02653374],
#        dtype=float32),
#  array([ 0.05535741, -0.01890611, -0.02831257,  0.06432718,  0.10411268,
#          0.01124836,  0.0346634 , -0.00801478,  0.10841063, -0.01570603],
#        dtype=float32),
#  array([ 0.05535741, -0.01890611, -0.02831257,  0.06432718,  0.10411268,
#          0.01124836,  0.0346634 , -0.00801478,  0.10841063, -0.01570603],
#        dtype=float32),
#  array([ 0.00159845,  0.00902871, -0.0126167 ,  0.01421583,  0.00872962,
#          0.01301639,  0.00325855,  0.01410785,  0.04006787,  0.00173114],
#        dtype=float32),
#  array([ 0.05223111, -0.01423816, -0.05274369,  0.0686269 ,  0.08944613,
#          0.02359801,  0.02844134, -0.01487033,  0.1277489 , -0.02123288],
#        dtype=float32),
#  array([ 0.0423358 , -0.00740893, -0.02312149,  0.00559197,  0.04191669,
#          0.00701616,  0.02029572,  0.01283513,  0.04100752, -0.01250959],
#        dtype=float32),
#  array([ 0.01051245, -0.00504139,  0.00104867,  0.02327722,  0.02014045,
#         -0.00222111, -0.00043537, -0.00542421, -0.00036524,  0.01143269],
#        dtype=float32),
#  array([-0.01659681, -0.01708176, -0.00564123, -0.00036435,  0.01766885,
#          0.00224616, -0.01078085, -0.00288294,  0.03607395, -0.00791044],
#        dtype=float32),
#  array([ 0.06699093, -0.0246693 , -0.04488604,  0.06243295,  0.08869725,
#          0.03296844,  0.025221  , -0.00746781,  0.1186537 , -0.03686834],
#        dtype=float32),
#  array([ 0.03471453, -0.01548528, -0.0297364 ,  0.0349461 ,  0.05935176,
#          0.01443051,  0.0270371 , -0.00894592,  0.06997161, -0.01719128],
#        dtype=float32),
#  array([ 0.05548161, -0.03247136, -0.04519557,  0.06420026,  0.08965745,
#          0.01498708,  0.01809936, -0.01866618,  0.11581665, -0.02783971],
#        dtype=float32),
#  array([ 0.03601893, -0.01094182, -0.03100891,  0.0688518 ,  0.08274817,
#          0.01189806,  0.01927376, -0.01065322,  0.09693763, -0.02309777],
#        dtype=float32),
#  array([ 0.04592706, -0.01280899, -0.02340661,  0.07466849,  0.0688114 ,
#         -0.01806122,  0.02288746, -0.02886455,  0.08097909, -0.01038267],
#        dtype=float32),
#  array([ 0.05286561, -0.01870256, -0.02577273,  0.05477651,  0.0482284 ,
#         -0.01289381,  0.02476319, -0.02117283,  0.08930535, -0.03103533],
#        dtype=float32),
#  array([ 0.0574567 , -0.00186648, -0.03810617,  0.05722821,  0.05286633,
#          0.02031536,  0.03397759, -0.00907931,  0.09243339, -0.02619512],
#        dtype=float32),
#  array([ 0.02335376, -0.01757815, -0.02157335,  0.05474916,  0.04352165,
#          0.02715757,  0.02329888, -0.02003972,  0.07125217, -0.02048601],
#        dtype=float32),
#  array([ 0.0506205 , -0.02751792, -0.03271462,  0.04996009,  0.06192233,
#          0.00870574,  0.01721257, -0.00484934,  0.09135028, -0.03647527],
#        dtype=float32),
#  array([ 0.0481151 , -0.00540366, -0.0284712 ,  0.02529151,  0.02904399,
#          0.01160616,  0.02512047,  0.01826189,  0.02060279, -0.00444827],
#        dtype=float32),
#  array([ 0.01778119, -0.00795978,  0.00305382,  0.02912113,  0.04091682,
#          0.00869711,  0.01276468, -0.01918745,  0.04500517, -0.00115806],
#        dtype=float32),
#  array([ 1.2385172e-02, -4.0949225e-02, -2.6622221e-02,  4.2303920e-02,
#          5.1545050e-02,  2.9998433e-05,  4.8151683e-02, -1.1729530e-02,
#          7.8937151e-02, -2.5507467e-02], dtype=float32),
#  array([ 0.03431582, -0.0366597 , -0.02453181,  0.03685329,  0.06428793,
#          0.03272543,  0.01720561, -0.00634459,  0.06319518, -0.02419824],
#        dtype=float32),
#  array([ 0.06143689, -0.03392303, -0.03900392,  0.09384349,  0.10901487,
#          0.04500871,  0.02816033, -0.01808849,  0.11846673, -0.03876514],
#        dtype=float32),
#  array([ 0.0330908 , -0.00541051,  0.01253785,  0.01824682,  0.05533454,
#          0.03094127, -0.00922968,  0.00092647,  0.08187563, -0.00120342],
#        dtype=float32),
#  array([ 0.04737354, -0.01885574, -0.0349779 ,  0.06537449,  0.07121842,
#          0.02815671,  0.03899699, -0.01640513,  0.09743673, -0.02109836],
#        dtype=float32),
#  array([ 0.0489281 , -0.02106276, -0.02777258,  0.04447025,  0.06300081,
#          0.01700227,  0.02162105, -0.00263709,  0.08973996, -0.02930166],
#        dtype=float32),
#  array([ 0.04205855, -0.01448559, -0.03729785,  0.06034267,  0.06889695,
#          0.01713345,  0.0398295 , -0.01969585,  0.10110889, -0.02850337],
#        dtype=float32),
#  array([ 0.04846181, -0.02553763, -0.02096421,  0.03479121,  0.04967738,
#          0.01833027,  0.01423931, -0.02754614,  0.08184417, -0.00329688],
#        dtype=float32),
#  array([ 0.05626442, -0.01799153, -0.02204574,  0.04921042,  0.07458424,
#          0.02144266,  0.03160818, -0.01268402,  0.10586329, -0.01730118],
#        dtype=float32),
#  array([ 0.02192628, -0.00744575, -0.00552524,  0.03862826,  0.03165431,
#          0.0082089 ,  0.0274743 , -0.00570125,  0.04662829, -0.01752939],
#        dtype=float32),
#  array([ 0.01349241, -0.01380425,  0.00463849,  0.0103624 ,  0.02296792,
#          0.00948629,  0.00845192, -0.01188813,  0.03493661,  0.00963148],
#        dtype=float32),
#  array([ 0.02102245,  0.00211134, -0.01216451,  0.02341763,  0.02585281,
#         -0.00097644,  0.02725614,  0.0077921 ,  0.0307219 , -0.0115945 ],
#        dtype=float32),
#  array([ 0.02541446, -0.01599567,  0.00219614,  0.01659979,  0.0365013 ,
#          0.00487046,  0.0243087 , -0.00756993,  0.02445088, -0.00266574],
#        dtype=float32),
#  array([ 0.03689419, -0.02115382, -0.01750451,  0.01749075,  0.02104214,
#          0.00942004,  0.01767961, -0.01179332,  0.04615897, -0.00696435],
#        dtype=float32),
#  array([ 0.06374638, -0.00362045, -0.04339391,  0.09153976,  0.08528153,
#          0.01024252,  0.01014678,  0.00491226,  0.1185429 , -0.01573684],
#        dtype=float32),
#  array([ 0.013549  , -0.02503856, -0.01924746,  0.01659063,  0.02447301,
#         -0.00101078,  0.00918666,  0.01074566,  0.03256146, -0.00686785],
#        dtype=float32),
#  array([ 0.013549  , -0.02503856, -0.01924746,  0.01659063,  0.02447301,
#         -0.00101078,  0.00918666,  0.01074566,  0.03256146, -0.00686785],
#        dtype=float32),
#  array([ 0.02945685, -0.00462385, -0.02860999,  0.04520462,  0.05109606,
#          0.01306966,  0.00758034, -0.0185473 ,  0.0530835 , -0.03419546],
#        dtype=float32),
#  array([ 0.01074306,  0.01120997,  0.02300789,  0.03533656,  0.01914779,
#          0.02709457,  0.03599386,  0.00230009,  0.04234683, -0.01021693],
#        dtype=float32)]

# %%
# join the sentence embeddings with their problem desc and then remove rows with 0 length array
# then reset indexes so this will be in sync with the array that will feed into cluster model
X = list(text_df2["embeddings"])
X1 = X
print(len(X))
print(len(X1))
#The way these vectors are stored is that there is a list with 17 instances -- one for each of the trades,
#and within that list there is an array for each work order kept from that trade
# Out:
# 611
# 611

# %%
plt.figure(figsize=(10, 7))  
plt.title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(X1, method='ward'))

# %%
n_clus = 4
cluster = AgglomerativeClustering(n_clusters=n_clus, affinity='euclidean', linkage='ward')
hclus = cluster.fit_predict(X1)

# %%
hclus_df = []
for idx, pred in enumerate(hclus):
    hclus_df.append((idx, pred))
hclus_df = pd.DataFrame(hclus_df, columns = ['ind', 'cluster']).drop('ind', axis=1)

# %%
print(len(hclus_df))
print(len(text_df2))
# Out:
# 611
# 611

# %%
hclus_rslt_df = pd.merge(hclus_df, text_df2, right_index=True, left_index=True)

# %%
#how many observations went to each cluster
hclus_rslt_df.cluster.value_counts()
# Out:
# 0    127
# 1    106
# 3     77
# 2      5
# Name: cluster, dtype: int64

# %%
#Get top weighted words from tf-idf for each cluster
for cl in hclus_rslt_df.cluster.value_counts().index:
   
    #print(hclus_rslt_df.wo_trade_name.unique())
    print(cl)
   
    tk_lst = hclus_rslt_df[hclus_rslt_df["cluster"] == cl]
    #each work order needs to be a string, not a list of tokens
    string = [" ".join(x) for x in tk_lst["clean_text"]]

    #from sklearn.feature_extraction.text import TfidfVectorizer
    tvec = TfidfVectorizer(min_df=.0025, max_df=.1, stop_words='english', ngram_range = (1,1))
    tvec_weights = tvec.fit_transform(string)

    weights = np.asarray(tvec_weights.mean(axis=0)).ravel().tolist() #this gives the average weight of each word over all documents
    weights_df = pd.DataFrame({'term': tvec.get_feature_names(), 'weight': weights})
    topterm_weights = weights_df.sort_values(by='weight', ascending=False).head(30)
    print(topterm_weights)
# Out:
# 0
#          term    weight
# 459      like  0.018716
# 864     white  0.018174
# 839       use  0.016520
# 470      look  0.015500
# 531      need  0.014598
# 851      want  0.014102
# 121      care  0.012572
# 474      love  0.012198
# 143     child  0.011953
# 157     color  0.011327
# 866  williams  0.011114
# 825   twitter  0.010849
# 100     brand  0.010745
# 439      know  0.010532
# 793     thing  0.010513
# 501       men  0.010483
# 814   trippin  0.010464
# 333      good  0.010168
# 32   american  0.010041
# 870     woman  0.009841
# 815      true  0.009729
# 141   chicken  0.009710
# 24        ain  0.009299
# 798      time  0.009192
# 310    friend  0.009051
# 774      sure  0.009050
# 56        ask  0.009008
# 813     trend  0.008845
# 421      jail  0.008766
# 550   opinion  0.008753
# 1
#              term    weight
# 102         child  0.030225
# 547          read  0.028286
# 636         spank  0.023306
# 732          want  0.022982
# 578         right  0.021645
# 517          post  0.020661
# 292         grade  0.018368
# 451          need  0.018144
# 708       twitter  0.017700
# 682         thing  0.014538
# 75           blue  0.014448
# 518           pre  0.014165
# 376  kindergarten  0.014165
# 416           man  0.014079
# 407          look  0.013774
# 411          love  0.013611
# 757         wrong  0.013441
# 472           old  0.013304
# 396          life  0.013054
# 14        african  0.013034
# 448       naughty  0.013018
# 688          time  0.012988
# 534          race  0.012871
# 683         think  0.011953
# 461          nice  0.011653
# 377          know  0.011567
# 691         today  0.010985
# 90           care  0.010892
# 423        matter  0.010864
# 260        follow  0.010488
# 3
#              term    weight
# 521       twitter  0.027017
# 86          child  0.023928
# 475         start  0.023381
# 277          like  0.022850
# 465         spank  0.021208
# 374          post  0.020892
# 175          feel  0.019589
# 559           yes  0.019179
# 404          read  0.018895
# 499         think  0.017487
# 424         right  0.017463
# 533         video  0.016755
# 185          free  0.015820
# 320          need  0.015151
# 275           let  0.013564
# 264         kaaba  0.013130
# 557         wrong  0.013033
# 515          trip  0.012987
# 177       finally  0.012987
# 341        orrrrr  0.012987
# 297         maybe  0.012987
# 506          time  0.012946
# 47            big  0.012829
# 267  kindergarten  0.012461
# 376           pre  0.012461
# 115       culture  0.012395
# 498         thing  0.012183
# 433        screen  0.012033
# 127     developer  0.011980
# 461          soon  0.011555
# 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-180-8f2b909426b3> in <module>
#      11     #from sklearn.feature_extraction.text import TfidfVectorizer
#      12     tvec = TfidfVectorizer(min_df=.0025, max_df=.1, stop_words='english', ngram_range = (1,1))
# ---> 13     tvec_weights = tvec.fit_transform(string)
#      14
#      15     weights = np.asarray(tvec_weights.mean(axis=0)).ravel().tolist() #this gives the average weight of each word over all documents
#
# /anaconda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1857         """
#    1858         self._check_params()
# -> 1859         X = super().fit_transform(raw_documents)
#    1860         self._tfidf.fit(X)
#    1861         # X is already a transformed view of raw_documents so
#
# /anaconda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1239                                                        max_doc_count,
#    1240                                                        min_doc_count,
# -> 1241                                                        max_features)
#    1242
#    1243             self.vocabulary_ = vocabulary
#
# /anaconda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in _limit_features(self, X, vocabulary, high, low, limit)
#    1107         kept_indices = np.where(mask)[0]
#    1108         if len(kept_indices) == 0:
# -> 1109             raise ValueError("After pruning, no terms remain. Try a lower"
#    1110                              " min_df or a higher max_df.")
#    1111         return X[:, kept_indices], removed_terms
#
# ValueError: After pruning, no terms remain. Try a lower min_df or a higher max_df.

# %%
#Get top 20 most frequent words for each cluster
for cl in hclus_rslt_df.cluster.value_counts().index:
   
    #print(hclus_rslt_df.wo_trade_name.unique())
    print(cl)
   
    tk_lst = hclus_rslt_df[hclus_rslt_df["cluster"] == cl]
    #each work order needs to be a string, not a list of tokens
    lst = [" ".join(x) for x in tk_lst["clean_text"]]
    #[nltk.word_tokenize(z1) for z1 in z]
    tks = nltk.word_tokenize(" ".join(lst))
    fdist = nltk.FreqDist(tks)
    for word, frequency in fdist.most_common(20):
        print(u'{};{}'.format(word, frequency))
# Out:
# 0
# black;37
# people;15
# white;11
# like;10
# use;9
# want;9
# look;7
# care;7
# love;6
# color;6
# thing;6
# know;6
# men;6
# need;6
# american;6
# williams;6
# good;5
# help;5
# child;5
# design;5
# 1
# black;36
# like;20
# people;19
# want;11
# post;10
# right;9
# child;9
# man;8
# old;7
# thing;7
# time;7
# need;7
# love;6
# read;6
# life;6
# matter;6
# think;6
# look;6
# today;6
# spank;6
# 3
# black;23
# people;10
# white;10
# like;9
# start;8
# know;8
# twitter;8
# feel;6
# think;6
# kaaba;5
# need;5
# child;5
# free;5
# soon;4
# culture;4
# right;4
# let;4
# video;4
# thing;4
# wrong;4
# 2
# mean;4
# black;3
# nigger;3
# blue;2
# collar;2
# game;2
# day;2
# shot;1
# people;1
# video;1
# like;1
# imformation;1
# worker;1
# input;1
# cause;1
# great;1
# men;1
# know;1
# couldn;1
# read;1
